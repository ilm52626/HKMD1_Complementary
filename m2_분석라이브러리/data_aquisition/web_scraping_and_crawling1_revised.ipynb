# %% [markdown]
# # 웹 스크레이핑과 웹 크롤링
#
# ![image.png](data:image/png;base64,...)
#
# 인터넷에서 정보를 얻기 위해서는 웹 페이지에 접속해야 합니다. 이 때, 웹 스크레이핑과 웹 크롤링은 그 페이지에서 우리가 원하는 정보를 얻어내는 방법입니다.
#
# ## 웹 스크레이핑
#
# **웹 스크레이핑**은 마치 정보를 찾는 스파이와 같은 프로그램입니다. 이 프로그램은 우리가 수집하고자 하는 웹 페이지를 선택하고, 해당 페이지에서 필요한 정보를 추출합니다. 이 정보는 다양한 형식일 수 있지만, 대개는 텍스트, 이미지, 링크 등의 형태입니다.
#
#
# ## 웹 크롤링
#
# 반면, **웹 크롤링**은 마치 인터넷에서 거미줄을 쳐놓은 거미같은 프로그램이라고 생각하시면 편합니다. 이 프로그램은 인터넷 상의 모든 웹 페이지를 순차적으로 끝없이 탐색합니다. 그리고 각 페이지에는 다른 페이지로 이동할 수 있는 링크가 있기 때문에, 해당 페이지에서 찾은 모든 링크를 따라가며 다른 페이지로 이동합니다. 이를 위해 일반적으로 "spider" 또는 "crawler"라고 불리는 봇을 사용합니다. 이 프로그램은 웹 페이지에서 다른 페이지로 이동하며 인터넷을 체계적으로 검색하며, 이러한 방식으로 많은 페이지를 한번에 수집할 수 있습니다.
#
# ## 특징
#
# ![image.png](data:image/png;base64,...)
#
# 두 기술 모두 데이터 수집에 활용됩니다. 그러나 웹 크롤링은 자동화된 프로그램을 사용하여 대량의 데이터를 수집하고 분석하는 것을 목적으로 합니다. 반면에 웹 스크레이핑은 특정 데이터를 수집하고 분석하는 것을 목적으로 합니다.
#
# 웹 스크래핑의의 특징:
#
# - 특정 웹 사이트나 페이지에서 필요한 데이터를 자동으로 추출해 내는 것
# - ‘스크래퍼 봇’이 특정 웹 사이트에 콘텐츠를 다운로드하기 위한 HTTP GET 요청을 보냄
# - HTML 문서를 분석하여 특정 패턴을 지닌 데이터를 뽑아냄
# - 추출된 데이터를 원하는 대로 사용할 수 있도록 데이터베이스에 저장
#
# 웹 크롤링의 특징:
#
# - 웹상의 정보들을 탐색하고 수집하는 작업
# - 자동으로 웹 문서를 탐색하는 컴퓨터 프로그램
# - 인터넷을 돌아다니며 여러 웹 사이트에 접속
# - 페이지의 내용과 링크의 복사본을 생성하여 다운로드하고 요약본을 만듦
# - 검색 시 유용한 정보만을 노출하도록 검색 색인을 붙임
#
#
# https://blog.codef.io/crawling_vs_scraping/
#
# https://98yejin.github.io/2020-11-02-crawling-vs-scraping/

# %% [markdown]
# ## BeautifulSoup
# Beautiful Soup Documentation <br/>
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
from bs4 import BeautifulSoup
with open('index.html','r',encoding='utf8') as f:
    soup = BeautifulSoup(f, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    케빈의 홈페이지
#   </title>
#   <link href="./practice.css" rel="stylesheet" type="text/css"/>
#   <script type="javascript">
#   </script>
#   <script src="add_two_numbers.js" type="text/javascript">
#   </script>
#   <script src="what_time_is_it.js" type="text/javascript">
#   </script>
#  </head>
#  <body>
#   <nav>
#    <a href="./index.html">
#     Home
#    </a>
#    <a href="./blog_list.html">
#     Blog
#    </a>
#    <a href="./about_me.html">
#     About
#    </a>
#   </nav>
#   <h1>
#    첫번째 헤드라인
#   </h1>
#   <h2>
#    두번째 헤드라인
#   </h2>
#   <button onclick="whatTimeIsIt()">
#    현재시간
#   </button>
#   <hr/>
#   <label for="inputA">
#    a
#   </label>
#   <input id="inputA" onkeyup="doSomething()" value="1"/>
#   <label for="inputB">
#    b
#   </label>
#   <input id="inputB" onkeyup="doSomething()" value="2"/>
#   <p>
#    <span id="valueA">
#     1
#    </span>
#    +
#    <span id="valueB">
#     2
#    </span>
#    =
#    <span id="valueC">
#     3
#    </span>
#    입니다.
#   </p>
#   <p>
#    프로젝트 기반 빅데이터 서비스 솔루션 개발 전문과정
#   </p>
#   <p id="content">
#    핵심적인 요소기술 14개 모듈
#   </p>
#   <p id="content">
#    빅데이터 머신러닝 프로젝트
#   </p>
#   <p id="content">
#    기업 특화 AI 솔루션 프로젝트
#   </p>
#   <p id="content">
#    빅데이터 AI 공모전 및 관심주제 프로젝트
#   </p>
#   <a href="https://www.google.com">
#    첫화면으로 가기
#   </a>
#   <hr/>
#   <img src="./images/hriver.jpg" width="600px"/>
#  </body>
# </html>

# %%
value = soup.find('span',{'id':'valueA'})
# value = soup.find('span',{'id':'valueA'})
print(value)
# Out:
# <span id="valueA">1</span>

# %%
contents = soup.find_all('p',{'id':'content'})
for i, content in enumerate(contents):
    print(f'{i}번: {content.get_text().strip()}')
# Out:
# 0번: 핵심적인 요소기술 14개 모듈
# 1번: 빅데이터 머신러닝 프로젝트
# 2번: 기업 특화 AI 솔루션 프로젝트
# 3번: 빅데이터 AI 공모전 및 관심주제 프로젝트

# %% [markdown]
# ## 정규표현식
# 정규표현식 연습
# http://pythex.org/

# %% [markdown]
# 파이썬을 활용한 데이터 가공
# - 문자열 자료형(인덱싱) : 시퀀스 자료형으로 인덱스가 있고 인덱스 값으로 접근이 가능함
# - 파이썬에서 문자열을 쉽게 다룰 수 있도록 제공하는 내장함수
#   * find: 해당문자가 없으면 -1 반환
#   * index: 해당 문자가 없으면 에러
#   * strip: 데이터 가공 초기 단계에 불필요한 공백을 지울 때 사용
#   * replace: 특정 문자를 원하는 내용으로 변경
# - 정규표현식
#   * 특정한 규칙을 가진 문자열을 표현하기 위해 사용하는 형식
#   * 주로 문자열의 검색 및 치환에 활용
#   * re 모듈을 제공
#   * 규칙을 정의하기 위해 메타 문자를 활용
#   * 정규표현식 연습 웹 사이트 : https://pythex.org

# %% [markdown]
# 인덱싱

# %%
# title() :주어진 문자열에서 알파벳 외의 문자(숫자, 특수기호, 띄어쓰기 등)로 나누어져 있는 영단어들의 
# 첫 글자를 모두 대문자로 변환시킨다.
text = "k-digital training 7기"
text1 = 'abc'
print(text[0])
print(text[-1])
print(text[len(text)-1])
print(text1.capitalize())
print(text1.upper())
print(text.capitalize())
print(text.title())
# Out:
# k
# 기
# 기
# Abc
# ABC
# K-digital training 7기
# K-Digital Training 7기

# %%
text1 = "   <k-digital training 3기>   "
text2 = ';'
print(text1.strip()+text2)
print(text1.lstrip()+text2)
print(text1.rstrip()+text2)
# Out:
# <k-digital training 3기>;
# <k-digital training 3기>   ;
#    <k-digital training 3기>;

# %%
text = "<title>k-digital training 3기</title>"
print(text.replace('<title>','<div>'))
print(text.replace('title', 'div'))
# Out:
# <div>k-digital training 3기</title>
# <div>k-digital training 3기</div>

# %%
import re
text = ('111<head>안녕하세요</head>22')
body = re.search('<head>.+</head>',text)
body = body.group()
print(body)
# Out:
# <head>안녕하세요</head>

# %%
import re
text = ('111<head>안녕하세요</head>22')
p = re.compile('[가-힣]+')
m = p.search(text).group()
m
# Out:
# '안녕하세요'

# %%
text = '<meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요">'
# content = re.search('([가-힣]+ *)+',text)
content = re.search('([가-힣]+\s*)+',text)
print(content.group())
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
import re
text = '<title>k-digital training 3기</title>'
# body = re.sub('<.\w+>','',text)
# body = re.sub('<\D+>','',text) # 숫자가 아닌 것과 매치
body = re.sub('<.+?>','',text)
print(body)
# Out:
# k-digital training 3기

# %%
import re
text = "<head> 안녕하세요... <title>k-digital training 3기</title> 반갑습니다...</head>"
body = re.search('<title.*/title>',text)
body = body.group()
print(body)
body = re.sub('<.+?>','',body)
print(body)
# Out:
# <title>k-digital training 3기</title>
# k-digital training 3기

# %%
import re
text = "<head> 안녕하세요... <title>k-digital training 3기</title> 반갑습니다...</head>"
body = re.search('<title.*/title>',text)
body = body.group()
print(body)
# Out:
# <re.Match object; span=(16, 52), match='<title>k-digital training 3기</title>'>

# %% [markdown]
# ## 웹 개발 언어
#
# HTML, CSS, Javascript는 웹 개발에 사용되는 세 가지 주요 언어입니다.
#
# HTML은 HyperText Markup Language의 약자로 웹 페이지의 구조를 만들기 위한 언어입니다. HTML은 웹 페이지의 내용과 구조를 정의하는 데 사용됩니다1.
#
# CSS는 Cascading Style Sheets의 약자로 웹 페이지의 디자인과 레이아웃을 만들기 위한 스타일시트입니다. CSS는 HTML로 작성된 웹 페이지의 외형을 예쁘게 바꿀 수 있습니다. 글자 색상과 배경 색상, 배치 등을 자유롭게 변경할 수 있습니다1.
#
# Javascript는 웹 페이지를 프로그래밍하기 위한 언어입니다. Javascript를 사용하면 웹 페이지에 동적인 기능을 추가할 수 있습니다2.
#
# 이 세 가지 언어는 서로 다른 역할을 하지만 함께 사용되어 웹 페이지를 만들어냅니다.
#
# https://codingcoding.tistory.com/1085

# %% [markdown]
# ### HTML
#
# ### HTML의 구조  및 태그
# - 구조
#  - \<!Doctype html> : HTML5 문서를 선언하는 구문
#  - \<html></html> : HTML 문서의 시작과 끝
#  - \<head></head> : CSS, JavaScript, meta, title 정보들을 설정
#  - \<body></body> : 실제 홈페이지 화면을 나타내는 부분
#
# - 요소 구조
#  - HTML 요소는 여러 속성들을 가질 수 있으며 속성들은 해당 요소에 대한 추가 정보를 제공
#  - 시작 태그\(< >)로 시작해서 종료 태그(</>)로 끝남
#  - 요소 안에 다른 요소를 작성할 수 있음
#  <img src = './dataset/html요소구조.jpg' STYLE = 'width:50px;'>

# %%
# HTML 기본 구조
html ='''
<!DOCTYPE html>                html5 명시
<html lang="en">               html 태그로 모든 태그를 감사줌. lang이라는 속성을 포함
 <head>                        head 태그는 meta, title 이외의 style, script, link와 같은 태그 포함
     <meta charset="UTF-8">    
     <title>a.html</title>      title 태그는 문서의 제목
     <meta name="viewport" content="width=device-width, initial-scale=1.0"> meta 태그는 name과 contents속성으로 문서 정보 포함
 </head>
 <body>                        웹페이지의 내용 포함
     <style type="text/css">    CSS 코드가 포함된는 태그  
     </style>
                                script 태그는 JavaScript 코드를 작성하거나 파일 로드. head 태그 or body 태그 하단 위치
 </body>
</html>
'''
print(f'HTML 구조 \n {html}')
# Out:
# HTML 구조
#
# <!DOCTYPE html>                html5 명시
# <html lang="en">               html 태그로 모든 태그를 감사줌. lang이라는 속성을 포함
#  <head>                        head 태그는 meta, title 이외의 style, script, link와 같은 태그 포함
#      <meta charset="UTF-8">
#      <title>a.html</title>      title 태그는 문서의 제목
#      <meta name="viewport" content="width=device-width, initial-scale=1.0"> meta 태그는 name과 contents속성으로 문서 정보 포함
#  </head>
#  <body>                        웹페이지의 내용 포함
#      <style type="text/css">    CSS 코드가 포함된는 태그
#      </style>
#                                 script 태그는 JavaScript 코드를 작성하거나 파일 로드. head 태그 or body 태그 하단 위치
#  </body>
# </html>

# %% [markdown]
# #### HTML 태그
# - p 태그를 이용하여 문단 작성
# - h 태그를 이용하여 폰트 크기 설정
# - ul(unordered list)과 ol(ordered list) 태그로 리스트 작성, 리스트 각각의 요소는 li(항목 나열) 태그로 표시
# - table 태그는 thead, tbody를 가질 수 있으며 표를 표현 : tr 행, th(가운데 정렬,굵은 글씨체),td 각 행의 컬럼
# - input 태그와 button 태그 : 데이터를 넣는 폼과 페이지 조작 버튼 생성
# - select # select 태그로 선택 리스트 생성
# - a 태그로 다른 페이지로 이동. 상대경로(내가 있는 경로부터의 경로), 절대경로(항상 같은 url)
# - img 태그로 이미지 포함 : src(이미지 붙임), alt(이미지 대체)
# - span 태그로 p태그 처럼 글을 추가. span 태그는 옆으로 나열. br 태그 사용하여 p 태그처럼 사용
# - div 태그는 화면 레이아웃을 잡는 역할 : 하위 태그들의 영역을 잡아줌

# %% [markdown]
# #### CSS
# - CSS로 웹 사이트를 꾸며주기 위해 해당 태그에 접근하는 방식을 크롤러에서도 사용.
# - selector : CSS로 꾸미기 위해 특정 요소에 접근하는 것을 셀렉터라고 함.
#   - html 파일을 만들었다면 각각의 태그에 다르게 css 를 설정 할 것입니다. 이 때, 어느 요소에 스타일을 적용할지 알려주는 방식이 바로 css 선택자 입니다.
# - 태그를 이용하여 접근하면 태그는 전부 CSS 효과가 적용
# - class를 이용하면 원하는 요소만 CSS 효과 적용할 수 있고 원하는 요소만 수집할 수 있음.
# - id는 class와 다르게 id값이 고유해야 함(id는 한페이지에 하나만 존재해야 함)
# - 부모 태그와 자식 태그를 나열하여 복잡한 셀렉터를 생성
#
# CSS 선택자 이해
#
# - https://ssungkang.tistory.com/entry/css-css-%EC%84%A0%ED%83%9D%EC%9E%90selector-%EC%9D%98-%EC%A2%85%EB%A5%98%EC%99%80-%EC%98%88%EC%8B%9C
# - https://developer.mozilla.org/en-US/docs/Web/CSS/CSS_Selectors
# - https://www.nextree.co.kr/p8468/

# %%
css = """

- 우리가 html 파일을 만들었다면 각각의 태그에 다르게 css 를 설정 할 것입니다. 
  이 때, 어느 요소에 스타일을 적용할지 알려주는 방식이 바로 css 선택자 입니다.

- 선택자가 어떻게 쓰이는가?

div {
    color: black;
    background-color: yellow;
}
div 태그들에게 css 를 주기 위해서 div 라는 선택자를 사용하였습니다. 이렇게 되면 html 문서에 
모든 div 태그들에는 { } 안에 적용해준 css 속성값들이 적용이 됩니다. div 처럼 태그의 이름 말고도 
선택자를 주는 방식이 굉장히 다양함

선택자의 종류

[ 선택자를 하나만 쓸 경우 ]

전체 선택자
전체 선택자는 * 을 사용하여 나타냅니다.

html 의 모든 태그에 대하여 적용합니다.

* {
    margin: 0 auto;
} 

태그 선택자
태그 선택자는 태그의 이름 을 사용하여 나타냅니다.
태그명이 선택자와 같은 태그들에 대하여 적용합니다.

p {
    color: red;
} 

클래스 선택자
클래스 선택자는 .클래스이름 을 사용하여 나타냅니다.
클래스가 클래스이름과 같은 태그들에 대하여 적용합니다.

.ClassName {
    width: 100px;
} 

ID 선택자
ID 선택자는 #아이디이름 을 사용하여 나타냅니다.
ID가 ID 이름과 같은 태그에 대해서 적용합니다.

#IdName {
    position: fixed;
} 

[ 선택자를 여러 개 쓸 경우] 

선택자를 여러 개 쓰는 경우를 복합 선택자라고 합니다. 복합 선택자에도 여러 가지 종류가 있어 
이에 대해서 알아보겠습니다.

하위 선택자
하위 선택자는 선택자 사이를 공백을 사용하여 나타냅니다.

앞 요소의 자손인 뒷 요소를 선택합니다.

section ul {
    text-shadow: none;
}
자식 선택자

하위 선택자는 선택자 사이를 > 를 사용하여 나타냅니다.

앞 요소의 자식 인 뒷 요소를 선택합니다.

section > ul {
    text-shadow: none;
}

자손과 자식의 차이는 무엇일까요?
자손은 자식을 포괄하는 의미입니다.
자손은 모든 하위 요소를 의미하고 자식은 바로 아래의 자식 요소에만 적용합니다.

인접 형제 선택자
인접 형제 선택자는 선택자 사이를 + 를 사용하여 나타냅니다.

앞 요소 바로 뒤의 뒷 요소를 선택합니다.

h1 + ul {
    color: red;
} 

일반 형제 선택자
일반 형제 선택자는 선택자 사이에 ~ 를 사용하여 나타냅니다.

앞 요소 뒤에 있는 모든 뒷 요소를 선택합니다.

h1 + ul {
    color: red;
}

형제라는 건 무엇일까요?

같은 부모를 가지는 요소들을 형제 라고 합니다.

속성 선택자
속성 선택자는 각 태그가 가지고 있는 그 속성에 접근하는 방식입니다. 생각 외로 활용도가 높으며 
크롤링를 할 경우에도 적절한 id 와 class 이름이 없을 경우, 이용합니다.

태그[속성]
속성이름 에 해당되는 속성을 가진 태그를 선택합니다.

a[href] {
    font-size: 10px;
}
태그[속성="변수"]
속성 의 속성값이 변수 인 태그를 선택합니다.

a[href="http://www.naver.com"] {
    color: black;
}

태그[속성~="변수"]
속성 의 속성값이 변수 를 포함하는 태그를 선택합니다.

a[href~="naver"] {
    color: black;
}

태그[속성^="변수"]
속성 의 속성값이 변수 로 시작하는 태그를 선택합니다.

a[href^="http"] {
    color: black;
}

태그[속성$="변수"]
속성 의 속성값이 변수 로 끝나는 요소를 선택합니다.

a[href$="com"]{
    color: black;
}

태그[속성*="변수"]
속성 의 속성값이 변수 를 포함하는 태그를 선택합니다.

a[href*="naver"] {
    color: black;
}

태그[속성~="변수"] 와 태그[속성*="변수"] 의 차이는 무엇일까요?
~ 은 포함여부를 단어를 기준으로 판단하고 * 는 문자열 기준으로 판단합니다.

다음과 같은 상황에서 navers 는 어떻게 될까요?
~ 은 naver와 navers 는 단어가 다르기 때문에 선택을 못하고
* 은 navers 는 naver 라는 문자열을 포함하기 때문에 선택을 하게 됩니다.

태그[속성|="변수"]
속성 의 속성값이 변수 이거나 변수 로 시작하는 태그를 선택합니다.

a[href|="http"]{
    color: black;
}
"""
print(f'CSS 선택자 \n {css}')
# Out:
# CSS 선택자
#
#
# - 우리가 html 파일을 만들었다면 각각의 태그에 다르게 css 를 설정 할 것입니다.
#   이 때, 어느 요소에 스타일을 적용할지 알려주는 방식이 바로 css 선택자 입니다.
#
# - 선택자가 어떻게 쓰이는가?
#
# div {
#     color: black;
#     background-color: yellow;
# }
# div 태그들에게 css 를 주기 위해서 div 라는 선택자를 사용하였습니다. 이렇게 되면 html 문서에
# 모든 div 태그들에는 { } 안에 적용해준 css 속성값들이 적용이 됩니다. div 처럼 태그의 이름 말고도
# 선택자를 주는 방식이 굉장히 다양함
#
# 선택자의 종류
#
# [ 선택자를 하나만 쓸 경우 ]
#
# 전체 선택자
# 전체 선택자는 * 을 사용하여 나타냅니다.
#
# html 의 모든 태그에 대하여 적용합니다.
#
# * {
#     margin: 0 auto;
# }
#
# 태그 선택자
# 태그 선택자는 태그의 이름 을 사용하여 나타냅니다.
# 태그명이 선택자와 같은 태그들에 대하여 적용합니다.
#
# p {
#     color: red;
# }
#
# 클래스 선택자
# 클래스 선택자는 .클래스이름 을 사용하여 나타냅니다.
# 클래스가 클래스이름과 같은 태그들에 대하여 적용합니다.
#
# .ClassName {
#     width: 100px;
# }
#
# ID 선택자
# ID 선택자는 #아이디이름 을 사용하여 나타냅니다.
# ID가 ID 이름과 같은 태그에 대해서 적용합니다.
#
# #IdName {
#     position: fixed;
# }
#
# [ 선택자를 여러 개 쓸 경우]
#
# 선택자를 여러 개 쓰는 경우를 복합 선택자라고 합니다. 복합 선택자에도 여러 가지 종류가 있어
# 이에 대해서 알아보겠습니다.
#
# 하위 선택자
# 하위 선택자는 선택자 사이를 공백을 사용하여 나타냅니다.
#
# 앞 요소의 자손인 뒷 요소를 선택합니다.
#
# section ul {
#     text-shadow: none;
# }
# 자식 선택자
#
# 하위 선택자는 선택자 사이를 > 를 사용하여 나타냅니다.
#
# 앞 요소의 자식 인 뒷 요소를 선택합니다.
#
# section > ul {
#     text-shadow: none;
# }
#
# 자손과 자식의 차이는 무엇일까요?
# 자손은 자식을 포괄하는 의미입니다.
# 자손은 모든 하위 요소를 의미하고 자식은 바로 아래의 자식 요소에만 적용합니다.
#
# 인접 형제 선택자
# 인접 형제 선택자는 선택자 사이를 + 를 사용하여 나타냅니다.
#
# 앞 요소 바로 뒤의 뒷 요소를 선택합니다.
#
# h1 + ul {
#     color: red;
# }
#
# 일반 형제 선택자
# 일반 형제 선택자는 선택자 사이에 ~ 를 사용하여 나타냅니다.
#
# 앞 요소 뒤에 있는 모든 뒷 요소를 선택합니다.
#
# h1 + ul {
#     color: red;
# }
#
# 형제라는 건 무엇일까요?
#
# 같은 부모를 가지는 요소들을 형제 라고 합니다.
#
# 속성 선택자
# 속성 선택자는 각 태그가 가지고 있는 그 속성에 접근하는 방식입니다. 생각 외로 활용도가 높으며
# 크롤링를 할 경우에도 적절한 id 와 class 이름이 없을 경우, 이용합니다.
#
# 태그[속성]
# 속성이름 에 해당되는 속성을 가진 태그를 선택합니다.
#
# a[href] {
#     font-size: 10px;
# }
# 태그[속성="변수"]
# 속성 이 속성값이 변수 인 태그를 선택합니다.
#
# a[href="http://www.naver.com"] {
#     color: black;
# }
#
# 태그[속성~="변수"]
# 속성 의 속성값이 변수 를 포함하는 태그를 선택합니다.
#
# a[href~="naver"] {
#     color: black;
# }
#
# 태그[속성^="변수"]
# 속성 의 속성값이 변수 로 시작하는 태그를 선택합니다.
#
# a[href^="http"] {
#     color: black;
# }
#
# 태그[속성$="변수"]
# 속성 의 속성값이 변수 로 끝나는 요소를 선택합니다.
#
# a[href$="com"]{
#     color: black;
# }
#
# 태그[속성*="변수"]
# 속성 의 속성값이 변수 를 포함하는 태그를 선택합니다.
#
# a[href*="naver"] {
#     color: black;
# }
#
# 태그[속성~="변수"] 와 태그[속성*="변수"] 의 차이는 무엇일까요?
# ~ 은 포함여부를 단어를 기준으로 판단하고 * 는 문자열 기준으로 판단합니다.
#
# 다음과 같은 상황에서 navers 는 어떻게 될까요?
# ~ 은 naver와 navers 는 단어가 다르기 때문에 선택을 못하고
# * 은 navers 는 naver 라는 문자열을 포함하기 때문에 선택을 하게 됩니다.
#
# 태그[속성|="변수"]
# 속성 의 속성값이 변수 이거나 변수 로 시작하는 태그를 선택합니다.
#
# a[href|="http"]{
#     color: black;
# }

# %% [markdown]
# #### JavaScript
# - 웹 사이트의 기능을 넣어줌. script 태그를 이용하여 작성. head or body 하단에 위치
# - js를 이용하여 HTML 코드를 생성. 크롤러로 분석하기 가장 어려운 부분임
# - DOM(Document Object Model)이란 HTML을 시각적으로 쉽게 표현하기 위해 만든 객체로 크롤러 만들 때 중요
# - 데이터를 수집하기 위해 DOM을 이용해 데이터에 접근한 후 해당 데이터 수집
# - 웹 브라우저는 HTML 코드를 가져온 후 JavaScript를 실행시킨 결과를 보여줌
# - 소스 보기 페이지에 수집하고자 하는 요소가 없다면 네트워크 탭을 이용, 서버에서 데이터를 받아오는 지 확인
# - 그렇지 않은 경우 셀레니움을 사용하여 해결
#
# http://www.tcpschool.com/javascript/js_intro_basic

# %% [markdown]
# 파이썬이 제공하는 표준 라이브러리 모듈
# - os 모듈, time 모듈
# - https://docs.python.org/ko/3/py-modindex.html#cap-o
#
# 외부 모듈
# - pip install 패키지명 으로 외부 모듈 설치 가능
# - 데이터 분석/통계 : numpy, pandas, matplotlib ...
# - 인공지능 : Tensorflow, PyTorch, Keras
# - 웹 크롤링 : BeautifulSoup, selenumu ...

# %% [markdown]
# requests 모듈 : pip install requests 명령어로 설치, anaconda를 설치하면 기본 설치
# - http는 요청과 응답으로 이루어져 있음
# - 요청/응답 구조
#  - 요청
#       * GET : 정보를 가져오기 위해 요청
#       * POST: 새로운 정보를 보내기 위해 요청
#       * PUT: 수정할 정보를 보내기 위해 요청
#       * DELETE: 정보를 삭제하기 위해 요청
#  - 응답
#       * 1XX: 요청을 받았고 작업 진행 중
#       * 2XX: 사용자의 요청이 성공적으로 수행 됨
#       * 3XX: 요청은 완료되었으나 리다이렉션이 필요
#       * 4XX: 사용자의 요청이 잘못됨
#       * 5XX: 서버에 오류가 발생함
# - import requests로 모듈 호출 후 사용

# %%
import requests
URL = 'http://naver.com'
response = requests.get(URL)
print(response.status_code)
# Out:
# 200

# %%
import requests
URL = 'http://naver.com'
response = requests.get(URL)
print(response.status_code)
# print(response.text)
# Out:
# 200

# %%
import requests
URL = 'http://naver.com'
response = requests.get(URL)
html_data = response.text
print(html_data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20220526.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20220720154431,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '09170130',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--aweb14-->"; </script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/search.31110d72.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/nmain.f00a90f1.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> </head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap">
# <style>._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px -33px;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6lT._3MOWOORv:after{background-position:-80px -85px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5EzmJ:after{background-position:-65px -85px}._1hiMWemA{height:49px}._1hiMWemA .tY_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;height:1px;bottom:0;background-color:rgba(0,0,0,.050980392156862744)}</style>
# <div
# id="NM_TOP_BANNER"
# data-clk-prefix="top"
# class="_1hiMWemA"
# style="background-color: #fff7e1"
# >
# <div class="tY_u8r23">
# <a
# class="_3h-N8T9V"
# href="https://whale.naver.com/banner/details/security/?=main&wpid=RydDy7"
# data-clk="dropbanner1b"
# ></a
# ><span
# class="_1syGnXOL _3VkgqBXB"
# data-clk="dropbanner1b"
# style="padding-right: 20px; font-size: 17px; color: black"
# ><span>매일 쓰는 브라우저 보안이 걱정된다면, </span
# ><strong
# >안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.</strong
# ></span
# ><a
# href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe"
# class="_2aeXMlrb BMgpjddw"
# id="NM_whale_download_btn"
# data-clk="dropdownload1b"
# ><span style="background-color: #0436c7">다운로드</span></a
# ><button
# type="button"
# data-ui-cookie-exp-days="3"
# data-ui-cookie-key="NM_TOP_PROMOTION"
# data-ui-cookie-value="1"
# data-ui-hide-target="#NM_TOP_BANNER"
# data-clk="dropclose1b"
# class="_20PYt6lT _39oMCV2N"
# >
# 3일 동안 보지 않기
# </button>
# </div>
# </div>  <div id="header" role="banner">
#
#
#
#
#
#
#
#
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_default">
# <a href="/" class="logo_naver" data-clk="top.logo"
# ><span class="blind">네이버</span></a
# >
# </h1>
# </div>
# <div class="service_area">
# <a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a href="https://jr.naver.com" class="link_jrnaver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a href="https://happybean.naver.com" class="link_happybin" data-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
#
# <div id="search" class="search_area" data-clk-prefix="sch">
# <form id="sform" name="sform" action="https://search.naver.com/search.naver" method="get" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select id="where" name="where" title="검색 범위 선택" class="blind">
# <option value="nexearch" selected="selected">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input type="hidden" id="sm" name="sm" value="top_hty" />
# <input type="hidden" id="fbm" name="fbm" value="0" />
# <input type="hidden" id="acr" name="acr" value="" disabled="disabled" />
# <input type="hidden" id="acq" name="acq" value="" disabled="disabled" />
# <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled" />
# <input type="hidden" id="ie" name="ie" value="utf8" />
# <input type="hidden" id="acir" name="acir" value="" disabled="disabled" />
# <input type="hidden" id="os" name="os" value="" disabled="disabled" />
# <input type="hidden" id="bid" name="bid" value="" disabled="disabled" />
# <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled" />
# <input type="hidden" id="eid" name="eid" value="" disabled="disabled" />
# <input type="hidden" id="mra" name="mra" value="" disabled="disabled" />
#
#
#
# <div class="green_window" style=''>
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input id="query" name="query" type="text" title="검색어 입력" maxlength="255" class="input_text" tabindex="1" accesskey="s" style="ime-mode:active;" autocomplete="off"  placeholder="검색어를 입력해 주세요." onclick="document.getElementById('fbm').value=1;" value="" data-atcmp-element>
# </div>
# <button id="search_btn" type="submit" title="검색" tabindex="3" class="btn_submit" onclick="window.nclick(this,'sch.action','','',event);" style=''>
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a href="#" id="ke_kbd_btn" role="button" class="btn_keyboard" onclick="return false;"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a href="#" role="button" id="nautocomplete" tabindex="2" class="btn_arw _btn_arw fold" aria-pressed="false" data-atcmp-element><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div id="autoFrame" class="reatcmp" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element>
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a role="button" href="#" class="item _delAll" aria-pressed="false">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a href="#" role="button" class="bt_item _del" aria-pressed="false"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" data-clk="sly.help" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _keywordOnOff">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_lotto _answer" data-template-type="answer_3" data-code="@code@" data-keyword="@1@">
# <a href="#" class="link_item">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@5@회차 당첨번호</span>
# <span class="dsc">
# <span class="item">추첨 @13@.</span><span class="item">지급기한 1년</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc lotto">
# <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_exchange _answer" data-template-type="answer_9" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @11@">
# <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
# <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>
# <div class="dsc_area">
# <span class="tit">@txt@<span class="sub">@currency@</span></span>
# <span class="dsc">
# <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc"><em class="num">@6@</em>원</span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_weather _answer" data-template-type="answer_11" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @12@">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@7@, @message@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">
# <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
# <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
# <em class="degree">@8@<sup class="celsius">°</sup></em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_site _answer" data-template-type="answer_17" data-code="@code@" data-keyword="@1@">
# <a href="@5@" class="link_item" target="_blank">
# <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@5@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">바로가기</span>
# </span>
# </a>
# </div>
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <!-- 최근검색어 있으면 날짜 표시 -->
# <em class="date">@date@.</em>
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-intend-rank="@intendRank@" data-template-type="intend" data-keyword="@transQuery@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
# <span class="dsc_inner">
# <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
# <span class="_alert_passage2"></span>
# <!-- [AU] _alert_link 클래스를 추가해주세요. -->
# <a href="#" class="link _alert_link" target="_blank">자세히보기</a>
# </span>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="link_dsc" data-clk="sug.cxhelp" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a role="button" href="#" class="bt_switch active _plus_btn" aria-pressed="false"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a href="https://nid.naver.com/nidlogin.login" class="btn btn_login" data-clk="sug.cxlogin">로그인</a>
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a href="#" role="button" class="btn_close _plus_layer_close"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1987" data-clk="sug.help" target="_blank">도움말</a></span>
# <span class="opt_item"><a href="https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215" class="report" data-clk="sug.report" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _suggestOnOff">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# </div>
# </div>
#
# <!--EMPTY-->
# <div id="gnb" role="navigation">
# <div id="NM_FAVORITE" class="gnb_inner">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
# <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li>
# <li class="nav_item"><a href="https://kin.naver.com/" class="nav" data-clk="svc.kin">지식iN</a></li>
# <li class="nav_item"><a href="https://shopping.naver.com/" class="nav shop" data-clk="svc.shopping"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a href="https://shoppinglive.naver.com/home" class="nav shoplive"
# data-clk="svc.shoppinglive"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a href="https://order.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li>
# <li class="nav_item">
# <a href="https://tv.naver.com/" class="nav" data-clk="svc.tvcast"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul
# class="list_nav NM_FAVORITE_LIST"
# >
# <li class="nav_item"><a href="https://dict.naver.com/" class="nav" data-clk="svc.dic">사전</a></li>
# <li class="nav_item"><a href="https://news.naver.com/" class="nav" data-clk="svc.news">뉴스</a></li>
# <li class="nav_item"><a href="https://finance.naver.com/" class="nav" data-clk="svc.stock">증권</a></li>
# <li class="nav_item"><a href="https://land.naver.com/" class="nav" data-clk="svc.land">부동산</a></li>
# <li class="nav_item"><a href="https://map.naver.com/" class="nav" data-clk="svc.map">지도</a></li>
# <li class="nav_item"><a href="https://vibe.naver.com/" class="nav" data-clk="svc.vibe">VIBE</a></li>
# <li class="nav_item"><a href="https://search.shopping.naver.com/book/home" class="nav" data-clk="svc.book">도서</a></li>
# <li class="nav_item"><a href="https://comic.naver.com/" class="nav" data-clk="svc.webtoon">웹툰</a></li>
#
# </ul>
# <ul class="list_nav type_empty" style="display: none;"></ul>
# <a href="#" role="button" class="btn_more" data-clk="svc.more">더보기</a>
# <div class="ly_btn_area">
# <a href="more.html" class="btn NM_FAVORITE_ALL" data-clk="map.svcmore">서비스 전체보기</a>
# <a href="#" role="button" class="btn btn_set" data-clk="map.edit">메뉴설정</a>
# <a href="#" role="button" class="btn btn_reset" data-clk="edt.reset">초기화</a>
# <a href="#" role="button" class="btn btn_save" data-clk="edt.save">저장</a>
# </div>
# </div>
# <div id="NM_WEATHER" class="group_weather">
# <div>
# <a data-clk="squ.weat" href="https://weather.naver.com/today/09170130" class="weather_area ico_w05">
# <div class="current_box">
# <strong class="current" aria-label="현재기온">31.2°</strong><strong class="state">구름많음</strong>
# </div>
# <div class="degree_box">
# <span class="min" aria-label="최저기온">24.0°</span><span class="max" aria-label="최고기온">30.0°</span>
# </div>
# <span class="location">이태원동</span>
# </a>
# </div>
# <div>
# <a data-clk="squ.dust" href="https://weather.naver.com/today/09170130" class="air_area">
# <ul class="list_air">
# <li class="air_item">미세<strong class="state state_good">좋음</strong></li>
# <li class="air_item">초미세<strong class="state state_good">좋음</strong></li>
# </ul>
# <span class="location">이태원동</span>
# </a>
# </div>
#
# </div>
# </div>
# <div class="ly_service">
# <div class="group_service NM_FAVORITE_ALL_LY"></div>
# <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;"></div>
# </div>
# </div>
# </div>
#  <div id="container" role="main"> <div style="position:relative;width:1130px;margin:0 auto;z-index:11"> <div id="da_top"></div> <div id="da_expwide"></div> </div> <div id="NM_INT_LEFT" class="column_left"> <div id="veta_top"> <div id="veta_top_inner" style="height:135px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="newsstand" class="sc_newscast"> <h2 class="blind">뉴스스탠드</h2> <div id="NM_NEWSSTAND_HEADER" class="group_issue" data-clk-prefix="ncy"> <div class="issue_area"> <a class="link_media" href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y" data-clk="newsflash">연합뉴스</a> <div id="NM_ONELINE_ROLLING" class="list_issue" data-nm-ui="rolling"> <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013322841" class="issue" data-clk="quickarticle">30만명 확진 대비…4천병상 추가확보·요양병원 접촉면회 중단</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013322881" class="issue" data-clk="quickarticle">안철수, '安 당대표·張 사무총장' 제휴설에 "처음 들어"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013322325" class="issue" data-clk="quickarticle">박홍근 "檢출신 '문고리 육상시'…권력사유화 대가, 朴땐 탄핵"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013322636" class="issue" data-clk="quickarticle">민주, '민주유공자법' 재추진…"운동권 셀프보상법 아냐"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013322897" class="issue" data-clk="quickarticle">박진 "일본도 韓노력에 성의있게 호응할 용의가 있다고 느껴"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013322847" class="issue" data-clk="quickarticle">법무부 "강제 북송 전 법리 검토…법적 근거 없다 판단"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013323005" class="issue" data-clk="quickarticle">北피격 공무원 유족 "대통령기록물 공개하라" 행정소송</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013323419" class="issue" data-clk="quickarticle">노동장관, 하루만에 또 거제로…"대우조선해양 파업 해결 임박"</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013323344" class="issue" data-clk="quickarticle">한국여권으로 192곳 입국 쉬워 …여권지수 세계 2위</a></div>
# <div><a href="https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0013323456" class="issue" data-clk="quickarticle">인하대, '성폭행 추락사' 2차 가해 대응…로펌 선임</a></div> </div> </div> <div class="direct_area"> <a href="http://news.naver.com/" class="link_news" data-clk="newshome">뉴스홈</a>
# <a href="http://entertain.naver.com/home" class="link_direct" data-clk="entertainment">연예</a>
# <a href="http://sports.news.naver.com/" class="link_direct" data-clk="sports">스포츠</a>
# <a href="http://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101" class="link_direct" data-clk="economy">경제</a> </div> </div>        <div id="NM_NEWSSTAND_TITLE" class="group_title" data-clk-prefix="nsd"> <a href="http://newsstand.naver.com/" class="link_newsstand" data-clk="title" target="_blank">뉴스스탠드</a> <div id="NM_NEWSSTAND_data_buttons" class="sort_area" role="tablist">  <a href="#" role="tab" data-type="my" data-clk="my" class="btn_sort" aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false">구독한 언론사</a> <a href="#" role="tab" data-type="all" data-clk="all" class="btn_sort" aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true">전체언론사</a>  </div> <div id="NM_NEWSSTAND_view_buttons" class="set_area" role="tablist">  <a href="#" role="tab" data-type="list" data-clk="articleview" class="btn_set" aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false"> <i class="ico_list"><span class="blind">리스트형</span></i></a> <a href="#" role="tab" data-type="thumb" data-clk="pressview" class="btn_set" aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true"> <i class="ico_tile"><span class="blind">썸네일형</span></i></a>  <a href="http://newsstand.naver.com/config.html" class="btn_set" data-clk="set" target="_blank"> <i class="ico_set"><span class="blind">설정</span></i></a> </div> </div> <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative"> <div id="NM_NEWSSTAND_DEFAULT_LIST" class="group_news" role="tabpanel" style="display:none" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev"><i class="ico_btn"><span class="blind">이전</span></i></a> <a href="#" role="button" class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="list_view"> <div class="option_area"> <div class="list_option_wrap"> <ul class="list_option"> <li class="option_item" data-cateid="ct2"><a href="#" class="option" data-clk="daei">종합/경제</a></li> <li class="option_item" data-cateid="ct3"><a href="#" class="option" data-clk="dtvcom">방송/통신</a></li> <li class="option_item" data-cateid="ct4"><a href="#" class="option" data-clk="dit">IT</a></li> <li class="option_item" data-cateid="ct5"><a href="#" class="option" data-clk="deng">영자지</a></li> <li class="option_item" data-cateid="ct6"><a href="#" class="option" data-clk="dsporent">스포츠/연예</a></li> <li class="option_item" data-cateid="ct7"><a href="#" class="option" data-clk="dmagtec">매거진/전문지</a></li> <li class="option_item" data-cateid="ct8"><a href="#" class="option" data-clk="dloc">지역</a></li> </ul> </div> </div> <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a"></div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg">해당 언론사 사정으로 접근이 제한됩니다.</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE">확인</a> </div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg"><strong class="NM_NEWSSTAND_POPUP_PNAME"></strong>을(를)<br>구독해지 하시겠습니까?</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone">확인</a> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel">취소</a> </div> </div> <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none"> <p class="toast_msg">구독한 언론사에 추가되었습니다.</p> </div> </div>   <div id="NM_NEWSSTAND_DEFAULT_THUMB" class="group_news" role="tabpanel" style="display:block" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev ...
# <div class="tile_view">
# <div class="frame_area">
# <i class="line to_right1"></i>
# <i class="line to_right2"></i>
# <i class="line to_right3"></i>
# <i class="line to_bottom1"></i>
# <i class="line to_bottom2"></i>
# <i class="line to_bottom3"></i>
# <i class="line to_bottom4"></i>
# <i class="line to_bottom5"></i>
# </div>
# <div class="thumb_area">
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="117"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/117.png"
# height="20"
# alt="마이데일리"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="117"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="117"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=117"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="117"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="092"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/092.png"
# height="20"
# alt="지디넷코리아"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="092"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="092"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=092"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="092"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="215"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/215.png"
# height="20"
# alt="한국경제TV"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="215"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="215"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=215"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="215"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="044"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/044.png"
# height="20"
# alt="코리아헤럴드"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="044"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="044"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=044"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="044"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="011"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2019/logo/011.png"
# height="20"
# alt="서울경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="011"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="011"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=011"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="011"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="052"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/052.png"
# height="20"
# alt="YTN"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="052"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="052"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=052"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="052"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="018"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/018.png"
# height="20"
# alt="이데일리"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="018"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="018"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=018"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="018"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="277"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/277.png"
# height="20"
# alt="아시아경제"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="277"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="277"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=277"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="277"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="055"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/055.png"
# height="20"
# alt="SBS"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="055"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="055"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=055"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="055"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="326"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/326.png"
# height="20"
# alt="KBS World"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="326"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="326"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=326"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="326"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="006"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/006.png"
# height="20"
# alt="미디어오늘"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="006"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="006"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=006"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="006"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="025"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2021/0824/nsd115034872.png"
# height="20"
# alt="중앙일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="025"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="025"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=025"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="025"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="005"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/005.png"
# height="20"
# alt="국민일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="005"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="005"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=005"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="005"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="030"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/030.png"
# height="20"
# alt="전자신문"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="030"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="030"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=030"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="030"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="047"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/047.png"
# height="20"
# alt="오마이뉴스"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="047"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="047"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=047"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="047"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="312"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/312.png"
# height="20"
# alt="텐아시아"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="312"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="312"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=312"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="312"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="830"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/up/2021/0211/nsd02321523.png"
# height="20"
# alt="게임동아"
# class="news_logo"
# />
# ...
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="62cea63a679445689fccedcd" data-da-position="true">
# 					<a href="https://blog.naver.com/maroyuki/222796333877" class="theme_thumb" data-clk="tcc_lif.list5cont5" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20220718_144%2F16580762533956UcSS_JPEG%2F750_8.jpg%22&amp;type&#x3D;nf340_228" alt="여행에서 만난 그릇들" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/maroyuki/222796333877" class="theme_info" data-clk="tcc_lif.list5cont5" target="_blank">
# 						<em class="theme_category"> 리빙</em>
# 						<strong class="title elss">여행에서 만난 그릇들</strong>
#                         <p class="desc">살림살이에 관심을 갖게 되면서부터 여행을 떠나면 항상 그 지역의 그릇가게나 리빙샵을 방문하는 게 우리의 관례가 되었다. 그렇게 해를 거듭하며 여기저기에서 데려오다보니 현재는 은근히 많은 그릇들이 집에서 열일하고 있는 중. 평소에 쉽게 살 수 있는 예쁜 그릇들도 물론 많지만 여행지에서 모은 그릇들에는 우리 나름의 추억이 담겨있어 괜시리 더 소중하게 느껴지기도</p>
# 						<div class="source_box">
# 							<span class="date">2주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">달고양이</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
# <div class="group_theme" data-block-id="" data-block-code="PC-THEME-LIVINGHOME-MOBILE-RANKING-DEFAULT-5" data-block-type="MATERIALS" data-template-code="MOBILE-RANKING-LIST"
#
# 	 data-da="container"
# 	 data-index=""
#      data-page="3"
# 	 style="display:none">
#
# 	<div class="list_theme_wrap">
# 		<ul class="list_theme">
#
# 				<li class="theme_item" data-gdid="62d421fe96e9990a3d558378" data-da-position="true">
# 					<a href="https://blog.naver.com/minjoo901010/222785370325" class="theme_thumb" data-clk="tcc_lif.list6cont1" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20220713_277%2F1657710127412qnLwL_JPEG%2F1655905471237.jpg%22&amp;type&#x3D;nf340_228" alt=" 비닐 봉지, 쓰레기 봉투 세모네모로 깔끔하게 접는 법 " width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/minjoo901010/222785370325" class="theme_info" data-clk="tcc_lif.list6cont1" target="_blank">
# 						<em class="theme_category"> 리빙</em>
# 						<strong class="title elss"> 비닐 봉지, 쓰레기 봉투 세모네모로 깔끔하게 접는 법 </strong>
#                         <p class="desc">맹은 결혼하면서 리빙 주제에 관심이 많아요 자취 경험이 없어서 집정리에 대한 다양한 시도를 아직까지도 하고 있어요ㅋㅋㅋㅋ(결혼 2년차) 그 중에 가장 속 시원했던 쓰레기봉투와 비닐 정리한 방법을 소개해드리고자 해요👍 비닐, 쓰레기봉투 정리 - 세모 네모 접기 - 눌맹이 사는 오피스텔은 음식물쓰레기를 그때그때 버릴 수 있는데(전용봉투X), 버릴 봉투를 모아</p>
# 						<div class="source_box">
# 							<span class="date">3주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">눌맹</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="62d421fe96e9990a3d558379" data-da-position="true">
# 					<a href="https://blog.naver.com/esggbe100/222807338872" class="theme_thumb" data-clk="tcc_lif.list6cont2" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20220713_201%2F1657709532161rGJHn_JPEG%2Ferah.jpg%22&amp;type&#x3D;nf340_228" alt="안 쓰는 대나무 문발 리폼, 다용도 수납함 만들기 " width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/esggbe100/222807338872" class="theme_info" data-clk="tcc_lif.list6cont2" target="_blank">
# 						<em class="theme_category"> 리빙</em>
# 						<strong class="title elss">안 쓰는 대나무 문발 리폼, 다용도 수납함 만들기 </strong>
#                         <p class="desc">어제는 더위에 댕댕이까지 갑자기 다리를 절어서 어찌나 놀랬는지.. 다행히도 오늘은 괜찮은듯해서 쪼물락 거려보았어요. 모쪼록 이번 더위도 잘 이겨내시길 바랍니다. 덥다는 이유로 진짜 꼬물락 거리기도 부담스런 날씨네요 에어컨을 풀가동해도 밖에도 못나가고 에어컨앞에서 ㅎㅎ 몇일전 잘라둔 나무 오늘은 마음의 여유가있어서 완성해 주기로했어요. https://blog</p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">신디</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="dfc05baf-bec7-4afd-a1ea-6ecc1bce2f12-1cf18e08-8c3f-44dc-bf21-a24e5c6209d2" data-da-position="true">
# 					<a href="https://blog.naver.com/oroi222/222775527484" class="theme_thumb" data-clk="tcc_lif.list6cont3" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20220706_28%2F1657042615839VsY0V_JPEG%2F750_23.jpg%22&amp;type&#x3D;nf340_228" alt="35년 된 아파트를 신혼집으로" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/oroi222/222775527484" class="theme_info" data-clk="tcc_lif.list6cont3" target="_blank">
# 						<em class="theme_category"> 리빙</em>
# 						<strong class="title elss">35년 된 아파트를 신혼집으로</strong>
#                         <p class="desc">복도식 27평 올수리 인테리어 드레스룸 온라인 집들이 #드레스룸 방 3개중 가장 작은 정사각형의 방! 이 방은 크기가 매우작아 원래 서재방으로 할까 하다가 점점 늘어나는 옷이 정리가 안돼 시스템 행거를 설치하게 되었어요! 처음에는 이렇게 남편 취미인 신발 모으는 공간으로 활용하다가 신발만 두기엔 아깝기도 하고.. 신발 둔김에 옷도 두고싶어서 ㅋㅋ 시스템장을</p>
# 						<div class="source_box">
# 							<span class="date">1개월 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">소소해집</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="7d87afad-fb33-4d24-a4bd-a890a2888003-64830b7e-7756-4a6b-b1a3-c1fc44148ecd" data-da-position="true">
# 					<a href="https://blog.naver.com/soyowng/222762210568" class="theme_thumb" data-clk="tcc_lif.list6cont4" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20220707_288%2F1657186413750408Cf_JPEG%2F336_6.jpg%22&amp;type&#x3D;nf340_228" alt="깔끔한 욕실, 마이너스 옵션 반셀프 인테리어 #졸리컷" width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://blog.naver.com/soyowng/222762210568" class="theme_info" data-clk="tcc_lif.list6cont4" target="_blank">
# 						<em class="theme_category"> 리빙</em>
# 						<strong class="title elss">깔끔한 욕실, 마이너스 옵션 반셀프 인테리어 #졸리컷</strong>
#                         <p class="desc">마이너스 옵션 세대 반셀프 인테리어 / 욕실 1탄 거실 욕실 기본 디자인으로 깔끔하게! 욕실은 반셀프 인테리어에서 가장 걱정이 됬던 곳이다. #욕실인테리어 는 하자가 생길 경우 가장 골치 아파지는 곳이기 때문이다. 크게 욕심부리지 않고 딱 기본으로 깔끔하게만 하자! 가 목표였다. 무난하고 깔끔한 욕실을 원한다면 우리집 욕실이 도움이 될 것 같다. 완성된 전</p>
# 						<div class="source_box">
# 							<span class="date">1개월 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">Lim Sally</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="f76a1918-4fb0-41b0-8f32-59c3805010a6-bcbcef39-1ed6-4c4f-807a-4561918783fe" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;33931965&amp;memberNo&#x3D;24659848" class="theme_thumb" data-clk="tcc_lif.list6cont5" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fshop.phinf%2F20220714_27%2F1657804245870Sb5wJ_JPEG%2F336_1.jpg%22&amp;type&#x3D;nf340_228" alt="문을 열면 야외가 되는 썬룸, 공간 활용도를 높인 주택 " width="170" height="114" onerror="this.outerHTML='<span class=\'pm_noimg\'><span class=\'noimg_text\'>이미지 준비중</span></span>'">
# 						<span class="thumb_bd"></span>
#
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;33931965&amp;memberNo&#x3D;24659848" class="theme_info" data-clk="tcc_lif.list6cont5" target="_blank">
# 						<em class="theme_category"> 리빙</em>
# 						<strong class="title elss">문을 열면 야외가 되는 썬룸, 공간 활용도를 높인 주택 </strong>
#                         <p class="desc">유연하고 포용적인 태도는 종종 물에 비유되곤 한다. 물은 중력을 거스르지 않고 아래로 흐르면서도 어느 누구와도 다투지 않는다. 노은동 주택의 건축주가 집을 지으며 품었던 마음가짐에는 물처럼 흐르는 지혜가 엿보인다. 집 짓기는 다양한 전문가들의 협업으로 이루어지기 때문에, 원만한 관계는 집 짓기의 성공을 좌우한다고 볼 수 있다. 글 강창대 기자 사진 민영기 </p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source">
#
#                                 <span class="source_inner">전원주택라이프</span>
#                             </span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
#
#
#
#
# 	<div class="btn_more_wrap">
# 		<button type="button" class="btn_more" data-clk-custom="tcc_lif.more" data-next-page="2"><i class="ico_more"></i>새로운 글 더보기</button>
# 	</div>
#
#
# <div class="NM_THEME_META" style="display: none" data-panel-code="LIVINGHOME" data-parent-code=""></div>
#
# 	</div>
# </div>
#  </div> </div> <div id="NM_INT_RIGHT" class="column_right"> <div class="column_fix_wrap"> <div id="da_brand"></div>
#
#
#
#
#
# <div id="account" class="sc_login">
# <h2 class="blind">Sign in</h2>
# <p class="login_msg">Connect with people</p>
# <a href="https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com" class="link_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">NAVER</span></i>Sign in</a>
# <div class="sub_area">
# <div class="look_box">
# <a href="https://nid.naver.com/user/help.nhn?todo=idinquiry" class="link_look" data-clk="log_off.searchid">Forgot Username</a>
# <a href="https://nid.naver.com/nidreminder.form" class="link_look" data-clk="log_off.searchpass">Password</a>
# </div>
# <a href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com" class="link_join" data-clk="log_off.registration">Sign up</a>
# </div>
# </div>
#
#
#
#  <div id="timesquare" class="sc_timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a href="#" role="button" class="btn_nav btn_prev" data-clk="squ.pre"><span class="blind">이전</span></a>
# <a href="#" role="button" class="btn_nav btn_next" data-clk="squ.next"><span class="blind">다음</span></a>
# </div>
# <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
# <div>
# <a href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819" class="card_news" data-clk="squ.line3"><i class="news_badge">이슈</i><span class="news">코로나바이러스감염증-19 현황</span></a>
# </div>
# <div>
# <a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSPI" class="card_stock " data-clk="squ.kospi">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스피</em>
# <strong class="current">2,386.85</strong>
# <span class="rate rate_up"><span class="blind">상승</span>15.88 +0.67%</span>
# </div>
# </a>
# </div>
# <div>
# <a href="https://finance.naver.com/sise/sise_index.nhn?code=KOSDAQ" class="card_stock " data-clk="squ.kosdaq">
# <strong class="stock_title">증시</strong>
# <div class="stock_box">
# <em class="name">코스닥</em>
# <strong class="current">790.72</strong>
# <span class="rate rate_up"><span class="blind">상승</span>8.39 +1.07%</span>
# </div>
# </a>
# </div>
# <div>
# <a href="https://finance.naver.com/marketindex/exchangeDetail.nhn?marketindexCd=FX_USDKRW" class="card_stock type_exchange" data-clk="squ.usd">
# <strong class="stock_title">환율</strong>
# <div class="stock_box">
# <em class="name">USD</em>
# <strong class="current">1,312.50</strong>
# <span class="rate rate_up"><span class="blind">상승</span>3.50 +0.27%</span>
# </div>
# </a>
# </div>
# </div>
# </div> <!-- EMPTY --> </div> <div id="veta_branding"> <span class="blind"> <script id="veta_service_check"></script> </span> <div id="veta_branding_inner" style="width:350px;height:200px"> </div> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="shopcast" class="sc_shopcast"> <iframe id="shopcast_iframe" data-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&domain=N" title="쇼핑캐스트" width="350" height="1809" marginheight="0" marginwidth="0" scrolling="no" frameborder="0"></iframe> </div> </div> </div> <a id="NM_scroll_top_btn" href="#wrap" class="content_top"><span class="blind">TOP</span></a> <button id="NM_darkmode_btn" type="button" role="button" class="btn_theme" aria-pressed="false"  > <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div id="NM-FOOTER-AD" class="banner_area"> <div class="da_box_wrap"> <div id="da_public_left"> </div> <div id="da_public_right"> </div> <div id="veta_time2"> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3> <!-- EMPTY --> </div> <a href="more.html" class="link_all" data-clk="svcmap">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a href="https://www.navercorp.com/service/creators" class="link_partner" data-clk="creator">크리에이터</a> <a href="https://www.navercorp.com/service/business" class="link_partner" data-clk="smbusiness">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a href="https://campaign.naver.com/smefullcare/online/" class="link_partner" data-clk="sme">SME 풀케어 시스템</a> <a href="https://business.naver.com/service.html" class="link_partner" data-clk="service">비즈니스 · 광고</a> <a href="https://sell.storefarm.naver.com/#/home/about" class="link_partner" data-clk="store">스토어 개설</a> <a href="https://smartplace.naver.com" class="link_partner" data-clk="place">지역업체 등록</a> <a href="https://expert.naver.com/expert/introduction?tab=guide#join" class="link_partner" data-clk="expert">엑스퍼트 등록</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a href="https://developers.naver.com" class="link_partner" data-clk="center">네이버 개발자 센터</a> <a href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md" class="link_partner" data-clk="openapi">오픈 API</a> <a href="https://naver.github.io" class="link_partner" data-clk="opensource">오픈소스</a> <a href="https://d2.naver.com" class="link_partner" data-clk="d2">네이버 D2</a> <a href="http://d2startup.com" class="link_partner" data-clk="naverD2SF">네이버 D2SF</a> <a href="https://www.naverlabs.com" class="link_partner" data-clk="labs">네이버 랩스</a> </div> </div> <div class="service_box_wrap"> <div class="service_box" data-clk-prefix="wbd"> <a href="http://whale.naver.com/" class="service_logo" data-clk="bt"> <img src="data:image/png;base64,..." alt="웨일" width="48" height="48"> </a> <div class="service_info"> <strong class="title">웨일 브라우저</strong> <a href="http://whale.naver.com/" class="dsc" data-clk="bt">다운받기</a> </div> </div> <div class="service_box" data-clk-prefix="prj"> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="service_logo" data-clk="link"> <img src="data:image/png;base64,..." alt="꽃" width="47" height="50"> </a> <div class="service_info"> <strong class="title">프로젝트 꽃</strong> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="dsc" data-clk="link">바로가기</a> </div> </div> </div> </div> <div class="corp_area" data-clk-prefix="plc"> <h3 class="blind">네이버 정책 및 약관</h3> <ul class=" ...

# %%
import requests
URL = 'http://naver.com'
response = requests.get(URL)
html_data = response.text
# print(html_data)
print(html_data.find('바로가기'))
print(html_data[5883:5887])
# print(html_data[365:368])
# Out:
# 5883
# 바로가기

# %%
html_data = response.text
# print(html_data,'\n')
print(html_data.find('네이버 메인에서'))
print(html_data[365:397])
# Out:
# 365
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
import re
content = re.search('([가-힣]+ *)+',html_data)
content = content.group()
print(content)
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
s = "abc"
s.split('b')
# Out:
# ['a', 'c']

# %%
li = range(5)
for i in li:
    print('c{} = i'.format(i))
# Out:
# c0 = i
# c1 = i
# c2 = i
# c3 = i
# c4 = i

# %%
html_data
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20220127.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function t(){}return t.prototype=n,new t})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"L ...

# %%
html_data.find('<meta property=')
print(html_data[390:450])
# Out:
#  만나 보세요"/> <meta property="og:title" content="네이버"> <meta pr

# %%
# split() 추출 후 정규표현식 활용한 가공
import re
content = html_data.split('<meta property=')[1]
print(content)
content = re.search('네이버+',content)
print(content.group())
print(content)
# Out:
# "og:title" content="네이버">
# 네이버
# <re.Match object; span=(20, 23), match='네이버'>

# %%
# Naver에서 'aa'를 검색
# get 메소드에 params 인자에 값을 넣어 함께 Get 요청(파라미터:query)
# 파라미터를 두 개 이상 사용하여 정보 요청 가능(특정날짜의 네이버 웹툰)
import requests
URL = 'https://search.naver.com/search.naver'
params = {'query':'빅데이터'}
response = requests.get(URL,params=params)
print(response.status_code)
print(response.text)
# Out:
# 200
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="빅데이터 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'빅데이터'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'빅데이터'의 네이버 통합검색 결과입니다."> <title>빅데이터 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220127.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_220113.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = co ...
#
#   <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
#   <link href="https://ssl.pstatic.net/sstatic/search/sa/211129/css/powerlink.css" rel="stylesheet" type="text/css">
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css">
#   <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head nx_power"><h2>파워링크</h2>
#
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">빅데이터</strong><em
#                 class="dsc_ncaution_quotation">&rsquo;</em></span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#         <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
#
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704" class="link_help">도움말</a></p>
#           <button type="button" class="bt_ad_clse">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=mD6q_GhxoQE-dqwC1rZ2XZ-...">
#       <ul class="lst_type">
#         <li class="lst  type_more type_subtitle ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=MxHebZbJA3qVEFtwkUA6+P///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39;+urlencode(&#39;http://www.cplatform.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTA0MTlfMTcw/MDAxNjE4ODA0OTgxODMw.vxQ4byvwqIDxLiI-FetRJB8gCsnKKA8eHt-ExwBxqZ8g.QB1rqE3Z55JLO9QVs38PVJBPv3DVY3AfEv5MChQ2Nikg.JPEG/1629883-e8dfb93c-b94d-4e9e-83e1-75d81b5a0028.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=Z3zzN9gwetNXDLjGG9n6o////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39; + urlencode(&#39;http://www.cplatform.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">넷스카우트 총판, 씨플랫폼</div>
#               <div class="sub_tit">제품상담 문의환영</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=Z3zzN9gwetNXDLjGG9n6o////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39;+urlencode(&#39;http://www.cplatform.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.cplatform.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               네트워크 및 애플리케이션 성능 분석 모니터링 제품, 디도스 및 APT 방어 솔루션
#
#             </p></div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=0zdcm/7ftqe+zErc0UazGP///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39;+urlencode(&#39;http://www.cplatform.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">성능모니터링</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=I/oyblhYx/D7q8echHFZd////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39;+urlencode(&#39;http://www.cplatform.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));"> 성능분석</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=tlL/BE3+KzqSu66riHybL////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39;+urlencode(&#39;http://www.cplatform.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">AED</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=4IP0Rd07SKRWu9oc5NuYq////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000159394130&amp;d=&#39;+urlencode(&#39;http://www.cplatform.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">디도스</a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle     "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=h/7UdVNlhlnmNMEbXo5XTv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000130177899&amp;d=&#39; + urlencode(&#39;https://cloud.google.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">Google Cloud</div>
#               <div class="sub_tit">Google BigQuery</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=h/7UdVNlhlnmNMEbXo5XTv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000130177899&amp;d=&#39;+urlencode(&#39;https://cloud.google.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">cloud.google.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               사용이 쉬우며 데이터 분석에만 집중할 수 있도록 전반적 관리 제공. 지금 체험.
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=2SSlo7z/6z650pfMb1P2a////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39;+urlencode(&#39;http://www.dreammoa.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMjAyMDhfODUg/MDAxNjQ0MjgzOTUwMjYw.8AA0eSk7aboY2UqshAqkbMGpgmYQaQGMD5rqVBdpgV4g.OJ5hnEI2Qh2XBixidpft4FKzb_T7izsTu7JiJi0hRmMg.JPEG/539985-793c36e3-4a7e-4841-a665-530d5a0efe1a.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=ruJK6+Z6OH/OE+VJ/VZeIf///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39; + urlencode(&#39;http://www.dreammoa.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">컴퓨터공학 1만원 장원사이버</div>
#               <div class="sub_tit">3/3 개강 선착순 마감!</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=ruJK6+Z6OH/OE+VJ/VZeIf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39;+urlencode(&#39;http://www.dreammoa.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.dreammoa.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               3/3개강. 공학 1만원 이벤트! 선착순40명. 온라인으로 빠르고 저렴한 학위취득
#
#             </p></div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=OarwciZMmopnHj3xT+Fl4f///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39;+urlencode(&#39;http://www.dreammoa.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">공학</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=7MCuqx17XXkAt7UQt2bz2P///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39;+urlencode(&#39;http://www.dreammoa.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">사회복지사</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=X9+r9Sml/e08k5l+t19N/f///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39;+urlencode(&#39;http://www.dreammoa.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">픽스딜</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=NVxOnxz/+3oj5sS7r3FL4v///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000169849805&amp;d=&#39;+urlencode(&#39;http://www.dreammoa.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">미용학위</a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="3">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=BvPtFdeTYSKZJNjwDTW0AP///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39;+urlencode(&#39;https://www.coocon.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMDA4MTJfMTI2/MDAxNTk3MjE4MDA0NTQ5.Xz3Mxo3F6xKUawv-aDNL4gSXpgmQug8wcyqiJ3jOWOQg.ape_gmZnNLFyI4iciARGQ4gwC92GTtvLadeafKNGFR4g.PNG/1353065-f1c528bd-1c76-4b24-849f-d161d79d0f0f.png?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=xzceLwcOMT6CVvPk1Qs7g////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39; + urlencode(&#39;https://www.coocon.net&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">국내 최대 API플랫폼,쿠콘</div>
#               <div class="sub_tit">마이데이터 비즈니스 파트너</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=xzceLwcOMT6CVvPk1Qs7g////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39;+urlencode(&#39;https://www.coocon.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.coocon.net</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               마이데이터, 쿠콘과 상의하세요! 200여 종의 오픈API와 간편결제 서비스 제공
#
#             </p></div>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=FuE0XqZIRVEgX/iqKPYLCf///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39;+urlencode(&#39;https://www.coocon.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">마이데이터</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=CSnw8Cz35qCnbSvLiah0Gf///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39;+urlencode(&#39;https://www.coocon.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">활용사례</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=pwdXUFuqnnshsIk6tuDH+////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39;+urlencode(&#39;https://www.coocon.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">고객인터뷰</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=RqhWW8xYONculGBtv9ukjP///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=4&amp;i=nad-a001-01-000000104067411&amp;d=&#39;+urlencode(&#39;https://www.coocon.net&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">회사소개</a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle    type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="4">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=zCua8G5BuV8dca7o9D/VBv///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000161657590&amp;d=&#39;+urlencode(&#39;https://khrdi.modoo.at/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTExMTdfMjMx/MDAxNjM3MTMxNTcyMTAw.-I6IMP6mQRkJ9K0CxkoqLE_32NG1voUIv55oj0RGy-wg.Fb6TDV8eIN66IU8X_Y5Hba0EdMxBgH8uyxQrYnlXVnMg.JPEG/1341361-fe64393f-947b-4986-aa3b-d7a75fb82be8.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=eHuQAsdaI3vtNSxxQ0ZUmv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000161657590&amp;d=&#39; + urlencode(&#39;https://khrdi.modoo.at/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">국비교육 서울디지털인재개발원</div>
#               <div class="sub_tit">청년 IT 공작소</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=eHuQAsdaI3vtNSxxQ0ZUmv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000161657590&amp;d=&#39;+urlencode(&#39;https://khrdi.modoo.at/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">khrdi.modoo.at/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               대기업/IT분야 취업집중대비, K-디지털, 3년 우수기관, 열정만 가지고 오세요
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more     type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="5">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=HDjwcC80G7aRtQm211uNW////w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000167683680&amp;d=&#39;+urlencode(&#39;http://www.human.or.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTA5MjNfNzkg/MDAxNjMyMzg2NTkyMzMw.NQlyQ-lmluoCRV6_jWWJogrYcd69y0hWLjYz6l6ftXQg.gQ2uay3lBoK440wQ2RVLDcRC5G1p38OSimnpPt069dQg.JPEG/2359412-b399f8e4-674c-46a5-b104-9f41389030de.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=qu5Pz6NQD4uJJAzc/BXVLv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000167683680&amp;d=&#39; + urlencode(&#39;http://www.human.or.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">100%무료교육 휴먼교육센터</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=qu5Pz6NQD4uJJAzc/BXVLv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000167683680&amp;d=&#39;+urlencode(&#39;http://www.human.or.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.human.or.kr/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               3년우수기관 K-DIGITAL선정기관,자바,파이썬,<strong class='hl'>빅데이터</strong>와AI,무료교육
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle    type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="6">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=EZMiwqNC/V92anSfC4Dwiv///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=7&amp;i=nad-a001-01-000000142406086&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDdfMjgy/MDAxNTUxOTM2MDY0NTU2.FjwQIJIffEpRVFxkKfsX8ZkFqRAFA77Kn1MAzB3OoHYg.mvX2GE-aldtCDVYLoZIatyhk-mrZTc0YEPIuRAyyhbUg.JPEG/699114-6d89b46c-8f64-4320-94b2-49480d718570.jpg?type=f120_120" width="70">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=4+vuuUXoYDoL8khU4QGhmv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000142406086&amp;d=&#39; + urlencode(&#39;http://www.greenart.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">그린컴퓨터아트학원공식홈페이지</div>
#               <div class="sub_tit">고용노동부지정 우수훈련기관</div>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin" tabindex="0"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=7&amp;i=nad-a001-01-000000142406086&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                   </a>
#                 </span>
#
#
#               </span>
#               <a href="https://adcr.naver.com/adcr?x=4+vuuUXoYDoL8khU4QGhmv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000142406086&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.greenart.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               전국24개지점, 고용노동부 우수훈련기관, 국비100%무료, 디자인IT <strong class='hl'>빅데이터</strong>
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst type_line       "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="7">
#           <div class="line"></div>
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=zHHhagkC4G8YfwOMJnbde////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000165245445&amp;d=&#39; + urlencode(&#39;http://gangnam.greenart.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">그린컴퓨터아카데미 강남캠퍼스</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=zHHhagkC4G8YfwOMJnbde////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000165245445&amp;d=&#39;+urlencode(&#39;http://gangnam.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">gangnam.greenart.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               취준생&직장인 국비100%무료지원, 1:1취업지원, 디자인IT 실무교육 <strong class='hl'>빅데이터</strong>
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst        "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="8">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=5xSeASOBdjs3TITIaawjcv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000168880746&amp;d=&#39; + urlencode(&#39;http://codestates.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">코드스테이츠의 AI 부트캠프</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=5xSeASOBdjs3TITIaawjcv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000168880746&amp;d=&#39;+urlencode(&#39;http://codestates.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">codestates.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               7개월과정 완강률86%, 학습 매니저 케어서비스, 데이터 사이언티스트로의 첫걸음
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst        "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="9">
#
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=/oKdDCBf3slXmxfZ8FKzF////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000139962859&amp;d=&#39; + urlencode(&#39;http://www.choongang.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">52년 역사 중앙정보처리학원</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=/oKdDCBf3slXmxfZ8FKzF////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000139962859&amp;d=&#39;+urlencode(&#39;http://www.choongang.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.choongang.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               Since1969 고용노동부 최우수 훈련기관 선정! 전액 국비지원 IT취업연계교육
#
#             </p></div>
#
#
#
#
#
#           </div>
#         </li>
#       </ul>
#       <div class="section_more">
#         <a class="go_site"
#            target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&amp;referenceId=hl4ESlprvmsssBTR31sssssssBw-138339" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">
#           더보기<i class="icon_arrow sp_ad"></i></a>
#       </div>
#     </div>
#
#
#   </div>
#
#
#
#   <section class="sc_new sp_ntotal _kin_snippet_root_ksn_kdc _prs_ksn_kdc"> <div class="api_subject_bx type_noline"> <ul class="lst_total"> <li class="bx"> <div class="bx_snippet"> <div class="_panel_wrap"> <div class="snippet_inner _panel"> <div class="kin_snippet"> <div class="snippet_dsc api_ani_send"> <a target="_blank" href="https://terms.naver.com/entry.naver?docId=1691554&cid=42171&categoryId=42183" class="thumb_single" onclick="goOtherCR(this,'a=ksn_kdc*s.img&r=1&i=08127052_0003a418fbb6&u='+urlencode(this.href));"> <img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F2157_000_1%2F20121212122253571_4YGYQH5NZ.jpg%2Fm70_03_i1.jpg%3Ftype%3Dw450_fst_n%23450x336%23c336&type=f348_240" width="174" height="120" alt="" class="api_get img" onerror="this.src='...';this.className='img bg_nimg2';this.alt='이미지준비중';"> </a> <a target="_blank" href="https://terms.naver.com/entry.naver?docId=1691554&cid=42171&categoryId=42183" class="dsc_area type_single" onclick="goOtherCR(this,'a=ksn_kdc*s.link&r=1&i=08127052_0003a418fbb6&u='+urlencode(this.href));"> <div class="api_txt_lines dsc_txt"> <mark>빅데이터</mark>란 디지털 환경에서 생성되는 <mark>데이터</mark>로 그 규모가 방대하고, 생성 주기도 짧고, 형태도 수치 <mark>데이터</mark>뿐 아니라 문자와 영상 <mark>데이터</mark>를 포함하는 대규모 <mark>데이터</mark>를 말한다. <mark>빅데이터</mark> 환경은 과거에 비해 <mark>데이터</mark>의 양이 폭증했다는 점과 함께 <mark>데이터</mark>의 종류도 다양해져 사람들의 행동은 물론 위치정보와 SNS를 통해 생각과 의견까지 분석하고 예측할 수 있다. </div> </a> </div> </div> <div class="total_wrap"> <div class="api_save_group _keep_wrap"> <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://terms.naver.com/entry.naver?docId=1691554&cid=42171&categoryId=42183" onclick="tCR('a=ksn_kdc*s.kep&r=&i=&u=javascript');"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=ksn_kdc*s.kepon" data-cr-off="a=ksn_kdc*s.kepoff">Keep에 저장</a> <a target="_blank" href="https://keep.naver.com/" class="spnew_af item item_quick" onclick="goOtherCR(this,'a=ksn_kdc*s.kephome&r=1&i=08127052_0003a418fbb6&u='+urlencode(this.href));">Keep 바로가기</a> </div> </div> <div class="total_tit_group"> <div class="total_source"> <div class="source_box"> <a target="_blank" href="https://terms.naver.com/entry.naver?docId=1691554&cid=42171&categoryId=42183" class="txt elss" onclick="goOtherCR(this,'a=ksn_kdc*s.link&r=1&i=08127052_0003a418fbb6&u='+urlencode(this.href));">빅데이터 terms.naver.com</a> </div> </div> <div class="total_tit"> <div class="badge_wrap"><span class="badge_kindic">지식백과</span></div> <a target="_blank" href="https://terms.naver.com/entry.naver?docId=1691554&cid=42171&categoryId=42183" class="link_tit" onclick="goOtherCR(this,'a=ksn_kdc*s.link&r=1&i=08127052_0003a418fbb6&u='+urlencode(this.href));"><mark>빅데이터</mark> 정의</a> </div> </div> </div> </div> </div> </div> <div class="kin_snippet_info _info_layer_wrap"> <span class="dsc"><a href="https://help.naver.com/support/alias/search/integration/intergration_90.naver" class="link" onclick="goOtherCR(this,'a=ksn_kdc*s.err&r=&i=&u='+urlencode(this.href));">정보오류 수정요청</a></span> <strong class="tit"><i class="spnew ico_kin_snippet">지식스니펫</i><a role="button" href="#" class="btn_help _trigger" onclick="tCR('a=ksn_kdc*s.iopen&r=&i=&u=javascript');"><i class="spnew api_ico_alert">이 정보가 표시된 이유</i></a></strong> <div class="ly_api_info _content"> <p class="dsc">네이버 AI 기반 분석 알고리즘을 적용하여 찾고자 하<br>시는 정보에 근접한 텍스트를 자동으로 추출하였습<br>니다.</p> <div class="btn_area"> <a target="_blank" href="https://help.naver.com/support/alias/search/integration/intergration_90.naver" class="link" onclick="goOtherCR(this,'a=ksn_kdc*s.help&r=&i=&u='+urlencode(this.href));">네이버 고객센터</a> </div> <button type="button" class="btn_close _close" onclick="tCR('a=ksn_kdc*s.iclose&r=&i=&u=javascript');"><i class="spnew ico_close">정보확인 레이어 닫기</i></button> </div> </div> </li> </ul> </div> </section> <script> (function() { /* Controller.js의 경로 지정. */ var jsControllerUr ...
#
#
#
#  <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <script type=text/javascript>var g_uad = false; </script><link href="https://ssl.pstatic.net/sstatic/keypage/outside/scui/custom_list/css/cs_custom_list_210311.css" type="text/css" rel="stylesheet" /> <section class="sc_new cs_custom_list _open_course" data-dss-logarea="xd5"> <div class="api_subject_bx"> <div class="api_title_area"> <h2 class="api_title">온라인 공개 강좌</h2> </div> <div class="api_cs_wrap"> <div class="list_bx"> <div class="info_select2"> <div class="select_box _select_wrap"> <a nocr href="#" class="btn_select _trigger" role="button" aria-expanded="false"><span class="_text" data-default-text="추천순">추천순</span><span class="ico_select"></span></a> <div class="list_select _root" aria-hidden="true"> <div class="_list_root"> <ul role="listbox" class="_ul"> <li class="_li" data-value="u3=recommend" role="option" aria-selected="true"> <a nocr onclick="goOtherTCR(this, 'a=nco_xd5*1.sortrec&r=1&i=8818439b_000000000000');return false;" href="#">추천순</a> </li> <li class="_li" data-value="u3=date" role="option" aria-selected="false"> <a nocr onclick="goOtherTCR(this, 'a=nco_xd5*1.sortlat&r=1&i=8818439b_000000000000');return false;" href="#">최신순</a> </li> <li class="_li" data-value="u3=student" role="option" aria-selected="false"> <a nocr onclick="goOtherTCR(this, 'a=nco_xd5*1.sortstu&r=1&i=8818439b_000000000000');return false;" href="#">수강생 많은 순</a> </li> <li class="_li" data-value="u3=view" role="option" aria-selected="false"> <a nocr onclick="goOtherTCR(this, 'a=nco_xd5*1.sortpv&r=1&i=8818439b_000000000000');return false;" href="#">조회수순</a> </li> <li class="_li" data-value="u3=lecture" role="option" aria-selected="false"> <a nocr onclick="goOtherTCR(this, 'a=nco_xd5*1.sortlec&r=1&i=8818439b_000000000000');return false;" href="#">강의수순</a> </li> </ul> </div> </div> </div> </div> <div class="info_list"> <div class="_panel"> <div class="info_box_v2"> <div class="spot_box _list"> <div class="box_inner _item" data-cr-area="blg" data-index="0"> <div class="thumb _content"> <a nocr href="javascript:;" class="_trigger" data-auto-play="true" data-is-visible-close-btn="true" data-real-url="https://www.edwith.org/terrydltalks" data-service-name="edwith" data-date="2020.04.07." data-title="3분에 익히는 머신러닝의 기본 원리" data-play-time="02:12" data-source="naver" data-video-id="4A2E356EC67E42F937E61AA449B381727440" data-in-key="V123bde26bd84cb5fb985a1f9c4b3f1cb39962b0bfe807c08cee31027e2966a05ae08a1f9c4b3f1cb3996" data-service-id="3036" > <img src="https://search.pstatic.net/common?type=ofullfill&size=520x292&fillColor=FFFFFF&quality=100&direct=true&src=https%3A%2F%2Fcphinf.pstatic.net%2Fmooc%2F20200407_71%2F1586232161698FeBAG_JPEG%2Fmax-langelott-wWQ760meyWI-unsplash.jpg" onerror="this.parentNode.parentNode.style.display='none';" width="260" height="146" alt="3분에 익히는 머신러닝의 기본 원리" /> <span class="img_bd"></span><span class="ico_play"></span> </a> </div> <div class="info_text"> <div class="scm_ellipsis _ellipsis"> <strong> <a nocr onclick="return  ...
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
#   <div class="ad_section section _bz_section bg_type_v2">
#     <div class="section_head"><h2>비즈사이트</h2>
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em>
#           <strong class="dsc_ncaution_keyword">빅데이터</strong>
#           <em class="dsc_ncaution_quotation">&rsquo;</em>
#         </span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowBz(this)) goOtherCR(this, &#39;a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#         <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
#           <button type="button" class="bt_ad_clse" title="안내 레이어 닫기">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space"
#          target="_blank" onclick="return goOtherCR(this, &#39;a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
#       <ul class="lst_type ">
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=2u2KFCcqNA0Rs1QzrWmmw////w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000169491239&amp;d=&#39; + urlencode(&#39;http://business.crowdworks.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">AI라벨링 전문 크라우드웍스</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=2u2KFCcqNA0Rs1QzrWmmw////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000169491239&amp;d=&#39;+urlencode(&#39;http://business.crowdworks.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">business.crowdworks.kr/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               국내 최대 32만 작업자 보유. 100% 전수검수 통한 99% 데이터 정확도 보장
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=Z2OgJSmkBuG31DJvzV/Tmf///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000155452384&amp;d=&#39; + urlencode(&#39;https://www.bsgglobal.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">BSG PARTNERS</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=Z2OgJSmkBuG31DJvzV/Tmf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000155452384&amp;d=&#39;+urlencode(&#39;https://www.bsgglobal.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.bsgglobal.com</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               SAP플래티넘&AWS어드밴스드 파트너,SAPonAWS,엔터프라이즈 클라우드 서비스
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=/h6I8n7jFfUQnL8WgKuJLf///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000168487319&amp;d=&#39; + urlencode(&#39;http://www.codeit.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">코드잇 빅데이터</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_ad ico_nlogin"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn"
#                      class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=biz_nop.naverlogin&amp;r=3&amp;i=nad-a001-01-000000168487319&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <p>네이버 아이디로 로그인이 가능합니다.</p>
#                       <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
#                     </span>
#                   </a>
#                 </span>
#
#
#               </span>
#               <a href="https://adcr.naver.com/adcr?x=/h6I8n7jFfUQnL8WgKuJLf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000168487319&amp;d=&#39;+urlencode(&#39;http://www.codeit.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.codeit.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               데이터분석 실무에 꼭 쓰이는 내용부터 다양한 연습문제까지! 하루 10분으로 마스터
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="3">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=kiFNx8Ohk0nb37+eOZNok////w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000168402291&amp;d=&#39; + urlencode(&#39;http://spss.datasolution.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">통계SW SPSS데이타솔루션</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=kiFNx8Ohk0nb37+eOZNok////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000168402291&amp;d=&#39;+urlencode(&#39;http://spss.datasolution.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">spss.datasolution.kr/</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               KoreaPlus statistics, SPSS 확장패키지, IBMSPSS.
#
#             </p></div>
#
#           </div>
#         </li>
#         <li class="lst"
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="4">
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=pqgH0C4Ozd53HJHs0qWfXv///w==...&amp;p=0" target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000063678901&amp;d=&#39; + urlencode(&#39;http://www.e2d2.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#               <div class="lnk_tit">이든티앤에스 E2D2</div>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=pqgH0C4Ozd53HJHs0qWfXv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000063678901&amp;d=&#39;+urlencode(&#39;http://www.e2d2.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.e2d2.co.kr</a>
#             </div>
#             <div class="ad_dsc"><p class="ad_dsc_inner">
#               E2D2, 지능형 독립 데이터 센터 솔루션, 설치 구성 최적화, 통합구축 비용절감
#
#             </p></div>
#
#           </div>
#         </li>
#       </ul>
#       <div class="section_more">
#         <a class="go_site"
#            target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&amp;referenceId=hl4ESlprvmsssBTR31sssssssBw-138339" onclick="return goOtherCR(this, &#39;a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u=&#39;+urlencode(this.href));">
#           더보기<i class="icon_arrow sp_ad"></i></a>
#       </div>
#     </div>
#
#
#   </div>
#
#   <div class="api_sc_page_wrap"> <div class="sc_page"> <a role="button" class="btn_prev" aria-disabled="true"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a href="?query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&sm=tab_pge&where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&r=1&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="true">1</a> <a href="?display=15&f=&filetype=0&page=2&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=1&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=2&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">2</a> <a href="?display=15&f=&filetype=0&page=3&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=16&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=3&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">3</a> <a href="?display=15&f=&filetype=0&page=4&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=31&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=4&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">4</a> <a href="?display=15&f=&filetype=0&page=5&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=46&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=5&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">5</a> <a href="?display=15&f=&filetype=0&page=6&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=61&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=6&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">6</a> <a href="?display=15&f=&filetype=0&page=7&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=76&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=7&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">7</a> <a href="?display=15&f=&filetype=0&page=8&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=91&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=8&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">8</a> <a href="?display=15&f=&filetype=0&page=9&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=106&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=9&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">9</a> <a href="?display=15&f=&filetype=0&page=10&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=121&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=10&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">10</a> </div> <a href="?display=15&f=&filetype=0&page=11&query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&research_url=&sm=tab_pge&start=1&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=11&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn_next" aria-disabled="false"><i class="spnew ico_page_arr">다음</i></a> </div> </div> </div><div id="sub_pack" class="sub_pack"><section class="sc_new sp_nkeyword" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a href="https://help.naver.com/support/alias/search/word/word_1.naver" class="api_link_help" onclick="return goOtherCR(this, 'a=rsk_top.guide&r=&i=&u='+urlencode(urlexpand(this.href)));" target="_blank"><i class="spnew api_ico_help">도움말</i></a></h2> <div class="api_title_sub"> <a href="https://help.naver.com/support/alias/search/word/word_2.naver" class="btn_report" onclick="return goOtherCR(this, 'a=rsk_top.report&r=&i=&u= ...

# %%
# 파라미터를 두 개 이상 사용하여 정보 요청 가능(특정날짜의 네이버 웹툰)
# https://comic.naver.com/webtoon/detail?titleId=785703&no=9&weekday=tue
import requests
URL = 'https://comic.naver.com/webtoon/detail'
params = {'titledId':785703, 'no':9, 'weekday':'tue'}
response = requests.get(URL,params=params)
print(response.status_code)
print(response.text)
# Out:
# 200
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
#
#
#
#
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#
# 	<meta http-equiv="Content-type" content="text/html; charset=UTF-8">
# 	<title>네이버 웹툰</title>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <meta property="og:title" content="네이버 웹툰" >
#         <meta property="og:image" content="https://ssl.pstatic.net/static/comic/images/og_tag_v2.png" >
#         <meta property="og:description" content="매일매일 새로운 재미, 네이버 웹툰.">
#
#
#
# <meta property="og:url" content="https://comic.naver.com/main" >
# <meta property="og:type" content="article" >
# <meta property="og:article:author" content="네이버 웹툰" >
# <meta property="og:article:author:url" content="https://comic.naver.com" >
#
# 	<link rel="shortcut icon" href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" type="image/x-icon">
#
# 	<script type="text/javascript">function windowOpen(url){location.href = url;}function goArtistTitle(element, area, titleId, index, event) {nclk_v2(event,area,'',index);return artistAction.viewArtist(titleId, element);}</script>
# 	<script type="text/javascript">
#         var g_ssc = "comic.home";
#         var ccsrv = "cc.naver.com";
# 	</script>
#
#
# 			<script type="text/javascript" src="/aggregate/javascript/release/comic_main_20220714182726.js"></script>
#
#
#
#
# 		<link rel="stylesheet" style="text/css" href="/css/comic/comic_20220714182726.css">
#
# 		<script type="text/javascript" src="/aggregate/javascript/release/comic_gnb_20220714182726.js"></script>
#
# </head>
#
#
#
#
#
#
#
#
#
#
# <body onload="">
#
#
#
#
#
#
# 	<div id="wrap"  class="end_page"    >
#
#
#
#
#
# 				<div id="u_skip">
# 					<a href="#menu" onclick="document.getElementById('menu').tabIndex=-1;document.getElementById('menu').focus();return false;"><span>메인 메뉴로 바로가기</span></a>
# 					<a href="#content" onclick="document.getElementById('content').tabIndex=-1;document.getElementById('content').focus();return false;"><span>본문으로 바로가기</span></a>
# 				</div>
#
#
# 		<div id="header_wrap">
# 			<div id="header">
#
#
#
#
# <div id="gnb">
#     <script type="text/javascript">
#         var gnb_option = {
#             gnb_service : "comic",
#             gnb_logout :  encodeURIComponent(window.location.href),
#             gnb_login :   encodeURIComponent(window.location.href),
#             gnb_template : "gnb_utf8",
#             gnb_brightness : 1,
#             gnb_item_hide_option: 0
#         };
#     </script>
#     <script type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8?20220714182726"></script>
# </div>
# <div id="snb_wrap">
#     <h1>
#         <a onclick="nclk_v2(event,'STA.naverlogo')" href="https://www.naver.com" title="NAVER" class="gnb_naver">NAVER</a>
#         <a onclick="nclk_v2(event,'STA.comic')" href="/index" title="웹툰" class="gnb_comic">웹툰</a>
#         <em class="bar">|</em>
#         <a onclick="nclk_v2(event,'STA.novel')" href="https://novel.naver.com" title="웹소설" class="gnb_novel">웹소설</a>
#
#         <em class="bar">|</em>
#         <a onclick="nclk_v2(event,'STA.series')" href="https://series.naver.com" title="시리즈" class="gnb_series">시리즈</a>
#
#     </h1>
#
#
#     <form id="searchForm" name="search" method="get" action="/search">
#         <fieldset>
#             <legend>검색</legend>
#             <div class="snb_search_box">
#
#
#
#
#
#
#
#
#
#                 <!-- [D] 클릭시 label.ph 텍스트 삭제해주세요. -->
#                 <label class="ph" for="gnb.keyword">제목 / 작가로 검색할 수 있습니다.</label>
#                 <input type="text" id="gnb.keyword" name="keyword" value="" title="검색어 입력" maxlength="18" class="snb_search_text">
#                 <button type="button" class="btn_search" id="search_bar_button" onclick="nclk_v2(event,'STA.search')" title="검색" alt="검색"><span class="Nico_search">검색</span></button>
#             </div>
#         </fieldset>
#     </form>
#
# </div>
#
#
# 				<div id="author_layer" style="text-align:left; display:none;">
# 					<ul id="author_layer_inner">&nbsp;</ul>
# 				</div>
#
#
#
#
#
# 					<div class="notice_info">
# 						<span class="blind">공지사항</span>
# 						<div class="rolling">
#
#
# 							<div class="notice_rolling">
# 								<li>
# 									<a onclick="nclk_v2(event,'STA.txt')" href="https://comic.naver.com/webtoon/list.nhn?titleId=797443" title="평범한 회사 생활 가능? &lt;운명을 보는 회사원&gt;">
# 										<span class="Nico_notice"></span>
# 										평범한 회사 생활 가능? &lt;운명을 보는 회사원&gt;
# 									</a>
# 								</li>
# 							</div>
# 						</div>
# 					</div>
#
# 			</div>
# 			<div id="menu">
# 				<ul class="menu">
# 					<!-- [D] 선택된 li에 current 클래스 추가 -->
# 					<li class="current"><a onclick="nclk_v2(event,'LNB.home');" href="/index"><span class="Ntxt_home">웹툰 홈</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.toon');" href="/webtoon/weekday"><span class="Ntxt_webtoon">웹툰</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.best');" href="/genre/bestChallenge"><span class="Ntxt_best_challenge">베스트 도전</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.chal');" href="/genre/challenge"><span class="Ntxt_challenge_comic">도전만화</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'LNB.my');" href="/mypage/favorite"><span class="Ntxt_mypage">마이페이지</span></a></li>
# 				</ul>
# 				<h2 class="blind">웹툰 홈</h2>
# 			</div>
# 			<!-- //상단 메뉴 /main-->
#
# 		</div>
# 		<!-- 상단 영역(메인에만 나감.) -->
#
#
#
#
#
#
#
#
# <div class="mainTopArea">
# 	<div class="main_spot" id="mainNavi">
# 		<div class="data_area">
# 			<h2 class="Ntxt_today_webtoon">오늘의 웹툰</h2>
# 			<p class="date" id="curDate"></p>
# 			<!-- [D] 클릭된 이미지 a에 class="sel" 추가 -->
# 			<ul id="listMenu">
# 				<li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byuser')"><span class="Ntxt_popular">인기순</span></a></li>
# 				<li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byupdate')"><span class="Ntxt_update">업데이트순</span></a></li>
# 				<li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byview')"><span class="Ntxt_count">조회순</span></a></li>
# 				<li><a href="javascript:void(0);" onclick="nclk_v2(event,'twt.byscore')"><span class="Ntxt_star_rate">별점순</span></a></li>
# 			</ul>
# 		</div>
# 		<h3 id="mainTopAreaBlindOrder" class="blind"></h3>
# 		<div class="webtoon_area">
# 			<div class="bigimg">
# 				<a href="javascript:void(0)" onclick="nclk_v2(event,'twt.main')" class="_bigImgLink">
# 					<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif" width="582" height="195" alt="static_img_comic" class="_bigImg">
# 					<span class="bd"></span>
# 					<span class="mark_adult_big" id="ageRateBig" style="display: none">18세 이상 이용 가능</span>
# 				</a>
# 			</div>
# 			<div class="webtoon_lst">
# 				<div class="lst_area">
# 					<ul id="comicList"></ul>
# 				</div>
# 				<!-- [D] 클릭된 화살이미지 span에 class="sel" 추가 -->
# 				<a href="javascript:void(0)" onclick="nclk_v2(event,'twt.prev')" class="btn_prev"><span class="btn_prev_arr">이전</span></a>
# 				<a href="javascript:void(0)" onclick="nclk_v2(event,'twt.next')" class="btn_next"><span class="btn_next_arr">다음</span></a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<script type="text/javascript">
# 		var ts = new nts.Comic.MainNavi();
# 	</script>
#
#
#
#
#
#
# 	<div class="todayChallenge">
#
#
#
# 			<h4 class="Ntxt_new_best">새로운 베스트 도전만화</h4>
#
#
# 		<p class="best_photo">
# 			<a onclick="nclk_v2(event,'new.thum','796271')" href="/bestChallenge/list?titleId=796271">
# 				<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/06/15/thumbnail_218x120330bedae_4000_4fc6_b999_d54f1e8f34aa_00003547.JPEG" width="202" height="110" alt="페이탈 레시피">
# 				<span class="mask"></span>
# 			</a>
# 		</p>
# 		<dl>
# 			<!-- [D] 제목부분: 공백포함 10자 이상 초과시 말줄임 표시 해주세요.  아이디 부분: 공백포함 7자 이상 초과시 말줄임 표시 해주세요. -->
# 			<!-- [D] IE 스펙의 이슈로 글자 수가 아닌 width로 말줄임 자동 표시. -->
# 			<dt>
# 				<a onclick="nclk_v2(event,'new.title','796271')" href="/bestChallenge/list?titleId=796271" class="challenge_title">
# 					페이탈 레시피
# 				</a>
# 				<span>
# 					<a onclick="nclk_v2(event,'new.author'); return artistAction.viewArtist(796271, this);" href="#" class="challenge_id">
# 						tige****
# 					</a>
# 				</span>
# 			</dt>
# 			<!-- [D] 세줄 초과시 말줄임 표시 해주세요.-->
# 			<dd class="ellipsis_content" style="height: 54px;">
# 				<a onclick="nclk_v2(event,'new.text','796271')" href="/bestChallenge/list?titleId=796271">
#
#
# 					카사노바는 여성을 유혹하기 위해 요리책을 만들 정도로 미식에 관심이 많았다.인간이 거부할 수 없는 욕구중 하나인 식욕. 선의 약속으로 포장된 미식의 세계! 허나 그 약속이 깨진다면? 훌륭한 요리는 우리의 오감을 장악한다. 헌데 그 음식을 스토커가 만들었고 오직 스토커만이 만들 수 있다면 이야기는 달라진다. 힐링과 킬링의 경계를 주무르는 스토커 셰프의 스토킹 이야기.
#
# 				</a>
# 			</dd>
# 		</dl>
# 	</div>
#
# </div>
#
# <script type="text/javascript">
# 	(function ellipsis() {
# 		var wel = $Element($$.getSingle("dd.ellipsis_content a"));
# 		var sParent = $Element($$.getSingle("dd.ellipsis_content"));
#
# 		if (!wel || !sParent) {
# 			return;
# 		}
#
# 		var sText = wel.text();
# 		var sLength = sText.length;
#
# 		for(var count = 1; count <= sLength; count++) {
# 			if (wel.height() > sParent.height()) {
# 				var cutText = sText.slice(0, count * (-1));
# 				wel.text(cutText + ' . . .');
# 			} else {
# 				break;
# 			}
# 		}
# 	})();
# </script>
#
#
# 		<!-- //상단 영역 -->
#
# 		<div id="container" class="">
#
#
#
#
#
#
# 			<div id="content" class="">
#
#
#
#
#
# 				<!-- body -->
# 				<div class="ad_banner_premium" data-ad-banner="premium_banner"></div>
#
#
# 		<!-- 장르별 추천 웹툰 -->
# 		<div class="genreRecomBox">
# 			<h3 class="titleMain">
# 				<a onclick="nclk_v2(event,'rtb.more')" href="#" id="moreGenre"><span class="Ntxt_genre_webtoon">장르별 추천웹툰</span></a>
# 			</h3>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<div class="tab_gr">
# 				<ul>
# 					<!-- [D] 선택된 li에 on 클래스 추가 -->
# 					<li ><a href="#" id="episode" title="에피소드">에피소드</a></li>
# 					<li ><a href="#" id="omnibus" title="옴니버스">옴니버스</a></li>
# 					<li class="on"><a href="#" id="story" title="스토리">스토리</a>
# 						<span class="bar"></span>
# 					</li>
# 					<li ><a href="#" id="daily" title="일상">일상</a></li>
# 					<li ><a href="#" id="comic" title="개그">개그</a></li>
# 					<li ><a href="#" id="fantasy" title="판타지">판타지</a></li>
# 					<li ><a href="#" id="action" title="액션">액션</a></li>
# 					<li ><a href="#" id="drama" title="드라마">드라마</a></li>
# 					<li ><a href="#" id="pure" title="순정">순정</a></li>
# 					<li ><a href="#" id="sensibility" title="감성">감성</a></li>
# 					<li ><a href="#" id="thrill" title="스릴러">스릴러</a></li>
# 					<li ><a href="#" id="historical" title="무협/사극">무협/사극</a></li>
# 					<li ><a href="#" id="sports" title="스포츠">스포츠</a></li>
# 				</ul>
# 			</div>
#
# 			<div class="view_type">
# 				<ul class="sortby">
# 					<li ><a onclick="nclk_v2(event,'rtb.byuser')" href="#" id="User"><span class="Ntxt_popular">인기순</span></a></li>
# 					<li class="sel"><a onclick="nclk_v2(event,'rtb.upd')" href="#" id="Update"><span class="Ntxt_update">업데이트순</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'rtb.cnt')" href="#" id="ViewCount"><span class="Ntxt_count">조회순</span></a></li>
# 					<li ><a onclick="nclk_v2(event,'rtb.sta')" href="#" id="StarScore"><span class="Ntxt_star_rate">별점순</span></a></li>
# 				</ul>
# 			</div>
# 			<h3 id="mainGenreBlind" class="blind">스토리 - 업데이트순</h3>
# 			<ul id="genreRecommand" class="genreRecom">
#
#
#
#
#
#
#
#
#
# 				<li>
# 					<div class="genreRecomImg2">
# 						<a onclick="nclk_v2(event,'rcn*s.thum','789645','1')" href="/webtoon/list?titleId=789645">
# 							<span class="mask"></span>
# 							<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 								 src="https://shared-comic.pstatic.net/thumb/webtoon/789645/thumbnail/thumbnail_IMAG04_f1a90fc3-e4cb-4bf1-9d5c-9695693cd018.jpg"
# 								 width="218" height="120" title="시간과 사연" alt="시간과 사연">
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo2">
# 						<h6 class="title">
# 							<span class="ico_break"	style="display:none;">휴재</span>
# 							<span class="ico_cut"	style="display:none;">컷툰</span>
# 							<span class="ico_short_ani"	style="display:none;">숏애니</span>
#
# 							<a onclick="nclk_v2(event,'rcn*s.title','789645','1')" href="/webtoon/list?titleId=789645">
# 								<span>시간과 사연</span>
# 							</a>
# 						</h6>
# 						<p>
# 							<a onclick="nclk_v2(event,'rcn*s.sub','789645','1')" href="/webtoon/detail?titleId=789645&no=4">
# 								<span>4화</span>
# 							</a>
# 						</p>
# 						<span class="user">
# 							<a href="#" onclick="return goArtist('789645', '1', this, event);">
# 								콜라베어
# 							</a>
# 						</span>
# 					</div>
# 				</li>
#
#
#
#
#
#
#
#
#
# 				<li>
# 					<div class="genreRecomImg2">
# 						<a onclick="nclk_v2(event,'rcn*s.thum','784822','2')" href="/webtoon/list?titleId=784822">
# 							<span class="mask"></span>
# 							<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 								 src="https://shared-comic.pstatic.net/thumb/webtoon/784822/thumbnail/thumbnail_IMAG04_4ddce86d-30ee-42ea-a37d-2934f450b80f.jpg"
# 								 width="218" height="120" title="한여름, 밤의 꿈" alt="한여름, 밤의 꿈">
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo2">
# 						<h6 class="title">
# 							<span class="ico_break"	style="display:none;">휴재</span>
# 							<span class="ico_cut"	style="display:none;">컷툰</span>
# 							<span class="ico_short_ani"	style="display:none;">숏애니</span>
#
# 							<a onclick="nclk_v2(event,'rcn*s.title','784822','2')" href="/webtoon/list?titleId=784822">
# 								<span>한여름, 밤의 꿈</span>
# 							</a>
# 						</h6>
# 						<p>
# 							<a onclick="nclk_v2(event,'rcn*s.sub','784822','2')" href="/webtoon/detail?titleId=784822&no=3">
# 								<span>3화 수국(3)</span>
# 							</a>
# 						</p>
# 						<span class="user">
# 							<a href="#" onclick="return goArtist('784822', '2', this, event);">
# 								김수박 / 칸
# 							</a>
# 						</span>
# 					</div>
# 				</li>
#
#
#
#
#
#
#
#
#
# 				<li>
# 					<div class="genreRecomImg2">
# 						<a onclick="nclk_v2(event,'rcn*s.thum','784841','3')" href="/webtoon/list?titleId=784841">
# 							<span class="mask"></span>
# 							<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 								 src="https://shared-comic.pstatic.net/thumb/webtoon/784841/thumbnail/thumbnail_IMAG04_407a51e9-6af9-4706-9317-a40d326e4605.jpg"
# 								 width="218" height="120" title="최종보스 공대장" alt="최종보스 공대장">
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo2">
# 						<h6 class="title">
# 							<span class="ico_break"	style="display:none;">휴재</span>
# 							<span class="ico_cut"	style="display:none;">컷툰</span>
# 							<span class="ico_short_ani"	style="display:none;">숏애니</span>
#
# 							<a onclick="nclk_v2(event,'rcn*s.title','784841','3')" href="/webtoon/list?titleId=784841">
# 								<span>최종보스 공대장</span>
# 							</a>
# 						</h6>
# 						<p>
# 							<a onclick="nclk_v2(event,'rcn*s.sub','784841','3')" href="/webtoon/detail?titleId=784841&no=4">
# 								<span>4화</span>
# 							</a>
# 						</p>
# 						<span class="user">
# 							<a href="#" onclick="return goArtist('784841', '3', this, event);">
# 								김장훈 / 박수봉, 하성신
# 							</a>
# 						</span>
# 					</div>
# 				</li>
#
#
#
#
#
#
#
#
#
# 				<li>
# 					<div class="genreRecomImg2">
# 						<a onclick="nclk_v2(event,'rcn*s.thum','784850','4')" href="/webtoon/list?titleId=784850">
# 							<span class="mask"></span>
# 							<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 								 src="https://shared-comic.pstatic.net/thumb/webtoon/784850/thumbnail/thumbnail_IMAG04_9461bb13-eb0a-4c5c-8a5e-5b9c61477196.jpg"
# 								 width="218" height="120" title="버티면 10억" alt="버티면 10억">
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo2">
# 						<h6 class="title">
# 							<span class="ico_break"	style="display:none;">휴재</span>
# 							<span class="ico_cut"	style="display:none;">컷툰</span>
# 							<span class="ico_short_ani"	style="display:none;">숏애니</span>
#
# 							<a onclick="nclk_v2(event,'rcn*s.title','784850','4')" href="/webtoon/list?titleId=784850">
# 								<span>버티면 10억</span>
# 							</a>
# 						</h6>
# 						<p>
# 							<a onclick="nclk_v2(event,'rcn*s.sub','784850','4')" href="/webtoon/detail?titleId=784850&no=3">
# 								<span>3화</span>
# 							</a>
# 						</p>
# 						<span class="user">
# 							<a href="#" onclick="return goArtist('784850', '4', this, event);">
# 								만화인간
# 							</a>
# 						</span>
# 					</div>
# 				</li>
#
#
#
#
#
#
#
#
#
# 				<li>
# 					<div class="genreRecomImg2">
# 						<a onclick="nclk_v2(event,'rcn*s.thum','784852','5')" href="/webtoon/list?titleId=784852">
# 							<span class="mask"></span>
# 							<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 								 src="https://shared-comic.pstatic.net/thumb/webtoon/784852/thumbnail/thumbnail_IMAG04_72b75f6f-8448-4a75-b8b2-ee7d1f7aed30.jpg"
# 								 width="218" height="120" title="어메이징 스파이더맨" alt="어메이징 스파이더맨">
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo2">
# 						<h6 class="title">
# 							<span class="ico_break"	style="display:none;">휴재</span>
# 							<span class="ico_cut"	style="display:none;">컷툰</span>
# 							<span class="ico_short_ani"	style="display:none;">숏애니</span>
#
# 							<a onclick="nclk_v2(event,'rcn*s.title','784852','5')" href="/webtoon/list?titleId=784852">
# 								<span>어메이징 스파이더맨</span>
# 							</a>
# 						</h6>
# 						<p>
# 							<a onclick="nclk_v2(event,'rcn*s.sub','784852','5')" href="/webtoon/detail?titleId=784852&no=4">
# 								<span>3화 다시 기본으로 3부</span>
# 							</a>
# 						</p>
# 						<span class="user">
# 							<a href="#" onclick="return goArtist('784852', '5', this, event);">
# 								닉 스펜서 / 라이언 오틀리
# 							</a>
# 						</span>
# 					</div>
# 				</li>
#
#
#
#
#
#
#
#
#
# 				<li>
# 					<div class="genreRecomImg2">
# 						<a onclick="nclk_v2(event,'rcn*s.thum','784890','6')" href="/webtoon/list?titleId=784890">
# 							<span class="mask"></span>
# 							<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 								 src="https://shared-comic.pstatic.net/thumb/webtoon/784890/thumbnail/thumbnail_IMAG04_c1bf28d2-80e9-48d1-a8cd-b9ea4cfef92b.jpg"
# 								 width="218" height="120" title="7아이언" alt="7아이언">
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo2">
# 						<h6 class="title">
# 							<span class="ico_break"	style="display:none;">휴재</span>
# 							<span class="ico_cut"	style="display:none;">컷툰</span>
# 							<span class="ico_short_ani"	style="display:none;">숏애니</span>
#
# 							<a onclick="nclk_v2(event,'rcn*s.title','784890','6')" href="/webtoon/list?titleId=784890">
# 								<span>7아이언</span>
# 							</a>
# 						</h6>
# 						<p>
# 							<a onclick="nclk_v2(event,'rcn*s.sub','784890','6')" href="/webtoon/detail?titleId=784890&no=4">
# 								<span>4화</span>
# 							</a>
# 						</p>
# 						<span class="user">
# 							<a href="#" onclick="return goArtist('784890', '6', this, event);">
# 								태발 / 김홍태
# 							</a>
# 						</span>
# 					</div>
# 				</li>
#
# 			</ul>
# 		</div>
# 		<!-- //장르별 추천 웹툰 -->
#
# <!-- 베스트&도전 추천만화 -->
# <div class="genreRecomBox_area">
# 	<h3 class="titleMain"><span class="Ntxt_best">베스트도전&도전 추천</span></h3>
# 	<ul class="genreRecom">
# 		<li>
# 			<h4 class="subtlt3">에피소드</h4>
# 			<ul class="genreRecomList">
#
#
# 					<li>
# 						<div class="genreRecomImg">
#
# 							<a onclick="nclk_v2(event,'sug.thum');" href="/bestChallenge/list?titleId=751743">
# 								<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2020/09/11/336145/thumbnail_83x908505d0c3_374b_4f99_a2e5_3a10d754d70f_00002577.JPEG" title="핫캣일기" alt="핫캣일기" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" >
# 								<span class="mask"></span>
#
#
#
#
# 							</a>
# 						</div>
# 						<div class="genreRecomInfo">
# 							<h6 class="title"><a onclick="nclk_v2(event,'sug.title');" href="/bestChallenge/list?titleId=751743">핫캣일기</a></h6>
# 							<div><a onclick="return goArtistTitle(this,'sug.artist','751743','1',event);" href="#" class="user">luna****</a></div>
# 							<div class="summary">느긋한 열정 고양이</div>
# 							<div class="rating_type">
# 								<span class="star"><em style="width:98%" title="점">평점</em></span>
# 								<strong>9.83</strong>
# 							</div>
# 						</div>
# 					</li>
#
#
# 					<li>
# 						<div class="genreRecomImg">
#
# 							<a onclick="nclk_v2(event,'sug.thum');" href="/bestChallenge/list?titleId=728359">
# 								<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2021/09/23/325440/thumbnail_83x90391b866f_de86_4628_8fb2_ac60218b3393_00003519.JPEG" title="휴르르의 개그만화 (러시아워)" alt="휴르르의 개그만화 (러시아워)" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" >
# 								<span class="mask"></span>
#
#
#
#
# 							</a>
# 						</div>
# 						<div class="genreRecomInfo">
# 							<h6 class="title"><a onclick="nclk_v2(event,'sug.title');" href="/bestChallenge/list?titleId=728359">휴르르의 개그만화 (러시아워)</a></h6>
# 							<div><a onclick="return goArtistTitle(this,'sug.artist','728359','2',event);" href="#" class="user">op****</a></div>
# 							<div class="summary">해외창업개그만화</div>
# 							<div class="rating_type">
# 								<span class="star"><em style="width:99%" title="점">평점</em></span>
# 								<strong>9.90</strong>
# 							</div>
# 						</div>
# 					</li>
#
#
# 					<li>
# 						<div class="genreRecomImg">
# 							<div class="cutTypeChal"><span>도전</span></div>
# 							<a onclick="nclk_v2(event,'sug.ecthum');" href="/challenge/list?titleId=744077">
# 								<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2020/08/01/332674/thumbnail_83x9092680dcc_504a_451e_893d_e7d5737609ca_00001446.JPEG" title="섭섭하지 않은 쿼카" alt="섭섭하지 않은 쿼카" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'" >
# 								<span class="mask"></span>
#
#
#
#
# 							</a>
# 						</div>
# 						<div class="genreRecomInfo">
# 							<h6 class="title"><a onclick="nclk_v2(event,'sug.ectitle');" href="/challenge/list?titleId=744077">섭섭하지 않은 쿼카</a></h6>
# 							<div><a onclick="return goArtistTitle(this,'sug.ecartist','744077','3',event);" href="#" class="user">i_me****</a></div>
# 							<div class="summary">하루,그림일기 웹툰</div>
# 							<div class="rating_type">
# 								<span class="star"><em style="width:81%" title="점">평점</em></span>
# 								<strong>8.13</strong>
# 							</div>
# 						</div>
# 					</li>
#
# 			</ul>
# 		</li>
# 		<li>
# 			<h4 class="subtlt3">옴니버스</h4>
# 			<ul class="genreRecomList">
#
#
#
# 						<li>
#
#
# 					<div class="genreRecomImg">
#
# 						<a onclick="nclk_v2(event,'sug.ecthum');" href="/bestChallenge/list?titleId=661463">
# 							<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/06/14/247046/thumbnail_83x90b0a22b05_c005_42d9_9dab_9f75fde01d7d_00003570.JPEG" title="칼람의 신들" alt="칼람의 신들" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'">
# 							<span class="mask"></span>
#
#
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo">
# 						<h6 class="title"><a onclick="nclk_v2(event,'sug.ectitle');" href="/bestChallenge/list?titleId=661463">칼람의 신들</a></h6>
# 						<div><a onclick="return goArtistTitle(this,'sug.ecartist','661463','1',event);" href="#" class="user">sing****</a></div>
# 						<div class="summary">수메르 신화</div>
# 						<div class="rating_type">
# 							<span class="star"><em style="width:98%" title="점">평점</em></span>
# 							<strong>9.85</strong>
# 						</div>
# 					</div>
# 					</li>
#
#
#
#
# 						<li class="first2">
#
# 					<div class="genreRecomImg">
#
# 						<a onclick="nclk_v2(event,'sug.ecthum');" href="/bestChallenge/list?titleId=791651">
# 							<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/06/04/354200/thumbnail_83x9083f18a9a_cca3_4407_a6d6_9337d3b015b4_00001170.JPEG" title="일상과 망상" alt="일상과 망상" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'">
# 							<span class="mask"></span>
#
#
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo">
# 						<h6 class="title"><a onclick="nclk_v2(event,'sug.ectitle');" href="/bestChallenge/list?titleId=791651">일상과 망상</a></h6>
# 						<div><a onclick="return goArtistTitle(this,'sug.ecartist','791651','2',event);" href="#" class="user">kopj****</a></div>
# 						<div class="summary">블랙코미디</div>
# 						<div class="rating_type">
# 							<span class="star"><em style="width:93%" title="점">평점</em></span>
# 							<strong>9.37</strong>
# 						</div>
# 					</div>
# 					</li>
#
#
#
#
# 						<li class="first2">
#
# 					<div class="genreRecomImg">
# 						<div class="cutTypeChal">도전</div>
# 						<a onclick="nclk_v2(event,'sug.octhum');" href="/challenge/list?titleId=784181">
# 							<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/05/25/350849/thumbnail_83x9014904281_e523_4002_bf1d_e87dbda97040_00000015.JPEG" title="비틀비틀동화" alt="비틀비틀동화" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'">
# 							<span class="mask"></span>
#
#
#
#
# 						</a>
# 					</div>
# 					<div class="genreRecomInfo">
# 						<h6 class="title"><a onclick="nclk_v2(event,'sug.octitle');" href="/challenge/list?titleId=784181">비틀비틀동화</a></h6>
# 						<div><a onclick="return goArtistTitle(this,'sug.ocartist','784181','3',event);" href="#" class="user">atlk****</a></div>
# 						<div class="summary">동화 비틀기</div>
# 						<div class="rating_type">
# 							<span class="star"><em style="width:81%" title="점">평점</em></span>
# 							<strong>8.16</strong>
# 						</div>
# 					</div>
# 					</li>
#
# 			</ul>
# 		</li>
# 		<li>
# 			<h4 class="subtlt3">스토리</h4>
# 			<ul class="genreRecomList">
#
#
# 					<li>
# 						<div class="genreRecomImg">
#
# 							<a onclick="nclk_v2(event,'sug.octhum');" href="/bestChallenge/list?titleId=787265">
# 								<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2022/01/29/352238/title_thumbnail_025022_83x90.jpg" title="두리안은 과일이 아니야!" alt="두리안은 과일이 아니야!" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'">
# 								<span class="mask"></span>
#
#
#
#
# 							</a>
# 						</div>
# 						<div class="genreRecomInfo">
# 							<h6 class="title"><a onclick="nclk_v2(event,'sug.octitle');" href="/bestChallenge/list?titleId=787265">두리안은 과일이 아니야!</a></h6>
# 							<div><a onclick="return goArtistTitle(this,'sug.ocartist','787265','1',event);" href="#" class="user">begi****</a></div>
# 							<div class="summary">두리안이 나타났다!</div>
# 							<div class="rating_type">
# 								<span class="star"><em style="width:94%" title="점">평점</em></span>
# 								<strong>9.44</strong>
# 							</div>
# 						</div>
# 					</li>
#
#
# 					<li>
# 						<div class="genreRecomImg">
#
# 							<a onclick="nclk_v2(event,'sug.octhum');" href="/bestChallenge/list?titleId=620732">
# 								<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2019/04/17/268523/thumbnail_83x90c75265ca_57cc_4223_bc8d_f35ad9768ff6_00002560.JPEG" title="백일몽화원" alt="백일몽화원" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'">
# 								<span class="mask"></span>
#
#
#
#
# 							</a>
# 						</div>
# 						<div class="genreRecomInfo">
# 							<h6 class="title"><a onclick="nclk_v2(event,'sug.octitle');" href="/bestChallenge/list?titleId=620732">백일몽화원</a></h6>
# 							<div><a onclick="return goArtistTitle(this,'sug.ocartist','620732','2',event);" href="#" class="user">bada****</a></div>
# 							<div class="summary">매력세계관 판타지</div>
# 							<div class="rating_type">
# 								<span class="star"><em style="width:97%" title="점">평점</em></span>
# 								<strong>9.71</strong>
# 							</div>
# 						</div>
# 					</li>
#
#
# 					<li>
# 						<div class="genreRecomImg">
# 							<div class="cutTypeChal">도전</div>
# 							<a onclick="nclk_v2(event,'sug.scthum');" href="/challenge/list?titleId=700179">
# 								<img src="https://shared-comic.pstatic.net/thumb/nas/user_contents_data/challenge_comic/2017/08/12/270834/thumbnail_title_mamatree101_225044_83x90.jpg" title="향기가 나는 집" alt="향기가 나는 집" width="83" height="90" onERROR="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/non83_90.gif'">
# 								<span class="mask"></span>
#
#
#
#
# 							</a>
# 						</div>
# 						<div class="genreRecomInfo">
# 							<h6 class="title"><a onclick="nclk_v2(event,'sug.sctitle');" href="/challenge/list?titleId=700179">향기가 나는 집</a></h6>
# 							<div><a onclick="return goArtistTitle(this,'sug.scartist','700179','3',event);" href="#" class="user">mama****</a></div>
# 							<div class="summary">특별한 힘을 가진 외톨이 4인방</div>
# 							<div class="rating_type">
# 								<span class="star"><em style="width:92%" title="점">평점</em></span>
# 								<strong>9.27</strong>
# 							</div>
# 						</div>
# 					</li>
#
# 			</ul>
# 		</li>
# 	</ul>
# </div>
# <!-- // 베스트&도전 추천만화 -->
#
#
#
#
#
#
#
#
# <!-- 장르별 인기 유료 만화(업데이트순) -->
#
#
#     <div class="genreRecomBox_area" id="updateCompositionContent">
#         <h3 class="titleMain">
#             <span class="Ntxt_genre_popular">장르별 인기 단행본만화</span>
#         </h3>
#         <ul class="genreRecom">
#
#             <li>
#                 <h4 class="subtlt3">
#                     <a onclick="nclk_v2(event,'Cha.cat','99',1); goSeries('/comic/categoryProductList.series?categoryTypeCode=genre&genreCode=99')" href="#none" title="새 창">
#
#                             순정
#
#
#
#                     </a><span class="Nico_arr"></span>
#                 </h4>
#
#                 <ul class="genreRecomList">
#
#                     <li>
#                         <div class="genreRecomImg3">
#                             <a onclick="nclk_v2(event,'Cha.thum','462984',1); goSeries('/comic/detail.series?originalProductId=462984')" href="#none" title="새 창">
#                                 <img src="https://comicthumb-phinf.pstatic.net/20220328_267/pocket_1648471008023KkKTz_JPEG/000.jpg?type=m80" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' width="80" height="100" title="바빌론 폭군의 왕비가 되다" alt="바빌론 폭군의 왕비가 되다">
#                                 <span class="mask"></span>
#                             </a>
#                         </div>
#                         <div class="genreRecomInfo3">
#                             <h6 class="title">
#                                 <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=462984')" title="새 창">바빌론 폭군의 왕비가 되다</a>
#                             </h6>
#                             <div class="user">애도성제-당림</div>
#                             <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=462984')" title="새 창">하룻밤 새에 고대 메소포타미아 평원에 떨어...</a></div>
#                             <div class="rating_type">
#                                 <span class="star"><em style="width:80%" title="8점">평점</em></span>
#                                 <strong>
#
#                                         8
#
#
#                                 </strong>
#                             </div>
#                         </div>
#                     </li>
#
#                     <li>
#                         <div class="genreRecomImg3">
#                             <a onclick="nclk_v2(event,'Cha.thum','409400',1); goSeries('/comic/detail.series?originalProductId=409400')" href="#none" title="새 창">
#                                 <img src="https://comicthumb-phinf.pstatic.net/20200910_31/pocket_1599734602825IhYoW_JPEG/000.jpg?type=m80" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' width="80" height="100" title="황녀의 생존법칙" alt="황녀의 생존법칙">
#                                 <span class="mask"></span>
#                             </a>
#                         </div>
#                         <div class="genreRecomInfo3">
#                             <h6 class="title">
#                                 <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=409400')" title="새 창">황녀의 생존법칙</a>
#                             </h6>
#                             <div class="user">양지묘</div>
#                             <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=409400')" title="새 창">신선들이 사는 선경(仙境). 모든 수선자들...</a></div>
#                             <div class="rating_type">
#                                 <span class="star"><em style="width:84%" title="8.4점">평점</em></span>
#                                 <strong>
#
#                                         8.4
#
#
#                                 </strong>
#                             </div>
#                         </div>
#                     </li>
#
#                 </ul>
#             </li>
#
#             <li>
#                 <h4 class="subtlt3">
#                     <a onclick="nclk_v2(event,'Cha.cat','90',1); goSeries('/comic/categoryProductList.series?categoryTypeCode=genre&genreCode=90')" href="#none" title="새 창">
#
#
#
#                             소년
#
#                     </a><span class="Nico_arr"></span>
#                 </h4>
#
#                 <ul class="genreRecomList">
#
#                     <li>
#                         <div class="genreRecomImg3">
#                             <a onclick="nclk_v2(event,'Cha.thum','420048',1); goSeries('/comic/detail.series?originalProductId=420048')" href="#none" title="새 창">
#                                 <img src="https://comicthumb-phinf.pstatic.net/20201223_33/pocket_1608700486768vtwd4_JPEG/__690x100.jpg?type=m80" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' width="80" height="100" title="테러대부활" alt="테러대부활">
#                                 <span class="mask"></span>
#                             </a>
#                         </div>
#                         <div class="genreRecomInfo3">
#                             <h6 class="title">
#                                 <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=420048')" title="새 창">테러대부활</a>
#                             </h6>
#                             <div class="user">고진호</div>
#                             <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=420048')" title="새 창">드디어 테러맨과 부활남이 만났다.
#
# ...</a></div>
#                             <div class="rating_type">
#                                 <span class="star"><em style="width:98%" title="9.8점">평점</em></span>
#                                 <strong>
#
#                                         9.8
#
#
#                                 </strong>
#                             </div>
#                         </div>
#                     </li>
#
#                     <li>
#                         <div class="genreRecomImg3">
#                             <a onclick="nclk_v2(event,'Cha.thum','439467',1); goSeries('/comic/detail.series?originalProductId=439467')" href="#none" title="새 창">
#                                 <img src="https://comicthumb-phinf.pstatic.net/20210709_221/pocket_1625835374696BsO4a_JPEG/__690x1000.jpg?type=m80" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' width="80" height="100" title="어느날 갑자기 서울은" alt="어느날 갑자기 서울은">
#                                 <span class="mask"></span>
#                             </a>
#                         </div>
#                         <div class="genreRecomInfo3">
#                             <h6 class="title">
#                                 <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=439467')" title="새 창">어느날 갑자기 서울은</a>
#                             </h6>
#                             <div class="user">박창근</div>
#                             <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=439467')" title="새 창">'닿는 순간 먹이가 된다.' 어느 날 갑자...</a></div>
#                             <div class="rating_type">
#                                 <span class="star"><em style="width:94%" title="9.4점">평점</em></span>
#                                 <strong>
#
#                                         9.4
#
#
#                                 </strong>
#                             </div>
#                         </div>
#                     </li>
#
#                 </ul>
#             </li>
#
#             <li>
#                 <h4 class="subtlt3">
#                     <a onclick="nclk_v2(event,'Cha.cat','88',1); goSeries('/comic/categoryProductList.series?categoryTypeCode=genre&genreCode=88')" href="#none" title="새 창">
#
#
#                             무협
#
#
#                     </a><span class="Nico_arr"></span>
#                 </h4>
#
#                 <ul class="genreRecomList">
#
#                     <li>
#                         <div class="genreRecomImg3">
#                             <a onclick="nclk_v2(event,'Cha.thum','470531',1); goSeries('/comic/detail.series?originalProductId=470531')" href="#none" title="새 창">
#                                 <img src="https://comicthumb-phinf.pstatic.net/20220613_78/pocket_1655098392668llxcD_JPEG/soksung.jpg?type=m80" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' width="80" height="100" title="속성으로 무림지존" alt="속성으로 무림지존">
#                                 <span class="mask"></span>
#                             </a>
#                         </div>
#                         <div class="genreRecomInfo3">
#                             <h6 class="title">
#                                 <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=470531')" title="새 창">속성으로 무림지존</a>
#                             </h6>
#                             <div class="user">faloo,Zhenlaiye</div>
#                             <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=470531')" title="새 창">외문제자 중 19세가 됐음에도 연기경 6중...</a></div>
#                             <div class="rating_type">
#                                 <span class="star"><em style="width:87%" title="8.7점">평점</em></span>
#                                 <strong>
#
#                                         8.7
#
#
#                                 </strong>
#                             </div>
#                         </div>
#                     </li>
#
#                     <li>
#                         <div class="genreRecomImg3">
#                             <a onclick="nclk_v2(event,'Cha.thum','456156',1); goSeries('/comic/detail.series?originalProductId=456156')" href="#none" title="새 창">
#                                 <img src="https://comicthumb-phinf.pstatic.net/20220207_144/pocket_1644235714183FcfgO_JPEG/001.jpg?type=m80" onerror='this.src="https://ssl.pstatic.net/static/comic/images/migration/thumbnail/noimg.gif"' width="80" height="100" title="만계 출석 시스템" alt="만계 출석 시스템">
#                                 <span class="mask"></span>
#                             </a>
#                         </div>
#                         <div class="genreRecomInfo3">
#                             <h6 class="title">
#                                 <a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=456156')" title="새 창">만계 출석 시스템</a>
#                             </h6>
#                             <div class="user">friexkk</div>
#                             <div class="summary"><a href="#none" onclick="goSeries('/comic/detail.series?originalProductId=456156')" title="새 창">왜 꼭 이런 육체로 환생했을까? 하지만 그...</a></div>
#                             <div class="rating_type">
#                                 <span class="star"><em style="width:86%" title="8.6점">평점</em></span>
#                                 <strong>
#
#                                         8.6
#
#
#                                 </strong>
#                             </div>
#                         </div>
#                     </li>
#
#                 </ul>
#             </li>
#
#         </ul>
#     </div>
#     <!-- // 장르별 인기 유료 만화(업데이트순) -->
#
#
#
# <script type="text/javascript">
#
#     new mainGenreInfo("Update", "story");
#
#     function goSeries(url) {
#         var seriesPopup = window.open("https://series.naver.com" + url, "series", "left=0, top=0, menubar=yes, resizable=yes, scrollbars=yes, status=yes, titlebar=yes, toolbar=yes, directories=yes, location=yes");
#         seriesPopup.focus();
#     }
#
#
#
# </script>
# <script type="text/template" id="webtoonGenreTemplate">
# 	{for num:record in mainGenreList}
# 	<li>
# 		<div class="genreRecomImg2">
# 			<a onclick="nclk_v2(event,'rcn*{=nCkicksValue}.thum','{=record.titleId}','{=num + 1}')" href="/webtoon/list?titleId={=record.titleId}">
# 				<span class="mask"></span>
# 				<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'"
# 					 src="https://shared-comic.pstatic.net/thumb/webtoon{=record.thumbnailFilepath}{=record.thumbnailFilename}"
# 					 width="218" height="120" title="{=record.titleName}" alt="{=record.titleName}">
# 				{if record.finished == 'Y'}<span class="finish">완결</span>{/if}
# 				{if record.ageRate == 'RATE_18'}<span class="mark_adult_thumb">18세 이상 이용 가능</span>{/if}
# 			</a>
# 		</div>
# 		<div class="genreRecomInfo2">
# 			<h6 class="title">
# 				{if record.restYN == 'Y'}<span class="ico_break">휴재</span>{/if}
# 				{if record.webtoonViewerType == 'CUTTOON'}<span class="ico_cut">컷툰</span>{/if}
# 				{if record.webtoonViewerType == 'SHORTANI'}<span class="ico_short_ani">숏애니</span>{/if}
# 				<a onclick="nclk_v2(event,'rcn*{=nCkicksValue}.title','{=record.titleId}','{=num + 1}')" href="/webtoon/list?titleId={=record.titleId}">
# 					<span>{=record.titleName}</span>
# 				</a>
# 			</h6>
# 			<p>
# 				<a onclick="nclk_v2(event,'rcn*{=nCkicksValue}.sub','{=record.titleId}','{=num + 1}')" href="/webtoon/detail?titleId={=record.titleId}&no={=record.no}">
# 					<span>{=record.subTitle}</span>
# 				</a>
# 			</p>
# 			<span class="user">
# 			<a href="#" onclick="return goArtist('{=record.titleId}', '{=num + 1}', this, event);">
# 				{=record.painterIdBy28}
# 			</a>
# 		</span>
# 		</div>
# 	</li>
# 	{/for}
# </script>
# 			</div>
# 			<!-- side menu -->
#
# 				<div id="aside">
#
#
#
#
#
#
#
#
# <div class="asideButton upload">
#
# 		<a href="/mypage/myActivity" class="Nbtn_upload" onclick="nclk_v2(event,'olk.upload');">웹툰 올리기</a>
#
#
# </div>
#
#
#
#
#
#
#
# <!-- 배너 -->
#
#
#
#         <div id="onlyRightAd" name="addiv" data-veta-preview="p_wtoon_end" class="asideAd"></div>
#
#
#
#
#
#
#         <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>
#         <script>
#             window.ndpsdk = window.ndpsdk || { cmd: [], polyfill: { cmd: [] } };
#             ndpsdk.cmd.push(function() {
#                 ndpsdk.defineAdSlot({
#                     adSlotElementId: "onlyRightAd",
#                     adTagUrl: "https://siape.veta.naver.com/fxshow?su=SU10321",
#                     width: 240,
#                     height: 240,
#                 });
#                 ndpsdk.displayAd("onlyRightAd");
#             });
#         </script>
#
#
# <!-- //배너 -->
#
#
#
#
#
#
# <!-- 롤링이미지 -->
#
# <div class="asideRolling">
# 	<a onclick="nclk_v2(event,'olk.banner')" href="https://comic-superstring.naver.com/" target="_blank">
# 		<img src="https://naverwebtoon-phinf.pstatic.net/20190711_69/15628125217864fItE_JPEG/upload_7786257395998636846.JPEG?type=p100" width="240" height="97" alt="드디어! 슈퍼스트링 전용관">
# 	</a>
# </div>
#
#
#
#
#
#
#
#
#
#
# <!-- 인기급상승웹툰 -->
# <div class="asideBox">
# 	<h4 class="asideBoxTitle"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_best_v2.gif" title="인기급상승웹툰" alt="인기급상승웹툰" width="78" height="11"></h4>
# 	<div>
# 		<ul class="asideBoxTab"><!-- 선택된 메뉴에는 choice라는 클래스명을 사용합니다 -->
# 			<li id="realTimeRankChoiceTabFavorite" class="choice"><a id="realTimeRankChoiceTabFavoriteClick" onclick="nclk_v2(event,'rnk.rep')" href="#"><img src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_favor.gif" title="인기순" alt="인기순" width="31" height="12"></a></li>
# 			<li id="realTimeRankChoiceTabUpdate"><a id="realTimeRankChoiceTabUpdateClick" onclick="nclk_v2(event,'rnk.upd')" href="#" ><img src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_update.gif" title="업데이트순" alt="업데이트순" width="52" height="12"></a></li>
# 		</ul>
# 		<h3 id="realTimeRankBlindName" class="blind">인기순</h3>
# 		<ol id="realTimeRankFavorite" class="asideBoxRank">
#
#
#
#
#
#
#
#
#
# 			<li class="rank01">
#
#
#
# 						<a onclick="nclk_v2(event,'rnk*p.cont','736277','1')" href="/webtoon/detail?titleId=736277&no=140" title="싸움독학-136화 : 이유는 고작 그것뿐입니다">싸움독학-136화 : 이유는 고작 그것뿐입니다</a>
#
#
# 				<span class="rankBox">
#
#
#
#
#
# 							<img src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음" width="7" height="10"> 0
#
#
# 				</span>
# 			</li>
#
#
#
#
#
#
#
#
#
# 			<li class="rank02">
#
#
#
# 						<a onclick="nclk_v2(event,'rnk*p.cont','748105','2')" href="/webtoon/detail?titleId=748105&no=185" title="독립일기-시즌2 82화 추억 팔이">독립일기-시즌2 82화 추억 팔이</a>
#
#
# 				<span class="rankBox">
#
#
#
#
#
# 							<img src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음" width="7" height="10"> 0
#
#
# 				</span>
# 			</li>
#
#
#
#
#
#
#
#
#
# 			<li class="rank03">
#
#
#
# 						<a onclick="nclk_v2(event,'rnk*p.cont','746858','3')" href="/webtoon/detail?titleId=746858&no=100" title="이번 생도 잘 부탁해-100화">이번 생도 잘 부탁해-100화</a>
#
#
# 				<span class="rankBox">
#
#
#
#
#
# 							<img src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음" width="7" height="10"> 0
#
#
# 				</span>
# 			</li>
#
#
#
#
#
#
#
#
#
# 			<li class="rank04">
#
#
#
# 						<a onclick="nclk_v2(event,'rnk*p.cont','758150','4')" href="/webtoon/detail?titleId=758150&no=90" title="입학용병-89화">입학용병-89화</a>
#
#
# 				<span class="rankBox">
#
#
#
# ...
# 				<a onclick="nclk_v2(event,'rnk*u.cont','774044','10')" href="/webtoon/detail?titleId=774044&no=55" title="투신전생기-55화">
#
# 					투신전생기-55화
# 				</a>
# 				<span class="timeBox">
#
#
#
# 							23시간전
#
#
#
#
#
# 				</span>
# 			</li>
#
# 		</ol>
#
# 	</div>
# </div>
# <!-- //인기급상승웹툰 -->
#
#
#
#
#
#
#
#
#
# <!-- 추천 웹툰 -->
# <div class="asideBox">
# 	<!-- [D] 10대: h_10_v2.gif, 20대: h_20_v2.gif -->
# 	<h4 class="asideBoxTitle"><img id="recommand_ageImg" src="https://ssl.pstatic.net/static/comic/images/migration/common/h_30_v2.gif" width="107" height="11" alt="30대 인기웹툰">
# 		<div class="tab_nv">
# 			<a id="recommandWebtoonRankLeftTabClick" href="#" class="Nico_prv">이전</a><a id="recommandWebtoonRankRightTabClick" href="#" class="Nico_nxt">다음</a>
# 		</div>
# 	</h4>
# 	<div>
# 		<ul class="asideBoxTab">
# 			<li id="recommandWebtoonRankMTabOver" class="choice"><a href="#" onclick="return false;"> <img src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_m.png" width="21" height="11" alt="남자" title="남자"></a></li>
# 			<li id="recommandWebtoonRankWTabOver"><a href="#" onclick="return false;"> <img src="https://ssl.pstatic.net/static/comic/images/migration/common/tab_txt_w.png" width="21" height="11" alt="여자" title="여자"></a></li>
# 		</ul>
# 		<h3 id="ageGenderRankBlindName" class="blind">남자</h3>
# 		<ol id="recommandWebtoonRank" class="asideBoxRank asideBoxRank2">
#
#
#
#
#
#
#
#
# 			<li id="recommandLi_0" class="rank01">
# 				<div class="thumb6">
# 					<a id="recommand_link_0" href="/webtoon/detail?titleId=736277&no=140" title="싸움독학">
# 						<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" id="recommand_thumbnail_0" src="https://shared-comic.pstatic.net/thumb/webtoon/736277/thumbnail/thumbnail_IMAG10_3ff8475e-6085-4188-a359-920a8801b419.jpg" width="30" height="33" alt="싸움독학">
# 						<span class="mask"></span>
# 					</a>
# 				</div>
# 				<div class="rc_info">
# 					<a id="recommand_titleName_0" href="/webtoon/detail?titleId=736277&no=140" class="tit" title="싸움독학">싸움독학</a>
# 					<em><a id="recommand_painter_0" href="#" onclick="return artistAction.viewArtist('736277', this);" title="박태준 만화회사 / 김정현 스튜디오">박태준 만화회사 / 김정현 스튜디오</a></em>
# 					<span class="rankBox2">
#
#
#
#
# 							<img id="recommand_img_0" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음"><em id="recommand_rank_0">0</em>
#
# 					</span>
# 				</div>
# 			</li>
#
#
#
#
#
#
#
#
# 			<li id="recommandLi_1" class="rank02">
# 				<div class="thumb6">
# 					<a id="recommand_link_1" href="/webtoon/detail?titleId=758150&no=90" title="입학용병">
# 						<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" id="recommand_thumbnail_1" src="https://shared-comic.pstatic.net/thumb/webtoon/758150/thumbnail/thumbnail_IMAG10_c03df7c9-dbf3-4314-8699-04ce77fb4444.jpg" width="30" height="33" alt="입학용병">
# 						<span class="mask"></span>
# 					</a>
# 				</div>
# 				<div class="rc_info">
# 					<a id="recommand_titleName_1" href="/webtoon/detail?titleId=758150&no=90" class="tit" title="입학용병">입학용병</a>
# 					<em><a id="recommand_painter_1" href="#" onclick="return artistAction.viewArtist('758150', this);" title="YC / 락현">YC / 락현</a></em>
# 					<span class="rankBox2">
#
#
#
#
# 							<img id="recommand_img_1" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음"><em id="recommand_rank_1">0</em>
#
# 					</span>
# 				</div>
# 			</li>
#
#
#
#
#
#
#
#
# 			<li id="recommandLi_2" class="rank03">
# 				<div class="thumb6">
# 					<a id="recommand_link_2" href="/webtoon/detail?titleId=795262&no=8" title="사형소년">
# 						<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" id="recommand_thumbnail_2" src="https://shared-comic.pstatic.net/thumb/webtoon/795262/thumbnail/thumbnail_IMAG10_90b36e49-de69-4484-b566-9e8fcb295ea2.jpg" width="30" height="33" alt="사형소년">
# 						<span class="mask"></span>
# 					</a>
# 				</div>
# 				<div class="rc_info">
# 					<a id="recommand_titleName_2" href="/webtoon/detail?titleId=795262&no=8" class="tit" title="사형소년">사형소년</a>
# 					<em><a id="recommand_painter_2" href="#" onclick="return artistAction.viewArtist('795262', this);" title="박태준만화회사, 김숭늉 / 광산">박태준만화회사, 김숭늉 / 광산</a></em>
# 					<span class="rankBox2">
#
#
#
#
# 							<img id="recommand_img_2" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음"><em id="recommand_rank_2">0</em>
#
# 					</span>
# 				</div>
# 			</li>
#
#
#
#
#
#
#
#
# 			<li id="recommandLi_3" class="rank04">
# 				<div class="thumb6">
# 					<a id="recommand_link_3" href="/webtoon/detail?titleId=774044&no=55" title="투신전생기">
# 						<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" id="recommand_thumbnail_3" src="https://shared-comic.pstatic.net/thumb/webtoon/774044/thumbnail/thumbnail_IMAG10_7e564e71-f824-466a-ae37-9a62192c6fa0.jpg" width="30" height="33" alt="투신전생기">
# 						<span class="mask"></span>
# 					</a>
# 				</div>
# 				<div class="rc_info">
# 					<a id="recommand_titleName_3" href="/webtoon/detail?titleId=774044&no=55" class="tit" title="투신전생기">투신전생기</a>
# 					<em><a id="recommand_painter_3" href="#" onclick="return artistAction.viewArtist('774044', this);" title="청담">청담</a></em>
# 					<span class="rankBox2">
#
#
#
#
# 							<img id="recommand_img_3" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음"><em id="recommand_rank_3">0</em>
#
# 					</span>
# 				</div>
# 			</li>
#
#
#
#
#
#
#
#
# 			<li id="recommandLi_4" class="rank05">
# 				<div class="thumb6">
# 					<a id="recommand_link_4" href="/webtoon/detail?titleId=710751&no=200" title="약한영웅">
# 						<img onerror="this.src='https://ssl.pstatic.net/static/comic/images/migration/common/blank.gif'" id="recommand_thumbnail_4" src="https://shared-comic.pstatic.net/thumb/webtoon/710751/thumbnail/thumbnail_IMAG10_f0f51e5a-a2f2-4404-8ace-866ab7fd1af3.jpg" width="30" height="33" alt="약한영웅">
# 						<span class="mask"></span>
# 					</a>
# 				</div>
# 				<div class="rc_info">
# 					<a id="recommand_titleName_4" href="/webtoon/detail?titleId=710751&no=200" class="tit" title="약한영웅">약한영웅</a>
# 					<em><a id="recommand_painter_4" href="#" onclick="return artistAction.viewArtist('710751', this);" title="서패스 / 김진석">서패스 / 김진석</a></em>
# 					<span class="rankBox2">
#
#
#
#
# 							<img id="recommand_img_4" src="https://ssl.pstatic.net/static/comic/images/migration/common/arrow_no.gif" title="변동없음" alt="변동없음"><em id="recommand_rank_4">0</em>
#
# 					</span>
# 				</div>
# 			</li>
#
# 		</ol>
# 	</div>
# </div>
# <script>
# new naver.comic.RecommandWebtoonRankLayer(2, "https://shared-comic.pstatic.net/thumb");
# </script>
# <!-- //추천 웹툰 -->
#
#
#
#
# <!-- 공지사항 -->
# <div class="asideBox">
# 	<h4 class="asideBoxTitle">
# 		<img src="https://ssl.pstatic.net/static/comic/images/migration/common/subtlt_r_notice.gif" title="공지사항" alt="공지사항" width="43" height="12">
# 	</h4>
#
# 	<ul class="asideBoxNotice">
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','1690','1')" href="/notice/detail?noticeId=1690" title="2022 학원로맨스 웹툰 모집 안내 (7/14~8/24)">
# 				<strong>
# 					2022 학원로맨스 웹툰 모집 안내
# 				</strong>
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','1686','2')" href="/notice/detail?noticeId=1686" title="2022 네이버웹툰 최강자전 개최 안내">
# 				<strong>
# 					2022 네이버웹툰 최강자전 개최 안내
# 				</strong>
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','1676','3')" href="/notice/detail?noticeId=1676" title="2022 지상최대공모전 웹툰 부문 상세 공지">
# 				<strong>
# 					2022 지상최대공모전 웹툰 부문 상세 공지
# 				</strong>
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','1678','4')" href="/notice/detail?noticeId=1678" title="2022 모든웹툰 공모전 (레드아이스X부천시with네이버웹툰) 개최 안내">
# 				<strong>
# 					2022 모든웹툰 공모전 개최 안내
# 				</strong>
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','535','5')" href="/notice/detail?noticeId=535" title="(new) 웹소설원작 웹툰을 위한 각색/작화 작가를 모십니다!">
#
# 					웹소설원작 웹툰을 위한 각색/작화 작가를 모십니다
#
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','495','6')" href="/notice/detail?noticeId=495" title="(new) 네이버웹툰 연재 작가를 모십니다! ">
#
# 					네이버웹툰 연재 작가를 모십니다
#
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','521','7')" href="/notice/detail?noticeId=521" title="[출시] 새로운 웹툰 라인업! <매일+>에서 만나보세요! ">
#
# 					[출시] 새로운 웹툰 라인업! &lt;매일+&gt;
#
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','526','8')" href="/notice/detail?noticeId=526" title="#내돈내툰, 우리가 웹툰을 즐기는 방법">
#
# 					#내돈내툰, 우리가 웹툰을 즐기는 방법
#
# 			</a>
# 		</li>
#
# 		<li>
# 			<a onclick="nclk_v2(event,'sna.not','1689','9')" href="/notice/detail?noticeId=1689" title="2022년 7월 유료화 전환 작품 안내">
#
# 					2022년 7월 유료화 전환 작품 안내
#
# 			</a>
# 		</li>
#
# 	</ul>
#
# 	<a onclick="nclk_v2(event,'sna.more')" href="/notice/list" class="asideBoxMore">
# 		<span class="blind">공지사항</span> 더보기
# 	</a>
#
# </div>
# <!-- //공지사항 -->
#
#
#
#
#
#
#
# <div class="asideBanner">
# 	<a onclick="nclk_v2(event,'sna.proposal');" href="/business/proposalGuide">
# 		<img src="https://ssl.pstatic.net/static/comic/images/bnr_partnership.jpg" width="240" height="86" alt="웹툰, 웹소설 온라인 광고 판권 사업">
# 	</a>
# </div>
#
#
# <div class="asideBanner">
# 	<a onclick="nclk_v2(event,'sna.writerproposal');" href="https://joinus.comic.naver.com">
# 		<img src="https://ssl.pstatic.net/static/comic/images/bnr_joinus.jpg" width="240" height="86" alt="연재 경력 작가 웹툰 차기작 제안">
# 	</a>
# </div>
#
#
# <div class="asideBanner">
# 	<a href="https://comic.naver.com/contest/greatest/webtoon">
# 		<img src="https://ssl.pstatic.net/static/comic/images/bnr_contest_2022.jpg" width="240" height="86" alt="2022 지상최대공모전 - 접수 및 안내">
# 	</a>
# </div>
#
#
# <div class="asideBanner">
# 	<a onclick="nclk_v2(event,'sna.recruit');" href="https://recruit.webtoonscorp.com">
# 		<img src="https://ssl.pstatic.net/static/comic/images/bnr_careers.jpg" width="240" height="86" alt="웹툰 채용공고 CAREERS">
# 	</a>
# </div>
#
#
#
# <div class="asideButton">
# 	<a class="btn_faq" onclick="nclk_v2(event,'sna.faq')" href="https://help.naver.com/support/service/main.help?serviceNo=799"
# 	   target="_blank" title="새 창">
# 		<span class="blind">웹툰 고객센터</span>
# 	</a>
# </div>
#
#
# 				</div>
#
# 		</div>
#
# 		<!-- Footer -->
#
#
#
#
#
#
#
# <!-- FOOTER Start -->
# <div id="footer">
# 	<div class="list_link">
# 		<ul>
# 			<li class="link_site webtoon"><a href="/index" onClick="nclk_v2(event,'fot.webtoon')"><span class="blind">웹툰</span></a></li>
# 			<li class="link_site novel"><a href="https://novel.naver.com" onclick="nclk_v2(event,'fot.novel')"><span class="blind">웹소설</span></a></li>
# 			<li class="link_site series"><a href="https://series.naver.com" onclick="nclk_v2(event,'fot.series')"><span class="blind">시리즈 <span>소설·만화</span></span></a></li>
# 			<li class="link_site serieson"><a href="https://serieson.naver.com" onclick="nclk_v2(event,'fot.serieson')"><span class="blind">시리즈온 <span>영화·방송</span></span></a></li>
# 		</ul>
# 	</div>
# 	<div class="corp_info">
# 		<div class="webtoon_corp_info">
# 			<ul>
# 				<li><a href="https://member.webtoon.naver.com/policies/terms/" target="_blank" onclick="nclk_v2(event,'fot.wagreement')">네이버웹툰 이용약관</a></li>
# 				<li><a href="https://m.comic.naver.com/store/comic/common/passJoinAgreeContract" target="_blank" onclick="nclk_v2(event,'fot.cooterms')">전용상품권 이용약관</a></li>
# 				<li><a href="https://member.webtoon.naver.com/policies/privacy/" target="_blank" class="privacy" onclick="nclk_v2(event,'fot.wprivacy')">개인정보처리방침</a></li>
# 				<li><a href="https://member.webtoon.naver.com/policies/youthpolicy/" target="_blank" onclick="nclk_v2(event,'fot.youthpolicy')">청소년보호정책</a></li>
# 				<li><a href="https://help.naver.com/support/service/main.help?serviceNo=799" target="_blank" onclick="nclk_v2(event,'fot.whelp')">웹툰 고객센터</a></li>
# 			</ul>
# 			<ul>
# 				<li><a href="/business/proposalGuide" onClick="nclk_v2(event,'fot.proposal')" target="_blank" onclick="nclk_v2(event,'fot.proposal')">광고<span class="dot">·</span>사업문의</a></li>
# 			</ul>
# 			<address><a onclick="nclk_v2(event,'fot.wtcorp');" href="https://webtoonscorp.com" class="webtoon_corp_link" target="_blank"><span class="blind">ⓒ NAVER WEBTOON Limited</span></a></address>
# 		</div>
#
# 		<div class="naver_corp_info">
# 			<ul>
# 				<li><a href="https://www.naver.com/rules/service.html" onclick="nclk_v2(event,'fot.agreement')" target="_blank">이용약관</a></li>
# 				<li><a href="https://www.naver.com/rules/privacy.html" onclick="nclk_v2(event,'fot.privacy')" target="_blank" class="privacy">개인정보처리방침</a></li>
# 				<li><a href="https://www.naver.com/rules/disclaimer.html" onclick="nclk_v2(event,'fot.disclaimer')" target="_blank">책임의 한계와 법적고지</a></li>
# 				<li><a href="https://help.naver.com/support/home.help?serviceNo=799" onclick="nclk_v2(event,'fot.helpdesk')" target="_blank" title="새 창">고객센터</a></li>
# 				<li><a href="https://help.pay.naver.com/mail/form.help?alias=checkout_accuse" target="_blank" onclick="nclk_v2(event,'fot.claim')">결제도용신고</a></li>
# 			</ul>
# 			<ul>
# 				<li><a href="https://cpc.naver.com/cpc/index.nhn" target="_blank" onclick="nclk_v2(event,'fot.cpclaim')">저작권침해신고</a></li>
# 			</ul>
# 			<address><a href="https://www.navercorp.com/" target="_blank" onclick="nclk_v2(event,'fot.navercorp')"><span class="naver_corp_link"><span class="blind">ⓒ NAVER CORP.</span></span></a></address>
# 		</div>
# 	</div>
#
# 	<ul class="company_info">
# 		<li>사업자등록번호 669-86-01888</li>
# 		<li>통신판매업 신고번호 2020-성남분당B-0719 <a href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=6698601888" target="_blank">(사업자정보확인)</a></li>
# 		<li>대표이사 김준구</li>
# 		<li>호스팅사업자 네이버비즈니스플랫폼</li>
# 	</ul>
# 	<ul class="company_info">
# 		<li>주소 경기도 성남시 분당구 분당내곡로 117, 9층 (백현동, 크래프톤타워)</li>
# 		<li>고객센터 1588-3820</li>
# 		<li>이메일 <a href="mailto:ccnaver@naver.com">ccnaver@naver.com</a></li>
# 	</ul>
# 	<p class="copyright_law">모든 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단으로 이용하는 경우 관련 법령에 따라 법적 책임을 질 수 있습니다.</p>
# </div>
# <!-- //FOOTER End -->
#
# 	</div>
#
# 		<script type="text/javascript">
# 			var agent = navigator.userAgent.toLowerCase();
#
# 			function loadEvent(){
# 				try{
# 					getGNB();
# 				}catch(ex){
#
# 				}
# 				new naver.comic.RealtimeRankLayer();
# 				if ( $("uploadLinkId") ){
# 					$Fn(function(oEvent) {
# 						oEvent.stop();
# 						if ("true" != "false") {
# 							if (!confirm('로그인해야 이용할 수 있습니다. 로그인 하겠습니까?'))
# 								return false;
# 							else {
# 								location.href = "https://nid.naver.com/nidlogin.login?mode=form&url="
# 										+ encodeURIComponent("https://" + location.host
# 												+ "/upload/upload");
# 								return;
# 							}
# 						}
# 						location.href = "/upload/upload";
# 						return true;
# 					}).attach($("uploadLinkId"),"click");
# 				}
# 				naver.comic.oArtistAction = new naver.comic.Artist();
# 				artistAction = naver.comic.oArtistAction;
# 				naver.comic.oSearchBar = new naver.comic.SearchBarOptionActHandler();
#
# 				// GNB 이벤트 재정의.
# 				$Fn(function(oEvent){
# 					var aWtChild = $Element("gnb" ).child(function (v){return true;});
# 					var wtSrc = $Element(oEvent.element);
# 					var bContain = false;
# 					for (var i = 0 ; i < aWtChild.length ;i++){
# 						if ( aWtChild[i].$value() == wtSrc.$value()){
# 							bContain = true;
# 							break;
# 						}
# 					}
# 					if ( !bContain && gnbAllLayerClose ){
# 						gnbAllLayerClose();
#
# 					}
#
# 				}).attach(document,"click");
# 			}
# 			$Fn(loadEvent).attach(window,'load');
# 		</script>
#
#
#
#
#
#
#
# 				<script type="text/javascript" src="/aggregate/javascript/release/lcslog_20220714182726.js"></script>
#
#
# <script type="text/javascript">
#     try {
#         var eventType = "onpageshow" in window ? "onpageshow" : "onload";
#         var oldEvent = window[eventType];
#         window[eventType] = function() {
#             if (oldEvent) {
#                 oldEvent();
#             }
#             lcs_do();
#         };
#     } catch(ex) { }
# </script>
# 	</body>
#
#
# </html>

# %%
# Q. 'https://www.naver.com'에서 공지사항을 출력하세요.(find, 인덱싱)
import requests
import re
URL = 'https://www.naver.com'
html = requests.get(URL)
text = html.text
content = re.search('공지사항+',text)
print(content.group())
# Out:
# 공지사항

# %%
# Q. 'https://www.naver.com'에서 공지사항을 출력하세요.(정규표현식)
import re
import requests
URL = 'https://www.naver.com'
response = requests.get(URL)
content = response.text
body = re.search('<h3.*/h3>',content)
body = body.group()
body = re.sub('<.+?>', '', body)
print(body[:5])
# Out:
# 공지사항

# %%
# Q. URL = 'http://naver.com' 에서 split()함수와 정규표현식을 이용하여 ['메일', '카페', '블로그', '지식iN', '쇼핑']을 출력하세요
import requests
URL = 'http://naver.com'
response = requests.get(URL)
html_data = response.text
# print(html_data)
li = []
for i in range(5):
    result = html_data.split('<li class="nav_item">')[i+1]
#     print(result)
    word = re.sub('<.*?>','',result)
    word = re.sub(r'\n','',word)
    li.append(word)
print(li)
# Out:
# ['메일', '카페', '블로그', '지식iN', '쇼핑']

# %%
# json 형식의 데이터 가져오기
import requests
response = requests.get('https://raw.githubusercontent.com/naver/naver-openapi-guide/draft/naver-openapi-swagger.json')
result = response.json()
print(type(result))
print(result)
# Out:
# <class 'dict'>
# {'swagger': '2.0', 'info': {'description': 'Naver Open API - Restful spec. You can find out more about Naver Open API at [https://developers.naver.com](https://developers.naver.com)', 'version': '1.2.0', 'title': 'Naver Open API', 'termsOfService': 'https://developers.naver.com/products/terms'}, 'host': 'openapi.naver.com', 'basePath': '/', 'tags': [{'name': 'Clova', 'description': 'Naver A.I platform and APIs', 'externalDocs': {'description': 'Find out more', 'url': 'https://developers.naver.com/products/clova/cic'}}, {'name': 'Papago', 'description': 'Naver Machine Learning Translation APIs'}, {'name': 'Naver Login', 'description': 'Login with Naver Id'}, {'name': 'Naver Services', 'description': 'Naver data trend, search, shorten url, captcha APIs'}, {'name': 'Maps', 'description': 'Naver Mpas JS, geocode, static map APIs'}], 'schemes': ['https'], 'paths': {'/v1/vision/face': {'post': {'tags': ['Clova'], 'summary': 'Clova Face Recognition (얼굴감지)', 'description': '얼굴 이미지를 입력하면 얼굴 감지 결과를 리턴합니다.', 'operationId': 'vision.face', 'consumes': ['multipart/form-data'], 'produces': ['application/json'], 'parameters': [{'name': 'image', 'in': 'formData', 'description': '이미지', 'required': True, 'type': 'file'}], 'responses': {'200': {'description': 'OK'}}, 'security': [{'clientId': []}, {'clientSecret': []}]}}, '/v1/vision/celebrity': {'post': {'tags': ['Clova'], 'summary': 'Clova Face Recognition (유명인 얼굴인식)', 'description': '얼굴 이미지를 입력하면 유명인과의 닮은 정도를 리턴합니다.', 'operationId': 'vision.celebrity', 'consumes': ['multipart/form-data'], 'produces': ['application/json'], 'parameters': [{'name': 'image', 'in': 'formData', 'description': '이미지', 'required': True, 'type': 'file'}], 'responses': {'200': {'description': 'OK'}}, 'security': [{'clientId': []}, {'clientSecret': []}]}}, '/v1/voice/tts.bin': {'post': {'tags': ['Clova'], 'summary': 'Clova Speech Synthesis (음성합성)', 'description': '입력된 텍스트를 성우의 낭독 음성으로 합성해 주는 REST API입니다.', 'operationId': 'voice.tts', 'consumes': ['application/x-www-form-urlencoded'], 'produces': ['audio/mpeg'], 'parameters': [{'name': 'speaker', 'in': 'formData', 'description': '음성 합성할 목소리 설정: ( mijin:미진(한국어, 여성), jinho:진호(한국어, 남성), clara:클라라(영어,여성), matt:매튜(영어, 남성), yuri:유리(일본어, 여성), shinji:신지(일본어, 남성),  meimei:메이메이(중국어, 여성))', 'required': True, 'default': 'mijin', 'type': 'string'}, {'name': 'speed', 'in': 'formData', 'description': '-5 ~ 5 사이 정수로 -5면 0.5배 빠른, 5면 0.5배 느린, 0이면 정상 속도의 목소리로 합성', 'required': True, 'default': '0', 'type': 'string'}, {'name': 'text', 'in': 'formData', 'description': '음성합성할 문장이며 UTF-8만 지원', 'required': True, 'default': '음성합성 테스트 입니다.', 'type': 'string'}], 'responses': {'405': {'description': 'Invalid input'}}, 'security': [{'clientId': []}, {'clientSecret': []}]}}, '/v1/datalab/search': {'post': {'tags': ['Naver Services'], 'summary': 'Search-통합 검색어 트렌드', 'description': '입력된 주제어와 해당하는 검색어 그룹에 대하여 네이버 통합검색에 대한 기간별 트렌드 데이터를 리턴합니다.', 'operationId': 'search.datalab', 'consumes': ['application/json'], 'produces': ['application/json'], 'parameters': [{'in': 'body', 'name': '', 'description': '검색 정보 요청 JSON', 'required': True, 'schema': {'$ref': '#/definitions/DatalabSearchReq'}}], 'responses': {'405': {'description': 'Invalid input'}}, 'security': [{'clientId': []}, {'clientSecret': []}]}}, '/v1/search/{serviceid}': {'get': {'tags': ['Naver Services'], 'summary': 'Search-기본 검색', 'description': '네이버 블로그/뉴스/책/백과사전/카페글/지식iN/웹문서/이미지/쇼핑/전문자료/성인검색어 판별 /오타변환 대상 검색입니다. ', 'operationId': 'search.service', 'consumes': ['plain/text'], 'produces': ['application/xml', 'application/json'], 'parameters': [{'name': 'serviceid', 'in': 'path', 'description': '검색대상<br/> 블로그-> blog, 뉴스-> news, 책-> book, 백과사전->encyc, 카페글->cafearticle, 지식인->kin, 웹문서->webkr, 이미지->image, 쇼핑->shop, 전문자료->doc, 성인검색어 판별->adult, 오타변환->errata', 'required': True, 'default': 'blog', 'type': 'string'}, {'name': 'query', 'in': 'query', 'description': '검색어(UTF-8인코딩 필요)', 'required': True, 'default': '진주', 'type': 'string'}, {'name': 'display', 'in': ...

# %% [markdown]
# urllib 모듈이란: 파이썬의 표준 모듈로써 URL을 다루기 위한 모듈 패키지
# - 설치가 필요하지 않고 import urllib로 활용
# - requests 모듈과 마찬가지로 URL과 관련된 여러가지 기능들을 제공
#
# 하위모듈
# - request : URL을 열고 읽는 모듈(HTTP 요청)
# - error : request 모듈에서 발생하는 에러들을 포함하는 모듈
# - parse : URL을 파싱하는 모듈(URL 해석 및 조작)
# - robots.txt 파일을 파싱하는 모듈

# %%
# Request() : 해당 URL 요청 객체 생성, HTTPRequest 객체 반환
import urllib

URL = 'https://www.naver.com'
request = urllib.request.Request(URL)
print(request)
print(request.full_url)
print(request.type)
print(request.host)
# Out:
# <urllib.request.Request object at 0x00000264189DDD90>
# https://www.naver.com
# https
# www.naver.com

# %%
# urlopen() : 해당 url을 열기, 응답 데이터는 바이트 형식의 HTTPResponse 객체
# request 객체 또는 URL을 직접 넣어도 가능
response1 = urllib.request.urlopen(request)
response2 = urllib.request.urlopen(URL)
print(response1)
print(response2)
# Out:
# <http.client.HTTPResponse object at 0x0000026418A22D00>
# <http.client.HTTPResponse object at 0x0000026419610730>

# %%
print(response1.geturl())
print(response2.getheaders())
# Out:
# https://www.naver.com
# [('Server', 'NWS'), ('Date', 'Wed, 20 Jul 2022 07:18:34 GMT'), ('Content-Type', 'text/html; charset=UTF-8'), ('Transfer-Encoding', 'chunked'), ('Connection', 'close'), ('Set-Cookie', 'PM_CK_loc=16f435ae20111e81adcf36de4f939388faeaacd7ccf2bb6847a93eff29c72b72; Expires=Thu, 21 Jul 2022 07:18:34 GMT; Path=/; HttpOnly'), ('Cache-Control', 'no-cache, no-store, must-revalidate'), ('Pragma', 'no-cache'), ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"'), ('X-Frame-Options', 'DENY'), ('X-XSS-Protection', '1; mode=block'), ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains'), ('Referrer-Policy', 'unsafe-url')]

# %%
# read() : 인자로 전달한 숫자만큼 데이터를 읽음
# readlines() : 홈페이지 데이터를 줄 단위로 읽어 리스트에 반환
import urllib
url = 'https://www.naver.com'
response = urllib.request.urlopen(URL)
print(response,'\n')
print(response.getheaders(),'\n')
print(response.geturl(),'\n')

print(response.read(30))
print(response.read(10))
print(response.read(10))
print(response.read())
# Out:
# <http.client.HTTPResponse object at 0x0000020A81BE70A0>
#
# [('Server', 'NWS'), ('Date', 'Tue, 08 Feb 2022 12:26:40 GMT'), ('Content-Type', 'text/html; charset=UTF-8'), ('Transfer-Encoding', 'chunked'), ('Connection', 'close'), ('Set-Cookie', 'PM_CK_loc=e9ae7035375476e944775f7f3048dbf20246eff2691ab6ccabb51b1a2a19485a; Expires=Wed, 09 Feb 2022 12:26:40 GMT; Path=/; HttpOnly'), ('Cache-Control', 'no-cache, no-store, must-revalidate'), ('Pragma', 'no-cache'), ('P3P', 'CP="CAO DSP CURa ADMa TAIa PSAa OUR LAW STP PHY ONL UNI PUR FIN COM NAV INT DEM STA PRE"'), ('X-Frame-Options', 'DENY'), ('X-XSS-Protection', '1; mode=block'), ('Strict-Transport-Security', 'max-age=63072000; includeSubdomains'), ('Referrer-Policy', 'unsafe-url')]
#
# https://www.naver.com/
#
# b'\n<!doctype html>              '
# b'          '
# b'  <html la'
# b'ng="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20220127.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function t(){}return t.prototype=n,new t})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING ...

# %%
import urllib
url = 'https://www.naver.com'
response = urllib.request.urlopen(URL)
print(response.read(500).decode('utf-8'))
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m

# %%
# 바이트 형식의 데이터를 원하는 형식으로 변환
import urllib
URL = "https://www.naver.com"
response = urllib.request.urlopen(URL)
byte_data = response.read(500)
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m

# %%
# urllib.request.urlretrieve() : 웹 상의 이미지를 저장
import urllib.request
img_src = 'https://homepages.cae.wisc.edu/~ece533/images/tulips.png'
new_name = 'img.png'
urllib.request.urlretrieve(img_src,new_name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x26ba64c89a0>)

# %%
# 단순한 패턴을 읽을 때에는 복잡한 정규표현식보다는 간단한 parse 모듈을 사용
# urllib.parse : URL을 6개로 분리하여 반환
import urllib
parse = urllib.parse.urlparse('https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai')
print(parse)
print(parse[0])
print(parse.scheme)
print(parse[1])
print(parse.netloc)
print(parse[2])
print(parse.path)
print(parse[3])
print(parse.params)
print(parse[4])
print(parse.query)
print(parse[5])
print(parse.fragment)
print(parse[:5])
# Out:
# ParseResult(scheme='https', netloc='section.blog.naver.com', path='/Search/Post.naver', params='', query='pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai', fragment='')
# https
# https
# section.blog.naver.com
# section.blog.naver.com
# /Search/Post.naver
# /Search/Post.naver
#
#
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai
#
#
# ('https', 'section.blog.naver.com', '/Search/Post.naver', '', 'pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai')

# %%
import urllib
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse)
print(parse[0])
print(parse.scheme)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
# https
# https

# %%
# 튜플(변경 불가능)로 반환되기 때문에 리스트(변경 가능)로 변경하여 활용
import urllib
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse,'\n')
parse = list(parse)
parse[1] = 'blog.daum.net'
unparse = urllib.parse.urlunparse(parse)
print(unparse)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
#
# https://blog.daum.net/koreatech91;a=1?b=2#b

# %%
# urllib.parse.urlsplit() : url을 5개로 분리하여 반환
parse1 = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse1,'\n')
parse2 = urllib.parse.urlsplit('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse2)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
#
# SplitResult(scheme='https', netloc='blog.naver.com', path='/koreatech91;a=1', query='b=2', fragment='b')

# %%
# urllib.parse.urlunparse(), urllib.parse.urlunsplit() 
# 분리된 url을 다시 합침. 튜플로 반환되기 때문에 리스트로 변경하여 활용
parse1 = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse1[1])
parse1 = list(parse1)
parse1[1] = 'blog.daum.net'
unparse1 = urllib.parse.urlunparse(parse1)
print(unparse1,'\n')

parse2 = urllib.parse.urlsplit('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse2[1])
parse2 = list(parse2)
parse2[1] = 'blog.daum.net'
unparse2 = urllib.parse.urlunsplit(parse2)
print(unparse2)
# Out:
# blog.naver.com
# https://blog.daum.net/koreatech91;a=1?b=2#b
#
# blog.naver.com
# https://blog.daum.net/koreatech91;a=1?b=2#b

# %%
# parse_qs(), parse_qs1()
# 쿼리를 파싱해서 사전(qs) 및 리스트(qsl)로 반환. 쿼리를 변경하여 요청시 활용
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse)
print(parse.query)
qs = urllib.parse.parse_qs(parse.query)
print(qs)
print(type(qs))

qsl = urllib.parse.parse_qsl(parse.query)
print(qsl)
print(type(qsl))
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
# b=2
# {'b': ['2']}
# <class 'dict'>
# [('b', '2')]
# <class 'list'>

# %%
# urljoin(a,b) : a와 b URL을 합쳐주는 기능. '/'에 따라 URL 주소가 달라짐
url = 'https://naver.com/a/b'
print(urllib.parse.urljoin(url,'c'))
print(urllib.parse.urljoin(url,'/c'))
# Out:
# https://naver.com/a/c
# https://naver.com/c

# %%
url = 'https://naver.com/a/b/'
print(urllib.parse.urljoin(url,'c'))
print(urllib.parse.urljoin(url,'/c'))
# Out:
# https://naver.com/a/b/c
# https://naver.com/c

# %%
from bs4 import BeautifulSoup
import requests
import re

URL = 'https://search.naver.com/search.naver?query="파이썬"'
req = requests.get(URL)
soup = BeautifulSoup(req.text,'html.parser')
soup = str(soup)
item = re.findall('[가-힣]+',soup)
m = ' '.join(item)
m
# Out:
# '파이썬 네이버 통합검색 파이썬 의 네이버 통합검색 결과입니다 파이썬 의 네이버 통합검색 결과입니다 파이썬 네이버 통합검색 파이썬 파이썬 메뉴 영역으로 바로가기 본문 영역으로 바로가기 검색 검색어를 입력해 주세요 파이썬 파이썬 한글 입력기 네트워크 상태가 안 좋아 한영입력기를 불러오지 못했습니다 잠시 후 다시 시도해 주세요 자동완성 레이어 최근검색어 전체삭제 삭제 검색어 저장 기능이 꺼져 있습니다 설정이 초기화 된다면 도움말 을 확인해주세요 최근 검색어 내역이 없습니다 설정이 초기화 된다면 도움말 을 확인해주세요 도움말 자동저장 끄기 회차 당첨번호 추첨 지급기한 년 원 바로가기 추가 추가 추가 자세히보기 관심사를 반영한 컨텍스트 자동완성 도움말 컨텍스트 자동완성 컨텍스트 자동완성 설정은 해당기기 브라우저 에 저장됩니다 자세히 동일한 시간대 연령 남녀별 사용자 그룹의 관심사에 맞춰 자동완성을 제공합니다 로그인 자세히 컨텍스트 자동완성 레이어 닫기 도움말 신고 자동완성 끄기 검색 통합 이미지 지식 인플루언서 동영상 쇼핑 뉴스 어학사전 지도 더보기 도서 뮤직 지식백과 오디오클립 학술정보 검색옵션 통합검색 공유 통합검색 파이썬 통합검색 결과 파이썬 검색옵션 닫기 정렬 관련도순 최신순 기간 전체 시간 일 주 개월 개월 개월 년 직접입력 옵션 펼치기 접기 기간 설정시작 기간 설정끝 년 월 일 적용 옵션초기화 검색옵션 가이드 의 경로 지정 은 의 별로 호출해야함 클릭로그 호출 파이썬 이 정확하게 일치한 상세검색 결과입니다 일반검색 결과보기 문서 저장하기 에 저장 바로가기 번역보기 의 경로 지정 은 의 별로 호출해야함 전체 블로그 카페 뷰타입 필터를 선택하세요 기본뷰 타임라인뷰 멀티미디어뷰 문서 저장하기 에 저장 바로가기 일 전 난장이 좋은 캠핑러 파이썬 교육 기초부터 실무 연습까지 또 최근에는 많은 성인분들도 코딩의 기본부터 세밀하게 배울 수 있는 파이썬 교육에 집중을 하고 있습니다 사실 코딩을 위한 교육은 꼭 파이썬 교육이 아니더라도 분야가 다양했는데 기본적으로 자바 언어 빅데이터 이미지준비중 문서 저장하기 에 저장 바로가기 마마 리사킴의 유쾌한 일상 이야기 파이썬 자격증 입문자 취업준비의 좋은선택 어떻게든 되겠지 하는 마음으로 우선은 파이썬 자격증을 취득해 보기로 했는데요 빅데이터에서 기초가 되는 부분이 파이썬 이었기 때문에 우선적으로 한 번 배워보고 가능하면 자격증까지 취득하면 좋으니 도전하게 이미지준비중 문서 저장하기 에 저장 바로가기 루윙코치 교육정보 육아일상 파이썬 자격증 확실한 취득방법 시험 프로그램 버전은 버전으로 진행되었습니다 학원에 있는 모든 컴퓨터에는 해당 버전으로 프로그램이 설치 되어 있었어요 파이썬 수업과정 확실히 체계가 잘 잡혀 있다는 것을 알게 된 건 아무래도 수업 이미지준비중 파이썬강의 파이썬책 문서 저장하기 에 저장 바로가기 호박공주맘의 시시콜콜 파이썬 학원 실습 위주의 수업이 포인트 총 주차에 걸치는 파이썬 학원의 수업의 커리큘럼은 다음과 같았어요 변수 자료형 연산자 랜덤문과 반복문으로 의 기본 명령어를 익히면서 차원과 차원 그리고 문자열로 넘어가 인덱싱 그리고 슬라이싱을 이미지준비중 함께 볼만한 검색어 이 정보가 표시된 이유 문서를 기반으로 함께 볼만한 검색어를 분석하여 제공하는 서비스입니다 피드백 제공하기 도움말 정보확인 레이어 닫기 이미지준비중 메가스터디 아카데미 강남캠퍼스 함께 볼만한 검색어 닫기 문서 저장하기 에 저장 바로가기 최신 트랜드와 지식창고 파이썬 학원 초보자를 위한 교육과정 친구에게 여러 가지 질문을 한 끝에 파이썬 학원을 저도 다녀봐야겠다는 확신을 얻을 수 있었습니다 사실 그래서 파이썬 학원을 검색하기 시작했습니다 어떤 곳이 좋은지 몰랐기에 친구에게 물어봤는데요 제가 찾아간 이미지준비중 문서 저장하기 에 저장 바로가기 부스트코스 모집마감 뜨거운 여름 전국 어디서나 시원하게 파이썬 스터디 본 스터디는 년 월 일 수 시를 기준으로 모집 마감되었습니다 이번 여름에도 어김없이 찾아온 부스트코스 코칭스터디 모두를 위한 파이썬 를 소개합니다 요즘 신입사원 직장인의 필수 이미지준비중 부스트코스 온라인 무료 스터디 비전공자 파이썬 코딩공부 코칭스터디 문서 저장하기 에 저장 바로가기 눈 내 위 의 뚝 딱 공 작 소 파이썬 교육 필수과목 체계적으로 배워보기 빠르고 효율적으로 배울 수 있는 과정이 뭐가 있을까 고민하다가 문과는 파이썬 교육부터 시작하는 것이 대부분의 학교에서 필수 과목으로 파이썬 교육을 들어야 하는데 저는 그 시기가 아니라 따로 배워야 했습니다 이미지준비중 더보기 로딩중 정보를 가져오는 중입니다 검색결과가 없습니다 옵션을 재선택 하시거나 초기화 해보시기 바랍니다 초기화 죄송합니다 일시적인 오류입니다 잠시 후 다시 시도해주십시오 재시도 문서 저장하기 에 저장 바로가기 나무위키 년에 발표된 인터프리터 방식의 프로그래밍 언어다 영어와 비슷해서 읽고 쓰기 쉬운 특유의 문법과 그로 인해 전 세계의 개발자들로부터 만들어진 수많은 패키지들 덕분에 사용할 수 있는 용도가 무궁무진해져 년대 중반부터 주류 프로그래밍 언어로 당당히 올라서게 되었다 개요 상세 특징 장점 단점 파이썬 구현체 개발 환경 주요 패키지 문법 학습 문서 저장하기 에 저장 바로가기 파이썬 의 특징 점프 투 파이썬 필자는 파이썬 을 무척 좋아한다 모든 프로그래밍 언어에는 각기 장점이 있지만 파이썬 에는 다른 언어에서는 쉽게 찾아볼 수 없는 파이썬 만의 독특한 매력이 있다 파이썬 의 특징을 문서 저장하기 에 저장 바로가기 점프 투 파이썬 점프 투 파이썬 오프라인 책 개정판 출간 책 구입 안내 이 책은 파이썬 문서 저장하기 에 저장 바로가기 파이썬 둘러보기 점프 투 파이썬 도대체 파이썬 이라는 언어는 어떻게 생겼는지 간단한 코드를 작성하며 알아보자 파이썬 을 자세히 탐구하기 전에 전체 모습을 죽 훑어보는 것은 매우 유익한 일이 될 것이다 검색결과 더보기 의 경로 지정 은 의 별로 호출해야함 인라인 스크립트 연속되는 섹션 요소인지 검사한다 동영상 이 정보가 표시된 이유 검색 대상 기준 동영상 검색은 네이버의 동영상 서비스뿐 아니라 수집이나 제휴를 통해 외부 서비스의 동영상을 검색 결과로 제공합니다 동영상 재생 섬네일이나 제목을 클릭하면 영상을 바로 재생하거나 원본 페이지로 이동할 수 있습니다 네이버앱에서 네이버 출처는 전용 앱 뷰어로 재생됩니다 장면 탐색 학습을 사용하여 동영상에 대한 챕터를 자동으로 생성합니다 챕터가 확인되는 영상은 바로 재생됩니다 자세히 보기 장면 탐색 제외 요청하기 네이버 고객센터 안내 정보확인 레이어 닫기 최신 파이썬 코딩 무료 강의 시간만 투자하면 개발자가 됩니다 동영상 바로재생 버튼 재생시간 문서 저장하기 신고된 영상입니다 신고하기 에 저장 바로가기 최신 파이썬 코딩 무료 강의 시간만 투자하면 개발자가 됩니다 최신 파이썬 코딩 무료 강의 시간만 투자하면 개발자가 됩니다 조코딩 조코딩 개월 전 파이썬 왕초보 기초 강의 동영상 바로재생 버튼 재생시간 문서 저장하기 신고된 영상입니다 신고하기 에 저장 바로가기 파이썬 왕초보 기초 강의 파이썬 왕초보 기초 강의 알지오 평생교육원 알지오 평생교육원 일 전 파이썬 왕초보 기초 강의 동영상 바로재생 버튼 재생시간 문서 저장하기 신고된 영상입니다 신고하기 에 저장 바로가기 파이썬 왕초보 기초 강의 파이썬 왕초보 기초 강의 알지오 평생교육원 알지오 평생교육원 일 전 파이썬 코딩 무료 강의 기본편 시간 뒤면 여러분도 개발자가 될 수 있어요 나도코딩 동영상 바로재생 버튼 재생시간 문서 저장하기 신고된 영상입니다 신고하기 에 저장 바로가기 파이썬 코딩 무료 강의 기본편 시간 뒤면 여러분도 개발자가 될 수 있어요 나도코딩 파이썬 코딩 무료 강의 기본편 시간 뒤면 여러분도 개발자가 될 수 있어요 나도코딩 나도코딩 나도코딩 년 전 동영상 더보기 빈텍스트상자 빈프레임 동영상 바로재생 닫기 닫기 동영상 바로재생 닫기 닫기 알림 일시적인 오류가 발생하였습니다 잠시 후 다시 시도해주십시오 새로고침 광고포함 광고 재생 중 상위 클래스 엘리먼트 지정 필요 지식 지식 에 물어보기 문서 저장하기 에 저장 바로가기 파이썬 코드 오류 파이썬 으로 그래프 그리려고 하는데 대체 왜 오류가 뜨는 걸까요 와 상담 코 ...

# %%
# quote(), unquote() : 아스키코드가 아닌 퍼센트 인코딩으로 변환
# 퍼센트 인코딩(percent-encoding)은 URL에 문자를 표현하는 문자 인코딩 방법
# url에 한글이 섞이면 오류 발생
import urllib
print(urllib.parse.quote('파이썬'))
print(urllib.parse.unquote('%ED%8C%8C%EC%9D%B4%EC%8D%AC'))
URL = 'https://search.naver.com/search.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC'
# URL = 'https://search.naver.com/search.naver?query="파이썬"'
response = urllib.request.urlopen(URL)

byte_data = response.read()
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# %ED%8C%8C%EC%9D%B4%EC%8D%AC
# 파이썬
# <!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="파이썬 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'파이썬'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'파이썬'의 네이버 통합검색 결과입니다."> <title>파이썬 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_220728.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_220804.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie ...
#
#
#
#  <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <section class="sc_new sp_nbook _prs_bok_lst _nshopping_book_pc"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nbook_220721.css"> <div class="api_subject_bx"> <div class="api_title_area _modal_wrapper"> <h2 class="api_title">네이버 도서<div class="api_title_inner"><a role="button" href="#" class="api_link_help _trigger" aria-pressed="false" onclick="return tCR('u=javascript&r=&i=&a=bok_lst.help1');"><i class="spnew api_ico_alert">이 정보가 표시된 이유</i></a> <div class="ly_api_info _modal_content"> <p class="dsc">네이버가 운영하는 도서 서비스입니다.</p> <button type="button" class="btn_close _trigger" onclick="return tCR('u=javascript&r=&i=&a=bok_lst.help1close');"><i class="spnew ico_close">정보확인 레이어 닫기</i></button> </div> </div> </h2> <div class="api_title_sub"> <div class="api_sub_link"> <span class="etc_txt">다른 사이트를 보시려면 클릭하세요</span><a href="?where=web&sm=tab_bok&query=%EB%8F%84%EC%84%9C%EA%B0%80%EA%B2%A9%EB%B9%84%EA%B5%90%EC%82%AC%EC%9D%B4%ED%8A%B8+-%EB%84%A4%EC%9D%B4%EB%B2%84" class="other_link" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=&i=&a=bok_lst.sitemore');">다른 사이트 더보기</a> </div> </div> </div> <div class="api_tab_wrap _tab_root" data-type="conveyer"> </div> <div class="_content_root"> <div class="book_list _content" style="display: block;"> <div class="_total_list"> <ul class="list_area"> <li class="item"><a href="https://cr3.shopping.naver.com/bridge/book/searchGate?cat_id=50010920&frm=PBOKPRO&h=86b986953cabdcee6664f65f306618cbf986f9d5&nv_mid=33275494626&query=%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC&t=L6J7Z35N" class="thumb_wrap" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=1&i=2533308065890530&a=bok_lst.cimg');"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fshopping-phinf.pstatic.net%2Fmain_3327549%2F33275494626.20220716093824.jpg&type=w216" alt="파이썬 자동화 교과서 (업무 생산성을 3배 높이는 엑셀, 워드, 크롤링, 메일 자동화 기술)" width="108" height="156" class="thumb api_get" onerror="this.src='...';this.className='bg_nimg2';this.alt='이미지준비중';"/></a><div class="info_wrap"><div class="info_area"><a href="https://cr3.shopping.naver.com/bridge/book/searchGate?cat_id=50010920&frm=PBOKPRO&h=86b986953cabdcee6664f65f306618cbf986f9d5&nv_mid=33275494626&query=%25ED%258C%258C%25EC%259D%25B4%25EC%258D%25AC&t=L6J7Z35N" class="item_title" target="_blank" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&r=1&i=2533308065890530&a=bok_lst.ctitle');">파이썬 자동화 교과서 (업무 생산성을 3배 높이는 엑셀, 워드, 크롤링, 메일 자동화 기술)</a><span class="item_rank">컴퓨터/IT 99위</span><div class="book_info"><div class="info writer"><span class="title">저자</span>구지라 히코즈쿠에</div><div class="info publish"><span class="title">출판</span>제이펍</div><div class="info date">2022.07.19.</div></div></div><div class="shop_area"><div class="shop_box"><div class="title">도서</div><a href="https://cr3.shopping.naver.com/bridge/book/searchGate?cat_id=50010920&frm=PBOKPRO&h=86b986953cabdcee6664f65f306618cbf986f9d5&nv ...
#   <script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/js/220616/power_link_for_you_responsive_pc.js?o=search"></script>
#   <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
#   <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220622/css/nx_powerlink.css" rel="stylesheet" type="text/css">
#   <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css">
#   <div class="ad_section section _pl_section bg_type_v2">
#     <div class="section_head nx_power"><h2>파워링크</h2>
#
#       <div class="dsc_ncaution">
#         <span><em class="dsc_ncaution_quotation">&lsquo;</em><strong class="dsc_ncaution_keyword">파이썬</strong><em
#                 class="dsc_ncaution_quotation">&rsquo;</em></span>
#         <span class="dsc_ncaution_text">관련 광고입니다.</span>
#         <a href="javascript:void(0);" class="ico_ad_dsc"
#            title="이 광고가 표시된 이유" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">이 광고가 표시된 이유</a>
#
#         <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
#
#           <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704" class="link_help">도움말</a></p>
#           <button type="button" class="bt_ad_clse">안내 레이어 닫기</button>
#         </div>
#       </div>
#       <a href="//saedu.naver.com/adbiz/searchad/intro.nhn" class="go_register space" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));">등록 안내</a>
#     </div>
#     <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
#       <ul class="lst_type">
#         <li class="lst  type_more     type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="0">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=fHgutR9FpEFOcKcm5Euz2P///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000195153166&amp;d=&#39;+urlencode(&#39;http://www.choongang.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMTA4MDZfMjMx/MDAxNjI4MjMxNDU2NzI5.vDmmp1j8BzQ4MNmD7yWzFzKP078asv6UOXCw8MvPyqYg.DQo0GcNKfj9eoNrXPk2QPkztmfSOMRBnO5yOBueWiOgg.PNG/2318894-3a05d8a6-ec35-485b-8022-ae9427796d6c.png?type=f160_160" width="100%" height="100%">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=7AXBaQw3lFC6vHASVglH9f///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000195153166&amp;d=&#39; + urlencode(&#39;http://www.choongang.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#
#                 <span class="lnk_tit">52년 역사 중앙정보처리학원</span>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=7AXBaQw3lFC6vHASVglH9f///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000195153166&amp;d=&#39;+urlencode(&#39;http://www.choongang.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.choongang.co.kr/</a>
#             </div>
#             <p class="ad_dsc">
#
#               Since1969 고용노동부 최우수 훈련기관 선정! 전액 국비지원 IT취업연계교육
#
#             </p>
#
#
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle ext_link   type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="1">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=uQckwmLxl41Ji4xVnIMsEP///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAxOTAzMDdfMjgy/MDAxNTUxOTM2MDY0NTU2.FjwQIJIffEpRVFxkKfsX8ZkFqRAFA77Kn1MAzB3OoHYg.mvX2GE-aldtCDVYLoZIatyhk-mrZTc0YEPIuRAyyhbUg.JPEG/699114-6d89b46c-8f64-4320-94b2-49480d718570.jpg?type=f160_160" width="100%" height="100%">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=v/9GVKQNy3L8vUuNV3gerf///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39; + urlencode(&#39;http://www.greenart.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#                 <span class="lnk_tit">그린컴퓨터아트학원공식홈페이지</span><span class="lnk_tit">고용노동부지정 우수훈련기관</span>
#
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#               <span class="ico_area">
#
#                 <span class="ico">
#                   <span class="sp_nad ico_nlogin" tabindex="0"
#                         onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                         onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                         onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                         onBlur="NAVER.SEARCH_AD.hideTooltip(this);">네이버 로그인</span>
#                   <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                      style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                      onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                      onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                      onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;u=&#39;+urlencode(this.href));">
#                     <span class="ly_box">
#                       <span>네이버 아이디로 로그인이 가능합니다.</span>
#                       <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
#                     </span>
#                   </a>
#                 </span>
#
#
#               </span>
#               <a href="https://adcr.naver.com/adcr?x=v/9GVKQNy3L8vUuNV3gerf///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.greenart.co.kr</a>
#             </div>
#             <p class="ad_dsc">
#
#               사회공헌대상 고용노동부 장관상수상, 취준생&직장인 국비 최대 100%, <strong class='hl'>파이썬</strong>
#
#             </p>
#
#             <ul class="lst_link">
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=r+SiKXocInq4EuCZkn5+9f///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">국비지원안내</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=N+fqAtFvHDshJxYIouIqwv///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">추천교육과정</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=zk3KKLiD0xKZRj17DYvWpv///w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">수강료조회</a>
#                 </li>
#
#                 <li class="item">
#                   <a class="link" href="https://adcr.naver.com/adcr?x=Ezb6a3dU6fcJFkPaEUj++////w==..." target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=2&amp;i=nad-a001-01-000000175135458&amp;d=&#39;+urlencode(&#39;http://www.greenart.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">지점조회</a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst  type_more type_subtitle    type_img "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#
#           <a class="lnk_thumb"
#              href="https://adcr.naver.com/adcr?x=y1CdEAzh6vnSthAZKaBVMP///w==..."
#              target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000186404429&amp;d=&#39;+urlencode(&#39;https://www.udemy.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#             <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMTExMjlfMjQg/MDAxNjM4MTY0NzY0NTUw.z-PlmeEKSSIWhJh67iGmsEDdWx2m_3N4CmVUz8Ggb8kg.sh9UYWzMV0USI_MPEEJQDwXn99ieE9uh2qQ_LicXyC4g.JPEG/468960-55b745b2-b506-42a6-9e40-7418320817b8.jpg?type=f160_160" width="100%" height="100%">
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=EODAoSZu5itZRf0/oQeMl////w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000186404429&amp;d=&#39; + urlencode(&#39;https://www.udemy.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#                 <span class="lnk_tit">파이썬 시작하기, 유데미</span><span class="lnk_tit">글로벌 베스트 강의 추천</span>
#
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_ad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=EODAoSZu5itZRf0/oQeMl////w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000186404429&amp;d=&#39;+urlencode(&#39;https://www.udemy.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.udemy.com</a>
#             </div>
#             <p class="ad_dsc">
#
#               글로벌 전문가의 <strong class='hl'>파이썬</strong> 강의 오직 유데미에서만, 5천 2백만 수강생 인증
#
#             </p>
#
#
#
#
#
#           </div>
#         </li>
#       </ul>
#       <div class="section_more">
#         <a class="go_site"
#            target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&amp;referenceId=hX%2BWrwp0YihsslAqpowssssstQ4-414567" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">
#           더보기<i class="icon_arrow sp_nad"></i></a>
#       </div>
#     </div>
#
#
#   </div>
#
#
#
#
# <link rel="stylesheet" href="https://ssl.pstatic.net/adimg3.search/imp/nx/libs/egjs-flicking/4.4.2/flicking-inline.css" />
# <link rel="stylesheet" href="https://ssl.pstatic.net/adimg3.search/imp/nx/libs/egjs-flicking-plugins/20220228/flicking-plugins.min.css">
#
# <div class="ad_section section" id="_power_link_together_section" style="display: none" data-responsive-json="{&quot;aq&quot;:0,&quot;ssc&quot;:&quot;tab.nx.all&quot;,&quot;apiUrl&quot;:&quot;https://external.impression-neo.naver.com/api/v1/powerLinkForYou/responsive/ads/search&quot;,&quot;requestId&quot;:&quot;hX+Wrwp0YihsslAqpowssssstQ4-414567&quot;,&quot;query&quot;:&quot;파이썬&quot;,&quot;channel&quot;:&quot;naver.search.pc.pl.responsive&quot;,&quot;sm&quot;:null,&quot;adCreativeIds&quot;:[&quot;nad-a001-01-000000195153166&quot;,&quot;nad-a001-01-000000175135458&quot;,&quot;nad-a001-01-000000186404429&quot;]}">
#     <div class="section_head power_together">
#         <h2 class="together_head">함께 찾은 파워링크</h2>
#         <div class="beta_tag">
#             <span class="blind">beta</span>
#         </div>
#
#         <div class="space">
#             <div class="dsc_ncaution">
#                 <span>
#                   <em class="dsc_ncaution_quotation">‘</em>
#                   <strong class="dsc_ncaution_keyword" id="_together_search_keyword"></strong>
#                   <em class="dsc_ncaution_quotation">’</em>
#                 </span>
#                 <span class="dsc_ncaution_text">관련 광고입니다.</span>
#                 <a class="ico_ad_dsc together_caution_icon" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
#
#                 <div class="ly_ad_dsc type_simple type_right together_caution_layer" style="display:none; z-index: 121;">
#                     <p>최근에 클릭한 파워링크를 토대로 <br>선호할 만한 파워링크를 노출합니다.</p>
#                     <button type="button" class="bt_ad_clse together_caution_close">안내 레이어 닫기</button>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="nad_area power_together">
#         <div id="_together_ad_flicking" class="together_content_area flicking-viewport">
#             <ul id="_together_list" class="together_list flicking-camera">
#             </ul>
#
#             <button id="_together_prev_button" class="prev_button" style="z-index: 1;">
#                 <span class="blind">이전으로 이동</span>
#             </button>
#             <button id="_together_next_button" class="next_button" style="z-index: 1;">
#                 <span class="blind">다음으로 이동</span>
#             </button>
#         </div>
#     </div>
#     <div class="lst_type_v2" id="map_layer" style="display: none;">
#         <div class="lst">
#           <div class="ly_map _preview_layer" style="top: 0px !important;" id="_preview_layer">
#             <h4 class="sp_ad_map m_tit">위치 미리보기</h4>
#             <div id="map" class="map_area" width="375" height="312">
#               <div id="map" style="position: relative; overflow: hidden; background: url('https://ssl.pstatic.net/static/maps/mantle/1x/pattern_1.png') 0px 0px repeat transparent; width: 375px; height: 312px;"></div>
#               <span class="bd"><span class="bd_top"></span><span class="bd_rgt"></span><span class="bd_btm"></span><span class="bd_lft"></span></span>
#             </div>
#             <div class="tit_area">
#               <div class="tit_sec">
#                   <!-- <span class="thumb">
#                       <img src="" width="49" height="36" id="preveiw_img" alt="리츠펫 프랜차이즈 본사"/>
#                           <span class="v"></span>
#                           <span class="bd"></span>
#                   </span> -->
#                   <h4 class="tit">
#                       <a target="_blank" id="preview_headline" href="" onclick="" class="txt"></a>
#                       <a target="_blank" id="preview_find_map" href="" onclick="" class="sp_ad_map ico_find_road">길찾기</a>
#                   </h4>
#                   <div class="m_url">
#                       <a target="_blank" id="preview_display_url" href="" onclick="" class="txt"></a>
#                   </div>
#               </div>
#               <div class="info_sec">
#                   <div class="address">
#                       <p class="txt" id="preveiw_number_address"></p>
#                       <p class="txt">
#                           <span class="sp_ad_map ico_road_name"><span class="blind">도로명 주소</span></span> <span id="preview_road_address"></span>
#                       </p>
#                   </div>
#                   <div class="dsc"></div>
#               </div>
#           </div>
#             <a href="javascript:;" class="sp_ad_mall btn_clse" id="map_btn_clse" title="미리보기 닫기">닫기</a>
#             </div>
#         </div>
#       </div>
# </div>
#
#
#   <div class="api_sc_page_wrap"> <div class="sc_page"> <a role="button" class="btn_prev" aria-disabled="true"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a href="?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&sm=tab_pge&where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&r=1&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="true">1</a> <a href="?display=15&f=&filetype=0&page=2&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=1&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=2&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">2</a> <a href="?display=15&f=&filetype=0&page=3&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=16&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=3&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">3</a> <a href="?display=15&f=&filetype=0&page=4&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=31&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=4&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">4</a> <a href="?display=15&f=&filetype=0&page=5&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=46&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=5&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">5</a> <a href="?display=15&f=&filetype=0&page=6&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=61&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=6&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">6</a> <a href="?display=15&f=&filetype=0&page=7&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=76&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=7&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">7</a> <a href="?display=15&f=&filetype=0&page=8&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=91&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=8&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">8</a> <a href="?display=15&f=&filetype=0&page=9&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=106&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=9&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">9</a> <a href="?display=15&f=&filetype=0&page=10&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=121&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=10&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn" aria-pressed="false">10</a> </div> <a href="?display=15&f=&filetype=0&page=11&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&research_url=&sm=tab_pge&start=1&where=web" onclick="return goOtherCR(this, 'a=pag.pag&r=11&i=&u='+urlencode(this.href ? this.href : location.href))" role="button" class="btn_next" aria-disabled="false"><i class="spnew ico_page_arr">다음</i></a> </div> </div> </div><div id="sub_pack" class="sub_pack"><section class="sc_new sp_nkeyword" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a href="https://help.naver.com/support/alias/search/word/word_1.naver" class="api_link_help" onclick="return goOtherCR(this, 'a=rsk_top.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><i class="spnew api_ico_help">도움말</i></a></h2> <div class="api_title_sub"> <a href="https://help.naver.com/support/alias/search/word/word_2.naver" class="btn_report" onclick="return goOtherCR(this, 'a=rsk_top.report&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><span class="txt">신고</ ...

# %%
# 홈페이지를 로컬에 파일로 저장
import urllib

request = urllib.request.Request('http://www.naver.com')
data = urllib.request.urlopen(request).read()
f = open('pc.html', 'wb')
f.write(data)
f.close()

# %%
with open('pc.html','rb') as f:
    data = f.read().decode('utf-8')
    print(data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20210601a.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>document.domain="naver.com",window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent;window.nmain.isIE=navigator.appName&&navigator.appName.indexOf("Explorer")>0&&ua.toLocaleLowerCase().indexOf("msie 10.0")<0,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function a(){}return a.prototype=n,new a})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script> <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"ANIMAL":{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000161","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_1","tb":"ANIMAL_1","unit":"SU10567","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000162","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_2","tb":"ANIMAL_1","unit":"SU10568","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BUSINESS":{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000165","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_1","tb":"BUSINESS_1","unit":"SU10577","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000166","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_2","tb":"BUSINESS_1","unit":"SU10578","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"CARGAME":{"menu":"CARGAME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000167","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_1","tb":"CARGAME_1","unit":"SU10587","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000168","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_2","tb":"CARGAME_1","unit":"SU10588","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"CHINA":{"menu":"CHINA","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000169","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_1","tb":"CHINA_1","unit":"SU10591","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000170","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_2","tb":"CHINA_1","unit":"SU10592","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"DESIGN":{"menu":"DESIGN","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000171","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_1","tb":"DESIGN_1","unit":"SU10569","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000172","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_2","tb":"DESIGN_1","unit":"SU10570","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"FARM":{"menu":"FARM","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000173","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_farm_1","tb":"FARM_1","unit":"SU10561","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000174","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_ma ...
# svt: 20210704101355,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '09650107',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cweb306-->"; </script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>    <script src="https://pm.pstatic.net/dist/js/external.76498058.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/preload.a37cdf88.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/polyfill_async.cca97940.js?o=www" type="text/javascript" crossorigin="anonymous" async></script>  <script src="https://pm.pstatic.net/dist/js/vendors~search.4d83db38.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>   <script src="https://pm.pstatic.net/dist/js/search.2f468bc7.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script>  <script src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.fe4f877d.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/vendors~nmain.4b71e896.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <script src="https://pm.pstatic.net/dist/js/nmain.204bf52e.js?o=www" type="text/javascript" crossorigin="anonymous" defer="defer"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> </head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap"> <style type="text/css">._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;width:18px;height:18px;margin:16px 8px 0 0;background-position:0 -89px}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._1syGnXOL._3dsvmZg2:before{background-position:-68px -63px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-26px -85px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-26px -63px}._1syGnXOL._18YOHi7v{color:#fff}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-98px -30px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{backgroun ...
# <div id="NM_TOP_BANNER" data-clk-prefix="top" class="_1hiMWemA"
# style="background-color: #6f5de5">
# <div class="tY_u8r23">
# <a class="_3h-N8T9V" href='https://whale.naver.com/banner/details/darkmode?=main&wpid=RydDy7'
# data-clk="dropbanner1b"></a>
# <i class="_1KncATpM _1yl_Ow6o"><span class="blind">NAVER whale</span></i>
# <img src="https://static-whale.pstatic.net/main/img_darkmode_v3@2x.png" width="215.5" height="49" alt=""
# style="padding-left: 92px"/>
# <span class="_1syGnXOL _18YOHi7v _3di88A4c" data-clk="dropbanner1b" style="padding-right: 20px; font-size: 18px; padding-left: 78px">
# <span>이제 </span><strong>다크 모드로 눈 건강은 ON! 피로는 OFF!</strong></span>
# <a href='https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe' class="_2aeXMlrb BMgpjddw" id="NM_whale_download_btn"
# data-clk="dropdownload1b"><span style="background-color: #44388e">다운로드</span></a>
# <button type="button" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1"
# data-ui-hide-target="#NM_TOP_BANNER" data-clk="dropclose1b" class="_20PYt6lT _3wm5EzmJ"
# style="display: none">3일 동안 보지 않기
# </button>
# </div>
# </div>  <div id="header" role="banner">
#
#
#
#
#
#
#
#
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_default">
# <a href="/" class="logo_naver" data-clk="top.logo"
# ><span class="blind">네이버</span></a
# >
# </h1>
# </div>
# <div class="service_area">
# <a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a href="https://jr.naver.com" class="link_jrnaver" data-clk="top.jrnaver"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a href="https://happybean.naver.com" class="link_happybin" data-clk="top.happybean"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
#
# <div id="search" class="search_area" data-clk-prefix="sch">
# <form id="sform" name="sform" action="https://search.naver.com/search.naver" method="get" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select id="where" name="where" title="검색 범위 선택" class="blind">
# <option value="nexearch" selected="selected">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input type="hidden" id="sm" name="sm" value="top_hty" />
# <input type="hidden" id="fbm" name="fbm" value="0" />
# <input type="hidden" id="acr" name="acr" value="" disabled="disabled" />
# <input type="hidden" id="acq" name="acq" value="" disabled="disabled" />
# <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled" />
# <input type="hidden" id="ie" name="ie" value="utf8" />
# <input type="hidden" id="acir" name="acir" value="" disabled="disabled" />
# <input type="hidden" id="os" name="os" value="" disabled="disabled" />
# <input type="hidden" id="bid" name="bid" value="" disabled="disabled" />
# <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled" />
# <input type="hidden" id="eid" name="eid" value="" disabled="disabled" />
# <input type="hidden" id="mra" name="mra" value="" disabled="disabled" />
#
#
#
# <div class="green_window" style=''>
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input id="query" name="query" type="text" title="검색어 입력" maxlength="255" class="input_text" tabindex="1" accesskey="s" style="ime-mode:active;" autocomplete="off"  placeholder="검색어를 입력해 주세요." onclick="document.getElementById('fbm').value=1;" value="" data-atcmp-element>
# </div>
# <button id="search_btn" type="submit" title="검색" tabindex="3" class="btn_submit" onclick="window.nclick(this,'sch.action','','',event);" style=''>
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a href="#" id="ke_kbd_btn" role="button" class="btn_keyboard" onclick="return false;"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a href="#" role="button" id="nautocomplete" tabindex="2" class="btn_arw _btn_arw fold" aria-pressed="false" data-atcmp-element><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div id="autoFrame" class="reatcmp" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element>
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a role="button" href="#" class="item _delAll" aria-pressed="false">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a href="#" role="button" class="bt_item _del" aria-pressed="false"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br><span class="kwd_dsc">설정이 초기화 된다면 <a href="https://help.naver.com/support/alias/search/word/word_29.naver" class="kwd_help" data-clk="sly.help" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" data-clk="sly.help" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _keywordOnOff">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_lotto _answer" data-template-type="answer_3" data-code="@code@" data-keyword="@1@">
# <a href="#" class="link_item">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@5@회차 당첨번호</span>
# <span class="dsc">
# <span class="item">추첨 @13@.</span><span class="item">지급기한 1년</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc lotto">
# <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_exchange _answer" data-template-type="answer_9" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @11@">
# <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
# <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>
# <div class="dsc_area">
# <span class="tit">@txt@<span class="sub">@currency@</span></span>
# <span class="dsc">
# <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc"><em class="num">@6@</em>원</span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_weather _answer" data-template-type="answer_11" data-code="@code@" data-keyword="@1@">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a href="#" class="link_item @12@">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@7@, @message@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">
# <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
# <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
# <em class="degree">@8@<sup class="celsius">°</sup></em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_site _answer" data-template-type="answer_17" data-code="@code@" data-keyword="@1@">
# <a href="@5@" class="link_item" target="_blank">
# <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@5@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">바로가기</span>
# </span>
# </a>
# </div>
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <!-- 최근검색어 있으면 날짜 표시 -->
# <em class="date">@date@.</em>
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-rank="@rank@" data-intend-rank="@intendRank@" data-template-type="intend" data-keyword="@transQuery@">
# <a href="#" class="kwd">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>
# </a>
# <span class="etc">
# <a href="#" role="button" class="bt_item _add" aria-pressed="false"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
# <span class="dsc_inner">
# <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
# <span class="_alert_passage2"></span>
# <!-- [AU] _alert_link 클래스를 추가해주세요. -->
# <a href="#" class="link _alert_link" target="_blank">자세히보기</a>
# </span>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658" class="link_dsc" data-clk="sug.cxhelp" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a role="button" href="#" class="bt_switch active _plus_btn" aria-pressed="false"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a href="https://help.naver.com/support/contents/contents.help?serviceNo=606&categoryNo=16659" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a href="https://nid.naver.com/nidlogin.login" class="btn btn_login" data-clk="sug.cxlogin">로그인</a>
# <a href="https://help.naver.com/support/alias/search/word/word_16.naver" class="btn btn_view" data-clk="sug.cxlink" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a href="#" role="button" class="btn_close _plus_layer_close"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a href="https://help.naver.com/support/service/main.help?serviceNo=605&categoryNo=1987" data-clk="sug.help" target="_blank">도움말</a></span>
# <span class="opt_item"><a href="https://help.naver.com/support/contents/contents.help?serviceNo=605&categoryNo=18215" class="report" data-clk="sug.report" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a href="#" class="close _suggestOnOff">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
#
# </div>
# </div>
#
# <!--EMPTY-->
# <div id="gnb">
# <div id="NM_FAVORITE" class="gnb_inner">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a href="https://mail.naver.com/" class="nav" data-clk="svc.mail"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a href="https://section.cafe.naver.com/" class="nav" data-clk="svc.cafe">카페</a></li>
# <li class="nav_item"><a href="https://section.blog.naver.com/" class="nav" data-clk="svc.blog">블로그</a></li>
# <li class="nav_item"><a href="https://kin.naver.com/" class="nav" data-clk="svc.kin">지식iN</a></li>
# <li class="nav_item"><a href="https://shopping.naver.com/" class="nav shop" data-clk="svc.shopping"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a href="https://shoppinglive.naver.com/home" class="nav shoplive"
# data-clk="svc.shoppinglive"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a href="https://order.pay.naver.com/home" class="nav" data-clk="svc.pay">Pay</a></li>
# <li class="nav_item">
# <a href="https://tv.naver.com/" class="nav" data-clk="svc.tvcast"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul
# class="list_nav NM_FAVORITE_LIST"
# >
# <li class="nav_item"><a href="https://dict.naver.com/" class="nav" data-clk="svc.dic">사전</a></li>
# <li class="nav_item"><a href="https://news.naver.com/" class="nav" data-clk="svc.news">뉴스</a></li>
# <li class="nav_item"><a href="https://finance.naver.com/" class="nav" data-clk="svc.stock">증권</a></li>
# <li class="nav_item"><a href="https://land.naver.com/" class="nav" data-clk="svc.land">부동산</a></li>
# <li class="nav_item"><a href="https://map.naver.com/" class="nav" data-clk="svc.map">지도</a></li>
# <li class="nav_item"><a href="https://vibe.naver.com/" class="nav" data-clk="svc.vibe">VIBE</a></li>
# <li class="nav_item"><a href="https://book.naver.com/" class="nav" data-clk="svc.book">책</a></li>
# <li class="nav_item"><a href="https://comic.naver.com/" class="nav" data-clk="svc.webtoon">웹툰</a></li>
#
# </ul>
# <ul class="list_nav type_empty" style="display: none;"></ul>
# <a href="#" role="button" class="btn_more" data-clk="svc.more">더보기</a>
# <div class="ly_btn_area">
# <a href="more.html" class="btn NM_FAVORITE_ALL" data-clk="map.svcmore">서비스 전체보기</a>
# <a href="#" role="button" class="btn btn_set" data-clk="map.edit">메뉴설정</a>
# <a href="#" role="button" class="btn btn_reset" data-clk="edt.reset">초기화</a>
# <a href="#" role="button" class="btn btn_save" data-clk="edt.save">저장</a>
# </div>
# </div>
# <div id="NM_WEATHER" class="group_weather">
# <div>
# <a data-clk="squ.weat" href="https://weather.naver.com/today/09650107" class="weather_area ico_w09">
# <div class="current_box">
# <strong class="current" aria-label="현재기온">23.0°</strong><strong class="state">비</strong>
# </div>
# <div class="degree_box">
# <span class="min" aria-label="최저기온">22.0°</span><span class="max" aria-label="최고기온">26.0°</span>
# </div>
# <span class="location">반포동</span>
# </a>
# </div>
# <div>
# <a data-clk="squ.dust" href="https://weather.naver.com/today/09650107" class="air_area">
# <ul class="list_air">
# <li class="air_item">미세<strong class="state state_good">좋음</strong></li>
# <li class="air_item">초미세<strong class="state state_good">좋음</strong></li>
# </ul>
# <span class="location">반포동</span>
# </a>
# </div>
#
# </div>
# </div>
# <div class="ly_service">
# <div class="group_service NM_FAVORITE_ALL_LY"></div>
# <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;"></div>
# </div>
# </div>
# </div>
#  <div id="container" role="main"> <div style="position:relative;width:1130px;margin:0 auto;z-index:11"> <div id="da_top"></div> <div id="da_expwide"></div> </div> <div id="NM_INT_LEFT" class="column_left">  <div id="veta_top"> <iframe id="da_iframe_time" name="da_iframe_time" data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10599&amp;nrefreshx=0" data-veta-preview="main_time" title="광고" width="750" height="135" marginheight="0" marginwidth="0" scrolling="no" frameborder="0"> </iframe> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div id="newsstand" class="sc_newscast"> <h2 class="blind">뉴스스탠드</h2> <div id="NM_NEWSSTAND_HEADER" class="group_issue" data-clk-prefix="ncy"> <div class="issue_area"> <a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y" class="link_media" data-clk="newsflash">연합뉴스</a> <div id="yna_rolling" class="list_issue"> <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501986" class="issue" data-clk="quickarticle">신규확진 743명,토요일 기준 올해 첫 700명대…해외유입 80명대 급증(종합)</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501976" class="issue" data-clk="quickarticle">日 아사히 "對韓 수출규제 '어리석은 계책의 극치'"</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501977" class="issue" data-clk="quickarticle">경찰, 민주노총 종로 기습시위 본격 수사…채증자료 분석</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501923" class="issue" data-clk="quickarticle">부산서 빗길 달리던 통근버스 넘어져 2명 중경상</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501845" class="issue" data-clk="quickarticle">부산에 강풍 동반 100㎜ 이상 많은 비…아파트 유리파손 등 피해</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501853" class="issue" data-clk="quickarticle">광양 주점서 흉기 난동…3명 사상(종합)</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501794" class="issue" data-clk="quickarticle">서해 풍랑주의보…인천∼백령도 등 3개 항로 운항 통제</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501842" class="issue" data-clk="quickarticle">서울 인구 5년만에 최대폭 감소…내국인 15만명 줄어</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501739" class="issue" data-clk="quickarticle">국민지원금 커트라인, 중위소득 180% 유력 검토…자산가는 배제</a></div>
# <div><a href="http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0012501747" class="issue" data-clk="quickarticle">尹, 처가 선긋고 마이웨이…칼잡이 내공, 여의도서 통할까</a></div> </div> </div> <div class="direct_area"> <a href="http://news.naver.com/" class="link_news" data-clk="newshome">네이버뉴스</a>
# <a href="http://entertain.naver.com/home" class="link_direct" data-clk="entertainment">연예</a>
# <a href="http://sports.news.naver.com/" class="link_direct" data-clk="sports">스포츠</a>
# <a href="http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101" class="link_direct" data-clk="economy">경제</a> </div> </div>        <div id="NM_NEWSSTAND_TITLE" class="group_title" data-clk-prefix="nsd"> <a href="http://newsstand.naver.com/" class="link_newsstand" data-clk="title" target="_blank">뉴스스탠드</a> <div id="NM_NEWSSTAND_data_buttons" class="sort_area">  <a href="#" role="button" data-type="my" data-clk="my" class="btn_sort">구독한 언론사</a> <a href="#" role="button" data-type="all" data-clk="all" class="btn_sort sort_on">전체언론사</a>  </div> <div id="NM_NEWSSTAND_view_buttons" class="set_area">  <a href="#" role="button" data-type="list" data-clk="articleview" class="btn_set"> <i class="ico_list"><span class="blind">리스트형</span></i></a> <a href="#" role="button" data-type="thumb" data-clk="pressview" class="btn_set set_on"> <i class="ico_tile"><span class="blind">썸네일형</span></i></a>  <a href="http://newsstand.naver.com/config.html" class="btn_set" data-clk="set" target="_blank"> <i class="ico_set"><span class="blind">설정</span></i></a> </div> </div> <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative"> <div id="NM_NEWSSTAND_DEFAULT_LIST" class="group_news" style="display:none" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev"><i class="ico_btn"><span class="blind">이전</span></i></a> <a href="#" role="button" class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="list_view"> <div class="option_area"> <div class="list_option_wrap"> <ul class="list_option"> <li class="option_item" data-cateid="ct2"><a href="#" class="option" data-clk="daei">종합/경제</a></li> <li class="option_item" data-cateid="ct3"><a href="#" class="option" data-clk="dtvcom">방송/통신</a></li> <li class="option_item" data-cateid="ct4"><a href="#" class="option" data-clk="dit">IT</a></li> <li class="option_item" data-cateid="ct5"><a href="#" class="option" data-clk="deng">영자지</a></li> <li class="option_item" data-cateid="ct6"><a href="#" class="option" data-clk="dsporent">스포츠/연예</a></li> <li class="option_item" data-cateid="ct7"><a href="#" class="option" data-clk="dmagtec">매거진/전문지</a></li> <li class="option_item" data-cateid="ct8"><a href="#" class="option" data-clk="dloc">지역</a></li> </ul> </div> </div> <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a"></div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg">해당 언론사 사정으로 접근이 일시 제한됩니다.</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE">확인</a> </div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" style="display:none" data-clk-sub="*a"> <a href="#" role="button" class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg"><strong class="NM_NEWSSTAND_POPUP_PNAME"></strong>을(를)<br>구독해지 하시겠습니까?</p> <div class="popup_btn"> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone">확인</a> <a href="#" role="button" class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel">취소</a> </div> </div> <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none"> <p class="toast_msg">구독한 언론사에 추가되었습니다.</p> </div> </div>   <div id="NM_NEWSSTAND_DEFAULT_THUMB" class="group_news" style="display:block" data-clk-prefix="nsd_all"> <a href="#" role="button" class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev"><i class="ico_btn"><span class="blind">이전</span></i></a> <a href="#" role="button" class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="_NM_UI_PAGE_CONTAINER" styl ...
# <div class="tile_view">
# <div class="frame_area">
# <i class="line to_right1"></i>
# <i class="line to_right2"></i>
# <i class="line to_right3"></i>
# <i class="line to_bottom1"></i>
# <i class="line to_bottom2"></i>
# <i class="line to_bottom3"></i>
# <i class="line to_bottom4"></i>
# <i class="line to_bottom5"></i>
# </div>
# <div class="thumb_area">
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="308"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/308.png"
# height="20"
# alt="시사인"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="308"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="308"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=308"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="308"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="117"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/117.png"
# height="20"
# alt="마이데일리"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="117"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="117"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=117"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="117"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="006"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/006.png"
# height="20"
# alt="미디어오늘"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="006"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="006"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=006"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="006"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="215"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/215.png"
# height="20"
# alt="한국경제TV"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="215"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="215"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=215"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="215"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="092"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/092.png"
# height="20"
# alt="지디넷코리아"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="092"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="092"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=092"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="092"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="014"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/014.png"
# height="20"
# alt="파이낸셜뉴스"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="014"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="014"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=014"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="014"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="076"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/076.png"
# height="20"
# alt="스포츠조선"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="076"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="076"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=076"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="076"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="241"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/241.png"
# height="20"
# alt="일간스포츠"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="241"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="241"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=241"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="241"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="031"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/031.png"
# height="20"
# alt="아이뉴스24"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="031"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="031"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=031"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="031"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="930"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/930.png"
# height="20"
# alt="뉴스타파"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="930"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="930"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=930"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="930"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="368"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/368.png"
# height="20"
# alt="데일리안"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="368"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="368"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=368"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="368"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="038"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/038.png"
# height="20"
# alt="한국일보"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="038"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="038"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=038"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="038"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="314"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/314.png"
# height="20"
# alt="스포츠동아"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="314"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="314"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=314"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="314"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="139"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/139.png"
# height="20"
# alt="스포탈코리아"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="139"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="139"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=139"
# target="_blank"
# class="btn_popup"
# data-clk="logo"
# data-pid="139"
# >기사보기</a
# >
# </div>
# </div>
# <div
# class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid"
# data-pid="293"
# >
# <a href="#" class="thumb">
# <img
# src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/293.png"
# height="20"
# alt="블로터"
# class="news_logo"
# />
# <span class="thumb_dim"></span
# ></a>
# <div class="popup_wrap">
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press"
# data-pid="293"
# data-clk="sub"
# >구독</a
# >
# <a
# href="#"
# role="button"
# class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press"
# data-pid="293"
# data-clk="unsub"
# >해지</a
# >
# <a
# href="http://newsstand.naver.com/?list=&pcode=293"
# target="_blank"
# ...
# 					<a href="https://blog.naver.com/adorable_38/222402416623" class="theme_thumb" data-clk="tcc_wed.list11cont5" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0628%2Fupload_1624842153623J256u.jpg%22&amp;type&#x3D;nf340_228" alt="디즈니 필터로 캐릭터 커플사진 만들었더니 남친 曰" width="170" height="114">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://blog.naver.com/adorable_38/222402416623" class="theme_info" data-clk="tcc_wed.list11cont5" target="_blank">
# 						<em class="theme_category"> 연애·결혼</em>
# 						<strong class="title elss">디즈니 필터로 캐릭터 커플사진 만들었더니 남친 曰</strong>
# 						<p class="desc">요즘 인스타 피드에 셀카를 디즈니 얼굴로 바꿔주는 Voila라는 어플이 유행이다! 디즈니 라푼젤, 겨울왕국 같은 최근 3D 디즈니 캐릭터 특유의 빵실빵실하고 눈 크고 코 작은 귀여운 캐릭터로 얼굴을 바꿀 수 있다. 인물사진을 디즈니 느낌으로 바꿔주는 어플 Voila #디즈니어플 #voila #디즈니셀카 #디즈니필터 제일 최근에 찍은 셀카를 예로 적용해 보면</p>
# 						<div class="source_box">
# 							<span class="date">2주일 전</span>
# 							<span class="source"><span class="source_inner">슈앙이</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
# <div class="group_theme" data-block-id="" data-block-code="PC-THEME-WEDDING-MOBILE-RANKING-DEFAULT-11" data-block-type="MATERIALS" data-template-code="MOBILE-RANKING-LIST"
#
# 	 data-da="container"
# 	 data-index=""
#      data-page="6"
# 	 style="display:none">
#
# 	<div class="list_theme_wrap">
# 		<ul class="list_theme">
#
# 				<li class="theme_item" data-gdid="CAS_e5e5e6b4-d71b-11eb-80b8-2ff0cbbdec94" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31828412&amp;memberNo&#x3D;42538534&amp;searchKeyword&#x3D;%25EA%25B2%25B0%25ED%2598%25BC&amp;searchRank&#x3D;7" class="theme_thumb" data-clk="tcc_wed.list12cont1" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0627%2Fupload_1624760525737F8TO9.jpg%22&amp;type&#x3D;nf340_228" alt="&quot;남친 강아지가  내 손을 물었고, 결혼은 깨졌다.&quot;" width="170" height="114">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31828412&amp;memberNo&#x3D;42538534&amp;searchKeyword&#x3D;%25EA%25B2%25B0%25ED%2598%25BC&amp;searchRank&#x3D;7" class="theme_info" data-clk="tcc_wed.list12cont1" target="_blank">
# 						<em class="theme_category"> 연애·결혼</em>
# 						<strong class="title elss">"남친 강아지가  내 손을 물었고, 결혼은 깨졌다."</strong>
# 						<p class="desc">강아지 때문에 파혼한 커플 이야기대한민국 반려동물 인구 1천5백만 시대. 약 4명 중 한명이 반려동물과 함께 살고 있다고 해도 과언이 아니다. 요즘은 동물과 함께하는 캠핑장부터 호텔에 이르기 까지, 사랑하는 동물과 함께할 수 있는 공간도 늘고 있다. 애완동물이 아닌 ‘반려’라는 의미는 우리 삶에 그만큼 깊숙이 스며들어 가족이란 무엇인가를 진단하는 가운데, </p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source"><span class="source_inner">웨딩해 연구소</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_b4a1be32-d554-11eb-a06a-d5c41b5eab45" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31785577&amp;memberNo&#x3D;45136730" class="theme_thumb" data-clk="tcc_wed.list12cont2" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0625%2Fupload_16245840497337Xsmg.jpg%22&amp;type&#x3D;nf340_228" alt="돌고 돌아 20년 만에 만난 부부가 공개한 집 내부" width="170" height="114">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31785577&amp;memberNo&#x3D;45136730" class="theme_info" data-clk="tcc_wed.list12cont2" target="_blank">
# 						<em class="theme_category"> 연애·결혼</em>
# 						<strong class="title elss">돌고 돌아 20년 만에 만난 부부가 공개한 집 내부</strong>
# 						<p class="desc">최근 강수지는 자신의 SNS를 통해 ‘하늘이 참 예쁜 오늘’이라는 글과 함께 여러 장의 일상 사진을 올렸습니다. 그녀가 공개한 사진 속에는 집안 꾸미기에 여념이 없는 강수지의 모습과 함께 마치 잡지 한 페이지를 보는 듯한 독보적인 인테리어로 여러 이들의 시선을 사로잡았죠. 현재 그녀는 고등학교 3학년인 딸을 위해 방송일도 접고 집안일을</p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source"><span class="source_inner">십중팔구</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_59b95d04-d4c8-11eb-80b8-ff8eb4acbb51" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31779415&amp;memberNo&#x3D;38753951" class="theme_thumb" data-clk="tcc_wed.list12cont3" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0624%2Fupload_1624524221564PKnf0.jpg%22&amp;type&#x3D;nf340_228" alt="&quot;나 그런 사람 아냐&quot;라 답하면 가스라이팅 시작?" width="170" height="114">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31779415&amp;memberNo&#x3D;38753951" class="theme_info" data-clk="tcc_wed.list12cont3" target="_blank">
# 						<em class="theme_category"> 연애·결혼</em>
# 						<strong class="title elss">"나 그런 사람 아냐"라 답하면 가스라이팅 시작?</strong>
# 						<p class="desc">내가 가스라이팅을 당하고 있는 건 아닐까? 지금 내 애인, 상사, 부모가 하는 건 가스라이팅이 아닐까? 요즘엔 이렇게 생각하시는 분들이 많죠. 그래서 가스라이팅에 대해서 최대한 쉽게 설명해 보려고 합니다. 이 글을 통해서 가스라이팅에 대해서 좀 더 이해하고, 가스라이팅을 어떻게 대처하는지에 대해서도 알 수 있게 됩니다. 바로 시작할게요. 1. 가스라이팅의 </p>
# 						<div class="source_box">
# 							<span class="date">2주일 전</span>
# 							<span class="source"><span class="source_inner">네이버 연애결혼</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_b4a1be34-d554-11eb-a06a-a3ffd9253f9d" data-da-position="true">
# 					<a href="https://blog.naver.com/kimnh3813/222403340515" class="theme_thumb" data-clk="tcc_wed.list12cont4" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0625%2Fupload_16245866105601FspE.jpg%22&amp;type&#x3D;nf340_228" alt="티파니 다이아링 안끼니까 커플링 또 사줌 히히" width="170" height="114">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://blog.naver.com/kimnh3813/222403340515" class="theme_info" data-clk="tcc_wed.list12cont4" target="_blank">
# 						<em class="theme_category"> 연애·결혼</em>
# 						<strong class="title elss">티파니 다이아링 안끼니까 커플링 또 사줌 히히</strong>
# 						<p class="desc">프러포즈 때 받은 다이아반지💍 영롱블링✨하지만 일하다 보니 착용을 안 하게 되어 ㅠㅠ 고이 모셔 놓는 중🥲 그런 나를 본 오빠... 아쉬움을 표현하며 &#x27;결혼 전에 커플링이란 걸 해보자!&#x27; &#x27;편한 반지 맞춰 같이 끼고 다녀 보자!&#x27; 등 의견을 냄ㅋㅋ (그냥 본인이 반지 끼고 싶었는듯?) 그리하여 결혼 전 커플링을 맞추게 됨! ㅋㅋ 우리의 &#x27;처음이...</p>
# 						<div class="source_box">
# 							<span class="date">2주일 전</span>
# 							<span class="source"><span class="source_inner">두부</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 				<li class="theme_item" data-gdid="CAS_5cc47bb2-d335-11eb-b9c4-814d7fc818cc" data-da-position="true">
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31837885&amp;memberNo&#x3D;47171853&amp;searchKeyword&#x3D;%25EC%259B%25A8%25EB%2594%25A9&amp;searchRank&#x3D;14" class="theme_thumb" data-clk="tcc_wed.list12cont5" target="_blank">
# 						<img  data-src="https://s.pstatic.net/dthumb.phinf/?src&#x3D;%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0625%2Fupload_1624603341833pVuTx.jpg%22&amp;type&#x3D;nf340_228" alt="백신 맞고 나면 여기 한국 신혼부부 천지겠는걸?!" width="170" height="114">
# 						<span class="thumb_bd"></span>
# 					</a>
# 					<a href="https://post.naver.com/viewer/postView.naver?volumeNo&#x3D;31837885&amp;memberNo&#x3D;47171853&amp;searchKeyword&#x3D;%25EC%259B%25A8%25EB%2594%25A9&amp;searchRank&#x3D;14" class="theme_info" data-clk="tcc_wed.list12cont5" target="_blank">
# 						<em class="theme_category"> 연애·결혼</em>
# 						<strong class="title elss">백신 맞고 나면 여기 한국 신혼부부 천지겠는걸?!</strong>
# 						<p class="desc">지난해 발생한 코로나19로 인해 하늘길이 막히고 국경문도 닫혔습니다. 이에 많은 신혼부부들은 해외 대신 국내로 신혼여행을 떠났죠. 그러나 점점 코로나19가 진정세로 들어서고 있고, 전 세계로 백신 접종도 진행되고 있는데요. 이에 이제는 해외로 가는 신혼여행을 고려해볼 수 있는 시기가 된 것 같습니다.이를 맞아 웨딩컨설팅 업체 듀오웨드에서는 미혼남성 198명</p>
# 						<div class="source_box">
# 							<span class="date">1주일 전</span>
# 							<span class="source"><span class="source_inner">커플스토리</span></span>
# 						</div>
# 					</a>
# 				</li>
#
# 		</ul>
# 	</div>
# </div>
#
#
# 	<p class="alert_msg" data-clk-prefix="tcc_wed">연애결혼판의 컨텐츠는 <a href="https://blog.naver.com/sum-lab/221084190193" data-clk-suffix="corp" target="_blank">㈜썸랩</a>에 의해 운영·편집 됩니다.</p>
#
#
#
# 	<div class="btn_more_wrap">
# 		<button type="button" class="btn_more" data-clk-custom="tcc_wed.more" data-next-page="2"><i class="ico_more"></i>새로운 글 더보기</button>
# 	</div>
#
#
# 	</div>
# </div>
#  </div> </div> <div id="NM_INT_RIGHT" class="column_right"> <div class="column_fix_wrap"> <div id="da_brand"></div>
#
#
#
#
# <div id="account" class="sc_login">
# <h2 class="blind">Sign in</h2>
# <p class="login_msg">Connect with people</p>
# <a href="https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com" class="link_login" data-clk="log_off.login"><i class="ico_naver"><span class="blind">NAVER</span></i>Sign in</a>
# <div class="sub_area">
# <div class="look_box">
# <a href="https://nid.naver.com/user/help.nhn?todo=idinquiry" class="link_look" data-clk="log_off.searchid">Forgot Username</a>
# <a href="https://nid.naver.com/nidreminder.form" class="link_look" data-clk="log_off.searchpass">Password</a>
# </div>
# <a href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com" class="link_join" data-clk="log_off.registration">Sign up</a>
# </div>
# </div>
#
#
#
#  <div id="timesquare" class="sc_timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a href="#" role="button" class="btn_nav btn_prev" data-clk="squ.pre"><span class="blind">이전</span></a>
# <a href="#" role="button" class="btn_nav btn_next" data-clk="squ.next"><span class="blind">다음</span></a>
# </div>
# <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
# <div>
# <a href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819" class="card_news" data-clk="squ.line3"><i class="news_badge">이슈</i><span class="news">코로나바이러스감염증-19 현황</span></a>
# </div>
#
# </div>
# </div> <!-- EMPTY --> </div>  <div id="veta_branding"> <iframe id="da_iframe_rolling" name="da_iframe_rolling" data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10601&amp;nrefreshx=0" data-veta-preview="main_rolling" title="광고" width="350" height="200" marginheight="0" marginwidth="0" scrolling="no" frameborder="0"></iframe> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div>   <div id="shopcast" class="sc_shopcast"> <iframe id="shopcast_iframe" data-iframe-src="https://castbox.shopping.naver.com/shoppingboxnew/main.nhn" title="쇼핑캐스트" width="350" height="1539" marginheight="0" marginwidth="0" scrolling="no" frameborder="0"></iframe> </div> </div> </div> <a id="NM_scroll_top_btn" href="#wrap" class="content_top"><span class="blind">TOP</span></a> <button id="NM_darkmode_btn" type="button" role="button" class="btn_theme" aria-pressed="false"  > <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div class="banner_area"> <div class="da_box_wrap">    <div id="da_public_left"> <iframe id="da_iframe_bottom_left" data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10641&amp;nrefreshx=0" title="광고" width="350" height="86" scrolling="no" frameborder="0"></iframe> </div> <div id="da_public_right"> <iframe id="da_iframe_bottom_right" data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10642&amp;nrefreshx=0" title="광고" width="350" height="86" scrolling="no" frameborder="0"></iframe> </div> <div id="veta_time2"> <iframe id="da_iframe_below" name="da_iframe_below" data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10640&amp;nrefreshx=0" data-veta-preview="main_below" width="350" height="86" scrolling="no" frameborder="0" title="광고"> </iframe> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3>
# <a href="https://www.naver.com/NOTICE/read/1100001014/10000000000030671651" class="notice_msg" data-clk="notice" >&#39;비밀번호 관리 프로그램&#39; 사용에 주의해 주세요.</a> </div> <a href="more.html" class="link_all" data-clk="svcmap">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a href="https://www.navercorp.com/service/creators" class="link_partner" data-clk="creator">크리에이터</a> <a href="https://www.navercorp.com/service/business" class="link_partner" data-clk="smbusiness">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a href="https://campaign.naver.com/smefullcare/online/" class="link_partner" data-clk="sme">SME 풀케어 시스템</a> <a href="https://business.naver.com/service.html" class="link_partner" data-clk="service">비즈니스 · 광고</a> <a href="https://sell.storefarm.naver.com/#/home/about" class="link_partner" data-clk="store">스토어 개설</a> <a href="https://smartplace.naver.com" class="link_partner" data-clk="place">지역업체 등록</a> <a href="https://expert.naver.com/expert/introduction?tab=guide#join" class="link_partner" data-clk="expert">엑스퍼트 등록</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a href="https://developers.naver.com" class="link_partner" data-clk="center">네이버 개발자 센터</a> <a href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md" class="link_partner" data-clk="openapi">오픈 API</a> <a href="https://naver.github.io" class="link_partner" data-clk="opensource">오픈소스</a> <a href="https://d2.naver.com" class="link_partner" data-clk="d2">네이버 D2</a> <a href="http://d2startup.com" class="link_partner" data-clk="naverD2SF">네이버 D2SF</a> <a href="https://www.naverlabs.com" class="link_partner" data-clk="labs">네이버 랩스</a> </div> </div> <div class="service_box_wrap"> <div class="service_box" data-clk-prefix="wbd"> <a href="http://whale.naver.com/" class="service_logo" data-clk="bt"> <img src="data:image/png;base64,..." alt="웨일" width="48" height="48"> </a> <div class="service_info"> <strong class="title">웨일 브라우저</strong> <a href="http://whale.naver.com/" class="dsc" data-clk="bt">다운받기</a> </div> </div> <div class="service_box" data-clk-prefix="prj"> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="service_logo" data-clk="link"> <img src="data:image/png;base64,..." alt="꽃" width="47" height="50"> </a> <div class="service_info"> <strong class="title">프로젝트 꽃</strong> <a href="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83" class="dsc" data-clk="link">바로가기</a> </div> </div> </div> </div> <div class="corp_area" data-clk-prefix="plc"> <h3 class="blind">네이버 정책 및 약관</h3> <ul class="list_corp"> <li class="corp_item"><a href="https://www.navercorp.com" data-clk="intronhn">회사소개</a></li> <li class="corp_item"><a href="https://recruit.navercorp.com/naver/recruitMain" data-clk="recruit">인재채용</a></li> <li class="corp_item"><a href="https://www.navercorp.com/naver/proposalGuide" data-clk="contact">제휴제안</a></li> <li class="corp_item"><a href="/policy/service.html" data-clk="service">이용약관</a></li> <li class="corp_item"><a href="/policy/privacy.html" data-clk="privacy"><strong>개인정보처리방침</strong></a></li> <li class="corp_item"><a href="/policy/youthpolicy.html" data-clk="youth">청소년보호정책</a></li> <li class="corp_item"><a href="/policy/spamcheck.html" data-clk="policy">네이버 정책</a></li> <li class="corp_item"><a href="https://help.naver.com/" data-clk="helpcenter">고객센터</a></li> </ul> <address class="addr"><a href="https://www.navercorp.com" target="_blank" data-clk="nhn">ⓒ NAVER Corp.</a></address> </div> </div> </div> </div> <div id="adscript" style="display:none"></div> </body> </html>

# %%
# 수정 보완 : Xpath 사용

import re
import urllib

query_list = ['파이썬','웹 크롤링', '빅데이터','python']
URL = 'https://search.naver.com/search.naver?query='
for i in query_list:
    new_URL = URL + urllib.parse.quote(i)     # 아스키코드가 아닌 문자들을 퍼센트 인코딩으로 변환
    response_urllib = urllib.request.urlopen(new_URL)
    byte_data = response_urllib.read()
    text_data = byte_data.decode('utf-8')
    print(new_URL)
# print(text_data)
# Out:
# https://search.naver.com/search.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC
# https://search.naver.com/search.naver?query=%EC%9B%B9%20%ED%81%AC%EB%A1%A4%EB%A7%81
# https://search.naver.com/search.naver?query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0
# https://search.naver.com/search.naver?query=python

# %%
# 수정 보완 : Xpath 사용

import re
import urllib

query_list = ['파이썬','웹 크롤링', '빅데이터','python']
URL = 'https://search.naver.com/search.naver?query='
for i in query_list:
    new_URL = URL + urllib.parse.quote(i)     # 아스키코드가 아닌 문자들을 퍼센트 인코딩으로 변환
    response_urllib = urllib.request.urlopen(new_URL)
    byte_data = response_urllib.read()
    text_data = byte_data.decode('utf-8')
    text_data = text_data.split('검색어를 입력해 주세요.')[1].split('도움말')[1]
    text_data = re.sub('<.+?>','',text_data)
    print(i, ":", text_data)
# Out:
# 파이썬 : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면
# 웹 크롤링 : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면
# 빅데이터 : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면
# python : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면

# %%
text_data.find('검색어를 입력해 주세요')
text_data[36450:36490]
# Out:
# 'laceholder="검색어를 입력해 주세요." data-atcmp-el'

# %%
# 수정 보완 : Xpath 사용

import re
import urllib

query_list = ['파이썬','웹 크롤링', '빅데이터','python']
URL = 'https://search.naver.com/search.naver?query='
for i in query_list:
    new_URL = URL + urllib.parse.quote(i)     # 아스키코드가 아닌 문자들을 퍼센트 인코딩으로 변환
    response_urllib = urllib.request.urlopen(new_URL)
    byte_data = response_urllib.read()
    text_data = byte_data.decode('utf-8')
#    text_data = text_data.split('연관검색어')[1].split('도움말')[1].split('닫기 후 1주일간')[0]
    text_data = text_data.split('검색어를 입력해 주세요.')[1].split('도움말')[1]
    text_data = re.sub('<.+?>','',text_data)
#    text_data = re.sub('<.+?>','',text_data, 0, re.I|re.S)
    text_data = text_data.replace(' ',' ').strip()
    print(i, ":", text_data)
# Out:
# 파이썬 : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면
# 웹 크롤링 : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면
# 빅데이터 : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면
# python : 을 확인해주세요. 최근 검색어 내역이 없습니다.설정이 초기화 된다면

# %% [markdown]
# BeautifulSoup 모듈
# - 홈페이지 내 데이터를 쉽게 추출할 수 있게 해주는 파이썬 외부 라이브러리
# - 웹 문서 내 수많은 HTML 태그들을 parser를 활용해 사용하기 편한 파이썬 객체로 만들어 제공
# - 웹 문서 구조를 알고 있다면 편하게 데이터를 뽑아 활용할 수 있음
#
# 기존방식과의 차이점
# - 정규 표현식, 문자열 함수 등을 활용하여 홈페이지 텍스트 내 패턴을 분석하여 하나씩 원하는 데이터를 찾아가는 형식
# - BS는 HTML 문서를 태그를 기반으로 구조화하여 태그로 원하는 데이터를 찾아가는 형식

# %%
# !pip install beautifulsoup4
# Out:
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Installing collected packages: soupsieve, beautifulsoup4
# Successfully installed beautifulsoup4-4.10.0 soupsieve-2.3.1

# %%
# 무작위로 작성된 HTML 코들를 태그들을 찾아 구조화
html_doc = """
<html lang="en">
<head><title>crawl</title></head>
<body>
<p class="a" align="center"> text1</p>
<p class="b" align="center"> text2</p>
<p class="c" align="center"> text3</p>
<div><img src="/source" width="300" height="200"></div>
</body>
</html>
"""
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html lang="en">
#  <head>
#   <title>
#    crawl
#   </title>
#  </head>
#  <body>
#   <p align="center" class="a">
#    text1
#   </p>
#   <p align="center" class="b">
#    text2
#   </p>
#   <p align="center" class="c">
#    text3
#   </p>
#   <div>
#    <img height="200" src="/source" width="300"/>
#   </div>
#  </body>
# </html>

# %%
import requests
URL = 'http://naver.com'
req = requests.get(URL)
html_data = req.text
# print(html_data)
print(html_data.find('네이버'))
print(html_data[365:368])
# Out:
# 365
# 네이버

# %%
# 수정 보완
import requests
from bs4 import BeautifulSoup

URL = 'http://naver.com'
req = requests.get(URL)
html = req.text
html
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20220526.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"L ...

# %%
html.find('blind')
html[10930:10980]
# Out:
# 'clk="top.logo"\n><span class="blind">네이버</span></a\n'

# %%
soup = BeautifulSoup(html,'html.parser')
result = soup.find(class_='blind')
print(result.text)
print(result.get_text())
# Out:
# 네이버
# 네이버

# %%
# 라이브러리 읽어 들이기 
from bs4 import BeautifulSoup
# 분석하고 싶은 HTML 
html = """
<html><body>
  <h1>스크레이핑이란?</h1>
  <p>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""
# HTML 분석하기 
soup = BeautifulSoup(html, 'html.parser')
# 원하는 부분 추출하기 
h1 = soup.html.body.h1
p1 = soup.html.body.p
p2 = p1.next_sibling.next_sibling
# 요소의 글자 출력하기 
print("h1 = " + h1.string)
print("p  = " + p1.string)
print("p  = " + p2.string)
# Out:
# h1 = 스크레이핑이란?
# p  = 웹 페이지를 분석하는 것
# p  = 원하는 부분을 추출하는 것

# %% [markdown]
# find() : HTML의 해당 태그에 대한 첫 번째 정보를 가져옴
# - find(속성='값') : HTML 해당 속성과 일치하는 값에 대한 첫 번째 정보를 가져옴

# %%
# id로 요소를 찾는 방법
from bs4 import BeautifulSoup

html = """
<html><body>
  <h1 id="title">스크레이핑이란?</h1>
  <p id="body">웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""

# HTML 분석하기 --- (※1)
soup = BeautifulSoup(html, 'html.parser')

# find() 메서드로 원하는 부분 추출하기 --- (※2)
title = soup.find(id="title")
body = soup.find(id="body")

# 텍스트 부분 출력하기
print("#title=" + title.string)
print("#body=" + body.string)
print(body.text)
print(body.get_text())
# Out:
# #title=스크레이핑이란?
# #body=웹 페이지를 분석하는 것
# 웹 페이지를 분석하는 것
# 웹 페이지를 분석하는 것

# %%
texts = soup.findAll('p')
for t in texts:
    print(t.text)
# Out:
# 웹 페이지를 분석하는 것
# 원하는 부분을 추출하는 것

# %%
# 여러개의 요소 추출
from bs4 import BeautifulSoup 
html = """
<html><body>
  <ul>
    <li><a href="http://www.naver.com">naver</a></li>
    <li><a href="http://www.daum.net">daum</a></li>
  </ul>
</body></html>
"""
# HTML 분석하기 --- (※1)
soup = BeautifulSoup(html, 'html.parser')
# find_all() 메서드로 추출하기 --- (※2)
links = soup.find_all("a")
# 링크 목록 출력하기 --- (※3)
for a in links:
    href = a.attrs['href']
    text = a.string
    print(text, ">", href)
# Out:
# naver > http://www.naver.com
# daum > http://www.daum.net

# %%
# urlopen() 과 BeautifulSoup 조합
from bs4 import BeautifulSoup
import urllib.request as req
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
# urlopen()으로 데이터 가져오기 --- (※1)
res = req.urlopen(url)
# BeautifulSoup으로 분석하기 --- (※2)
soup = BeautifulSoup(res, "html.parser")
# 원하는 데이터 추출하기 --- (※3)
title = soup.find("title").string
wf = soup.find("wf").string
print(title)
print(wf)
# Out:
# 기상청 육상 중기예보
# ○ (강수) 27일(수)은 수도권과 강원영서, 충남권, 전북에, 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 28~35도로 어제(23일, 아침최저기온 20~24도, 낮최고기온 27~29도)보다 높겠습니다.<br /><br />* 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.

# %%
import requests
import re
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
data = requests.get(url).text
soup = BeautifulSoup(data,"html.parser")
wf = soup.find('wf').string
wf = re.sub('[^0-9가-힣]',' ',wf)
wf
# Out:
# '   강수  27일 수 은 수도권과 강원영서  충남권  전북에  30일 토 은 전라권에 소나기가 오는 곳이 있겠습니다           기온  이번 예보기간 아침 기온은 22 26도  낮 기온은 28 35도로 어제 23일  아침최저기온 20 24도  낮최고기온 27 29도 보다 높겠습니다               우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며  돌풍과 함께 천둥 번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며  앞으로 발표되는 기상정보를 참고하기 바랍니다 '

# %%
import requests
import re
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
data = requests.get(url).text
soup = BeautifulSoup(data,"html.parser"ㅠ)
wf = soup.find('wf').text
print(wf)
wf = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
wf
# Out:
# ○ (강수) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다. 27일(수)은 수도권과 강원영서에 비가 오겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~26도로 어제(19일, 아침최저기온 20~24도)보다 조금 높겠고, 낮 기온은 28~34도로 어제(낮최고기온 27~34도)와 비슷하겠습니다. <br />○ (주말전망) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다.<br />              아침 기온은 22~24도, 낮 기온은 28~32도가 되겠습니다.<br /><br />* 이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며, 정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.
# '(강수) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다. 27일(수)은 수도권과 강원영서에 비가 오겠습니다.(기온) 이번 예보기간 아침 기온은 22~26도로 어제(19일, 아침최저기온 20~24도)보다 조금 높겠고, 낮 기온은 28~34도로 어제(낮최고기온 27~34도)와 비슷하겠습니다.(주말전망) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다. 아침 기온은 22~24도, 낮 기온은 28~32도가 되겠습니다. 이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며, 정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
import requests
import re
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
data = requests.get(url).text
soup = BeautifulSoup(data,"html.parser")
title = soup.find('title').string
wf = soup.find('wf').get_text()
wf = re.sub('<.+?>','',wf)
wf = re.finditer('\w',wf)
print(title,'\n')
for i in wf:
    print(i.group(), end='')
# Out:
# 기상청 육상 중기예보
#
# 강수12일토오후제주도에비가시작되어13일일남부지방으로확대되겠으며13일일14일월강원영동에는비또는눈이오겠습니다기온이번예보기간아침기온은96도낮기온은113도로오늘8일아침최저기온100도낮최고기온59도보다높겠습니다주말전망12일토은구름많겠으나제주도에는비가오겠으며13일일은대체로흐리고전라권과경상권제주도에비가강원영동에는비또는눈이오겠습니다아침기온은46도낮기온은713도가되겠습니다12일토14일월강수는남쪽을지나는저기압의위치와이동속도에따라변동성이있겠고13일일14일월강원영동에는많은강수량이예상되나기온의변화에따라강수형태비또는눈가달라질수있으니앞으로발표되는기상정보를참고하기바랍니다

# %% [markdown]
# find_all() :
# - HTML의 해당 태그에 대한 모든 정보를 리스트 형식으로 가져옴. limit 옵션으로 개수 지정 가능
# - CSS 속성으로 필터링(class_로 클래스를 직접 사용 혹은 attrs에서 속성 = 값으로 필터링)

# %%
texts = soup.findAll('wf')

for t in texts:
    t = t.text
    t = re.sub('[^0-9가-힣]',' ',t)
    print(t,'\n')
# Out:
#    강수  12일 토  오후 제주도에 비가 시작되어 13일 일  남부지방으로 확대되겠으며  13일 일  14일 월  강원영동에는 비 또는 눈이 오겠습니다           기온  이번 예보기간 아침 기온은  9 6도  낮 기온은 1 13도로 오늘 8일  아침최저기온  10 0도  낮최고기온 5 9도 보다 높겠습니다          주말전망  12일 토 은 구름많겠으나  제주도에는 비가 오겠으며  13일 일 은 대체로 흐리고 전라권과 경상권  제주도에 비가  강원영동에는 비 또는 눈이 오겠습니다                      아침 기온은  4 6도  낮 기온은 7 13도가 되겠습니다               12일 토  14일 월  강수는 남쪽을 지나는 저기압의 위치와 이동속도에 따라 변동성이 있겠고  13일 일  14일 월  강원영동에는 많은 강수량이 예상되나 기온의 변화에          따라 강수형태 비 또는 눈 가 달라질 수 있으니  앞으로 발표되는 기상정보를 참고하기 바랍니다
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐림
#
# 흐림
#
# 흐림
#
# 흐림
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비 눈
#
# 흐리고 비 눈
#
# 흐리고 눈
#
# 흐리고 눈
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐림
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 구름많음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 흐리고 비
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 맑음
#
# 구름많음
#
# 구름많음
#
# 흐리고 비
#
# 흐리고 비
#
# 흐리고 비
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림
#
# 구름많음
#
# 흐림

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get('https://naver.com')
html = req.text

soup = BeautifulSoup(html, 'html.parser')
# result = soup.find_all('a','api_link')
#result = soup.find_all('span',class_='blind',limit=2)
result = soup.find_all('span',class_='blind')[1]
result
# Out:
# <span class="blind">네이버</span>

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get('https://naver.com')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#  <html data-dark="false" lang="ko"> <head> <meta charset="utf-8"/> <title>NAVER</title> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <meta content="NAVER" name="apple-mobile-web-app-title"> <meta content="index,nofollow" name="robots"> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content="https://www.naver.com/" name="twitter:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"> <link href="https://pm.pstatic.net/dist/css/nmain.20210601a.css" rel="stylesheet"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css" rel="stylesheet"/> <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"> <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/> <script>document.domain="naver.com",window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent;window.nmain.isIE=navigator.appName&&navigator.appName.indexOf("Explorer")>0&&ua.toLocaleLowerCase().indexOf("msie 10.0")<0,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function a(){}return a.prototype=n,new a})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script> <script> window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"ANIMAL":{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000161","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_1","tb":"ANIMAL_1","unit":"SU10567","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000162","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_2","tb":"ANIMAL_1","unit":"SU10568","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BUSINESS":{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000165","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_1","tb":"BUSINESS_1","unit":"SU10577","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000166","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_2","tb":"BUSINESS_1","unit":"SU10578","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"CARGAME":{"menu":"CARGAME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000167","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_1","tb":"CARGAME_1","unit":"SU10587","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000168","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_cargame_2","tb":"CARGAME_1","unit":"SU10588","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"CHINA":{"menu":"CHINA","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000169","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_1","tb":"CHINA_1","unit":"SU10591","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000170","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_china_2","tb":"CHINA_1","unit":"SU10592","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"DESIGN":{"menu":"DESIGN","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000171","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_1","tb":"DESIGN_1","unit":"SU10569","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000172","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_design_2","tb":"DESIGN_1","unit":"SU10570","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"FARM":{"menu":"FARM","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000173","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_farm_1","tb":"FARM_1","unit":"SU10561","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000174","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_ma ...
# svt: 20210704151957,
# }; </script> <script> window.nmain.newsstand = {
# rcode: '09650107',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--cweb403-->"; </script> <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js"></script> <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/external.76498058.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/preload.a37cdf88.js?o=www" type="text/javascript"></script> <script async="" crossorigin="anonymous" src="https://pm.pstatic.net/dist/js/polyfill_async.cca97940.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~search.4d83db38.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/search.2f468bc7.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.fe4f877d.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~nmain.4b71e896.js?o=www" type="text/javascript"></script> <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/nmain.204bf52e.js?o=www" type="text/javascript"></script> <style>:root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}</style> </link></link></meta></meta></meta></meta></meta></head> <body> <div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div> <div id="wrap"> <style type="text/css">._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;width:18px;height:18px;margin:16px 8px 0 0;background-position:0 -89px}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._1syGnXOL._3dsvmZg2:before{background-position:-68px -63px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-26px -85px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-26px -63px}._1syGnXOL._18YOHi7v{color:#fff}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-98px -30px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px} ...
# <div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #6f5de5">
# <div class="tY_u8r23">
# <a class="_3h-N8T9V" data-clk="dropbanner1b" href="https://whale.naver.com/banner/details/darkmode?=main&amp;wpid=RydDy7"></a>
# <i class="_1KncATpM _1yl_Ow6o"><span class="blind">NAVER whale</span></i>
# <img alt="" height="49" src="https://static-whale.pstatic.net/main/img_darkmode_v3@2x.png" style="padding-left: 92px" width="215.5"/>
# <span class="_1syGnXOL _18YOHi7v _3di88A4c" data-clk="dropbanner1b" style="padding-right: 20px; font-size: 18px; padding-left: 78px">
# <span>이제 </span><strong>다크 모드로 눈 건강은 ON! 피로는 OFF!</strong></span>
# <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #44388e">다운로드</span></a>
# <button class="_20PYt6lT _3wm5EzmJ" data-clk="dropclose1b" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" style="display: none" type="button">3일 동안 보지 않기
# </button>
# </div>
# </div> <div id="header" role="banner">
# <div class="special_bg">
# <div class="group_flex">
# <div class="logo_area">
# <h1 class="logo_default">
# <a class="logo_naver" data-clk="top.logo" href="/"><span class="blind">네이버</span></a>
# </h1>
# </div>
# <div class="service_area">
# <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>
# <i class="sa_bar"></i>
# <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com"><i class="ico_jrnaver"></i><span class="blind">쥬니어네이버</span></a>
# <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com"><i class="ico_happybin"></i><span class="blind">해피빈</span></a>
# </div>
# <div class="search_area" data-clk-prefix="sch" id="search">
# <form action="https://search.naver.com/search.naver" id="sform" method="get" name="sform" role="search">
# <fieldset>
# <legend class="blind">검색</legend>
# <select class="blind" id="where" name="where" title="검색 범위 선택">
# <option selected="selected" value="nexearch">통합검색</option><option value="post">블로그</option><option value="cafeblog">카페</option><option value="cafe">- 카페명</option><option value="article">- 카페글</option><option value="kin">지식iN</option><option value="news">뉴스</option><option value="web">사이트</option><option value="category">- 카테고리</option><option value="site">- 사이트</option><option value="movie">영화</option><option value="webkr">웹문서</option><option value="dic">사전</option><option value="100">- 백과사전</option><option value="endic">- 영어사전</option><option value="eedic">- 영영사전</option><option value="krdic">- 국어사전</option><option value="jpdic">- 일본어사전</option><option value="hanja">- 한자사전</option><option value="terms">- 용어사전</option><option value="book">책</option><option value="music">음악</option><option value="doc">전문자료</option><option value="shop">쇼핑</option><option value="local">지역</option><option value="video">동영상</option><option value="image">이미지</option><option value="mypc">내PC</option><optgroup label="스마트 파인더"><option value="movie">영화</option><option value="auto">자동차</option><option value="game">게임</option><option value="health">건강</option><option value="people">인물</option></optgroup><optgroup label="네이버 랩"><option>긍정부정검색</option></optgroup>
# </select>
# <input id="sm" name="sm" type="hidden" value="top_hty"/>
# <input id="fbm" name="fbm" type="hidden" value="0"/>
# <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
# <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
# <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
# <input id="ie" name="ie" type="hidden" value="utf8"/>
# <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
# <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
# <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
# <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
# <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
# <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
# <div class="green_window" style="">
# <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
# <input accesskey="s" autocomplete="off" class="input_text" data-atcmp-element="" id="query" maxlength="255" name="query" onclick="document.getElementById('fbm').value=1;" placeholder="검색어를 입력해 주세요." style="ime-mode:active;" tabindex="1" title="검색어 입력" type="text" value=""/>
# </div>
# <button class="btn_submit" id="search_btn" onclick="window.nclick(this,'sch.action','','',event);" style="" tabindex="3" title="검색" type="submit">
# <span class="blind">검색</span>
# <span class="ico_search_submit"></span>
# </button>
# </fieldset>
# </form>
# <!-- 한글입력기 -->
# <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>
# <div id="_nx_kbd" style="display:none;"></div>
# <div class="autocomplete">
# <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
# <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>
# </div>
# <!-- 자동완성레이어 -->
# <div class="reatcmp" id="autoFrame" style="display: none;">
# <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
# <div class="ly_atcmp" data-atcmp-element="">
# <div class="api_atcmp_wrap">
# <!-- 최근검색어 -->
# <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _recent_layer" style="display:none;">
# <!-- [AU] _recent_header 클래스를 추가해주세요. -->
# <div class="atcmp_header _recent_header">
# <strong class="tit">최근검색어</strong>
# <div class="option">
# <!-- [AU] _delAll 클래스를 추가해주세요. -->
# <a aria-pressed="false" class="item _delAll" href="#" role="button">전체삭제</a>
# </div>
# </div>
# <div class="atcmp_container">
# <!-- [AU] _recent 클래스를 추가해주세요. -->
# <ul class="kwd_lst _recent">
# <!-- 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
# <a class="kwd" href="#">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>
# </a>
# <span class="etc">
# <em class="date">@date@.</em>
# <!-- [AU] _del 클래스를 추가해주세요. -->
# <a aria-pressed="false" class="bt_item _del" href="#" role="button"><i class="imsc ico_del">삭제</i></a>
# </span>
# </li>
# </ul>
# <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _offMsg 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_off _offMsg" style="display: none;">검색어 저장 기능이 꺼져 있습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span></div>
# <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
# <!-- [AU] _recentNone 클래스를 추가해주세요. -->
# <div class="kwd_info kwd_none _recentNone" style="display: none;">최근 검색어 내역이 없습니다.<br/><span class="kwd_dsc">설정이 초기화 된다면 <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">도움말</a>을 확인해주세요.</span></div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">도움말</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
# <a class="close _keywordOnOff" href="#">자동저장 끄기</a>
# </span>
# </span>
# </div>
# </div>
# <!-- 자동완성 -->
# <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
# <div class="atcmp_fixer _atcmp_layer" style="display:none;">
# <!-- [AU] _words 클래스를 추가해주세요. -->
# <div class="atcmp_container _words">
# <!-- 정답형 템플릿 : 로또당첨번호 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_lotto _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_3">
# <a class="link_item" href="#">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@5@회차 당첨번호</span>
# <span class="dsc">
# <span class="item">추첨 @13@.</span><span class="item">지급기한 1년</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc lotto">
# <em class="n@6@">@6@</em><em class="n@7@">@7@</em><em class="n@8@">@8@</em><em class="n@9@">@9@</em><em class="n@10@">@10@</em><em class="n@11@">@11@</em><em class="imsc_bf bonus n@12@">@12@</em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 환율 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_exchange _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_9">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a class="link_item @11@" href="#">
# <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
# <span class="common_ico_kwd"><i class="imsc ico @12@">@14@</i></span>
# <div class="dsc_area">
# <span class="tit">@txt@<span class="sub">@currency@</span></span>
# <span class="dsc">
# <span class="item"><i class="imsc ico_arr"></i>@8@(@9@%)</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc"><em class="num">@6@</em>원</span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_weather _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_11">
# <!-- [D] 상승 up, 하락 down 추가 -->
# <a class="link_item @12@" href="#">
# <span class="common_ico_kwd"><i class="imsc ico_search"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@7@, @message@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">
# <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
# <span class="ico_weather"><i class="imsc ico ico@iconNo@">@7@</i></span>
# <em class="degree">@8@<sup class="celsius">°</sup></em>
# </span>
# </span>
# </a>
# </div>
# <!-- 정답형 템플릿 : 사이트 바로가기 -->
# <!-- [AU] _answer 클래스를 추가해주세요. -->
# <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
# <div class="atcmp_correct type_site _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_17">
# <a class="link_item" href="@5@" target="_blank">
# <span class="common_ico_kwd"><i class="imsc ico_url"></i></span>
# <div class="dsc_area">
# <span class="tit">@txt@</span>
# <span class="dsc">
# <span class="item">@5@</span>
# </span>
# </div>
# <span class="etc_area">
# <span class="etc">바로가기</span>
# </span>
# </a>
# </div>
# <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
# <ul class="kwd_lst _kwd_list">
# <!-- [AU] 자동완성 검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="suggestion">
# <a class="kwd" href="#">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [AU] 최근검색어 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
# <a class="kwd" href="#">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>
# </a>
# <span class="etc">
# <!-- 최근검색어 있으면 날짜 표시 -->
# <em class="date">@date@.</em>
# <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# </ul>
# <!-- [AU] 문맥검색 템플릿 -->
# <!-- [AU] _item 클래스를 추가해주세요. -->
# <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
# <li class="item has_correct _item" data-intend-rank="@intendRank@" data-keyword="@transQuery@" data-rank="@rank@" data-template-type="intend">
# <a class="kwd" href="#">
# <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>
# </a>
# <span class="etc">
# <a aria-pressed="false" class="bt_item _add" href="#" role="button"><i class="imsc ico_insert">추가</i></a>
# </span>
# </li>
# <!-- [D] 선거안내문구 -->
# <!-- [AU] _alert 클래스를 추가해주세요. -->
# <div class="atcmp_alert _alert">
# <div class="dsc_election">
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
# <span class="dsc_inner">
# <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
# <span class="_alert_passage2"></span>
# <!-- [AU] _alert_link 클래스를 추가해주세요. -->
# <a class="link _alert_link" href="#" target="_blank">자세히보기</a>
# </span>
# </div>
# </div>
# <!-- [AU] _plus 클래스를 추가해주세요. -->
# <div class="atcmp_plus _plus">
# <div class="dsc_plus">
# <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/support/contents/contents.nhn?serviceNo=606&amp;categoryNo=16658" target="_blank">관심사를 반영한 컨텍스트 자동완성<i class="imsc ico_help">도움말</i></a>
# </div>
# <div class="switch">
# <!-- [D] 선택시 aria-pressed="ture/false" -->
# <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
# <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button"><i class="imsc ico_option">컨텍스트 자동완성</i></a>
# </div>
# <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
# <div class="layer_plus _plus_layer">
# <strong class="tit">컨텍스트 자동완성</strong>
# <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isloggedin" style="display:none">
# <p class="dsc">ON/OFF 설정은<br/>해당기기(브라우저)에 저장됩니다.</p>
# <div class="btn_area">
# <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/contents/contents.help?serviceNo=606&amp;categoryNo=16659" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
# <!-- [AU] style="display:none" 추가해주세요. -->
# <div class="_plus_layer_isnotloggedin" style="display:none">
# <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>
# <div class="btn_area">
# <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">로그인</a>
# <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">자세히</a>
# </div>
# </div>
# <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
# <a class="btn_close _plus_layer_close" href="#" role="button"><i class="imsc ico_close">컨텍스트 자동완성 레이어 닫기</i></a>
# </div>
# </div>
# </div>
# <div class="atcmp_footer">
# <span class="side_opt_area">
# <span class="opt_item"><a data-clk="sug.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1987" target="_blank">도움말</a></span>
# <span class="opt_item"><a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">신고</a></span>
# </span>
# <span class="rside_opt_area">
# <span class="opt_item">
# <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
# <a class="close _suggestOnOff" href="#">자동완성 끄기</a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--EMPTY-->
# <div id="gnb">
# <div class="gnb_inner" id="NM_FAVORITE">
# <div class="group_nav">
# <ul class="list_nav type_fix">
# <li class="nav_item">
# <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>
# </li>
# <li class="nav_item"><a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a></li>
# <li class="nav_item"><a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a></li>
# <li class="nav_item"><a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a></li>
# <li class="nav_item">
# <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>
# </li>
# </ul>
# <ul class="list_nav NM_FAVORITE_LIST">
# <li class="nav_item"><a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">사전</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.news" href="https://news.naver.com/">뉴스</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">증권</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.land" href="https://land.naver.com/">부동산</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.map" href="https://map.naver.com/">지도</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.vibe" href="https://vibe.naver.com/">VIBE</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.book" href="https://book.naver.com/">책</a></li>
# <li class="nav_item"><a class="nav" data-clk="svc.webtoon" href="https://comic.naver.com/">웹툰</a></li>
# </ul>
# <ul class="list_nav type_empty" style="display: none;"></ul>
# <a class="btn_more" data-clk="svc.more" href="#" role="button">더보기</a>
# <div class="ly_btn_area">
# <a class="btn NM_FAVORITE_ALL" data-clk="map.svcmore" href="more.html">서비스 전체보기</a>
# <a class="btn btn_set" data-clk="map.edit" href="#" role="button">메뉴설정</a>
# <a class="btn btn_reset" data-clk="edt.reset" href="#" role="button">초기화</a>
# <a class="btn btn_save" data-clk="edt.save" href="#" role="button">저장</a>
# </div>
# </div>
# <div class="group_weather" id="NM_WEATHER">
# <div>
# <a class="weather_area ico_w07" data-clk="squ.weat" href="https://weather.naver.com/today/09650107">
# <div class="current_box">
# <strong aria-label="현재기온" class="current">24.0°</strong><strong class="state">흐림</strong>
# </div>
# <div class="degree_box">
# <span aria-label="최저기온" class="min">22.0°</span><span aria-label="최고기온" class="max">26.0°</span>
# </div>
# <span class="location">반포동</span>
# </a>
# </div>
# <div>
# <a class="air_area" data-clk="squ.dust" href="https://weather.naver.com/today/09650107">
# <ul class="list_air">
# <li class="air_item">미세<strong class="state state_good">좋음</strong></li>
# <li class="air_item">초미세<strong class="state state_good">좋음</strong></li>
# </ul>
# <span class="location">반포동</span>
# </a>
# </div>
# </div>
# </div>
# <div class="ly_service">
# <div class="group_service NM_FAVORITE_ALL_LY"></div>
# <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;"></div>
# </div>
# </div>
# </div>
# <div id="container" role="main"> <div style="position:relative;width:1130px;margin:0 auto;z-index:11"> <div id="da_top"></div> <div id="da_expwide"></div> </div> <div class="column_left" id="NM_INT_LEFT"> <div id="veta_top"> <iframe data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10599&amp;nrefreshx=0" data-veta-preview="main_time" frameborder="0" height="135" id="da_iframe_time" marginheight="0" marginwidth="0" name="da_iframe_time" scrolling="no" title="광고" width="750"> </iframe> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div class="sc_newscast" id="newsstand"> <h2 class="blind">뉴스스탠드</h2> <div class="group_issue" data-clk-prefix="ncy" id="NM_NEWSSTAND_HEADER"> <div class="issue_area"> <a class="link_media" data-clk="newsflash" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">연합뉴스</a> <div class="list_issue" id="yna_rolling"> <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502252">장마시작 전국 곳곳서 비바람에 시설물 파손·정전…인명피해도</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502228">국민지원금 커트라인, 중위소득 180% 유력 검토…자산가는 배제</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502278">"델타변이 무서워"…재확산 공포에 '여행 취소' 잇따라</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502308">"가상 양자대결…이재명 44.7% 윤석열 36.7% '오차범위밖'"</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502292">민주 '反명연대' 뚜렷…기본소득 때리며 '본선 리스크' 부각</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502247">尹, 이재명 첫 직격 "점령군 발언, 황당무계 망언…용납못해"</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502259">"최소 85명 탑승한 필리핀 군용기 추락…15명 구조"</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502280">"GTX-D 노선 강남 직결 관철" 인천·김포 시민 차량 시위</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502067">상반기에 수도권 아파트값 13% 올랐다…19년만에 최고</a></div>
# <div><a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012502246">대학 女기숙사에 침입·촬영, 20대 중국인 검거</a></div> </div> </div> <div class="direct_area"> <a class="link_news" data-clk="newshome" href="http://news.naver.com/">네이버뉴스</a>
# <a class="link_direct" data-clk="entertainment" href="http://entertain.naver.com/home">연예</a>
# <a class="link_direct" data-clk="sports" href="http://sports.news.naver.com/">스포츠</a>
# <a class="link_direct" data-clk="economy" href="http://news.naver.com/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a> </div> </div> <div class="group_title" data-clk-prefix="nsd" id="NM_NEWSSTAND_TITLE"> <a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">뉴스스탠드</a> <div class="sort_area" id="NM_NEWSSTAND_data_buttons"> <a class="btn_sort" data-clk="my" data-type="my" href="#" role="button">구독한 언론사</a> <a class="btn_sort sort_on" data-clk="all" data-type="all" href="#" role="button">전체언론사</a> </div> <div class="set_area" id="NM_NEWSSTAND_view_buttons"> <a class="btn_set" data-clk="articleview" data-type="list" href="#" role="button"> <i class="ico_list"><span class="blind">리스트형</span></i></a> <a class="btn_set set_on" data-clk="pressview" data-type="thumb" href="#" role="button"> <i class="ico_tile"><span class="blind">썸네일형</span></i></a> <a class="btn_set" data-clk="set" href="http://newsstand.naver.com/config.html" target="_blank"> <i class="ico_set"><span class="blind">설정</span></i></a> </div> </div> <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative"> <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_LIST" style="display:none"> <a class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev" href="#" role="button"><i class="ico_btn"><span class="blind">이전</span></i></a> <a class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next" href="#" role="button"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="list_view"> <div class="option_area"> <div class="list_option_wrap"> <ul class="list_option"> <li class="option_item" data-cateid="ct2"><a class="option" data-clk="daei" href="#">종합/경제</a></li> <li class="option_item" data-cateid="ct3"><a class="option" data-clk="dtvcom" href="#">방송/통신</a></li> <li class="option_item" data-cateid="ct4"><a class="option" data-clk="dit" href="#">IT</a></li> <li class="option_item" data-cateid="ct5"><a class="option" data-clk="deng" href="#">영자지</a></li> <li class="option_item" data-cateid="ct6"><a class="option" data-clk="dsporent" href="#">스포츠/연예</a></li> <li class="option_item" data-cateid="ct7"><a class="option" data-clk="dmagtec" href="#">매거진/전문지</a></li> <li class="option_item" data-cateid="ct8"><a class="option" data-clk="dloc" href="#">지역</a></li> </ul> </div> </div> <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a"></div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" data-clk-sub="*a" style="display:none"> <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg">해당 언론사 사정으로 접근이 일시 제한됩니다.</p> <div class="popup_btn"> <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">확인</a> </div> </div> <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" data-clk-sub="*a" style="display:none"> <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button"><i class="ico_close"></i><span class="blind">닫기</span></a> <p class="popup_msg"><strong class="NM_NEWSSTAND_POPUP_PNAME"></strong>을(를)<br/>구독해지 하시겠습니까?</p> <div class="popup_btn"> <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">확인</a> <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">취소</a> </div> </div> <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none"> <p class="toast_msg">구독한 언론사에 추가되었습니다.</p> </div> </div> <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_THUMB" style="display:block"> <a class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev" href="#" role="button"><i class="ico_btn"><span class="blind">이전</span></i></a> <a class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next" href="#" role="button"><i class="ico_btn"><span class="blind">다음</span></i></a> <div class="_NM_UI_PAGE_CONTAINER" data-clk ...
# <div class="tile_view">
# <div class="frame_area">
# <i class="line to_right1"></i>
# <i class="line to_right2"></i>
# <i class="line to_right3"></i>
# <i class="line to_bottom1"></i>
# <i class="line to_bottom2"></i>
# <i class="line to_bottom3"></i>
# <i class="line to_bottom4"></i>
# <i class="line to_bottom5"></i>
# </div>
# <div class="thumb_area">
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="930">
# <a class="thumb" href="#">
# <img alt="뉴스타파" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/930.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="930" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="930" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="930" href="http://newsstand.naver.com/?list=&amp;pcode=930" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="330">
# <a class="thumb" href="#">
# <img alt="중앙데일리" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/330.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="330" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="330" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="330" href="http://newsstand.naver.com/?list=&amp;pcode=330" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="368">
# <a class="thumb" href="#">
# <img alt="데일리안" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/368.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="368" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="368" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="368" href="http://newsstand.naver.com/?list=&amp;pcode=368" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="021">
# <a class="thumb" href="#">
# <img alt="문화일보" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/021.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="021" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="021" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="021" href="http://newsstand.naver.com/?list=&amp;pcode=021" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="047">
# <a class="thumb" href="#">
# <img alt="오마이뉴스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/047.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="047" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="047" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="047" href="http://newsstand.naver.com/?list=&amp;pcode=047" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="139">
# <a class="thumb" href="#">
# <img alt="스포탈코리아" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/139.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="139" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="139" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="139" href="http://newsstand.naver.com/?list=&amp;pcode=139" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="055">
# <a class="thumb" href="#">
# <img alt="SBS" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/055.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="055" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="055" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="055" href="http://newsstand.naver.com/?list=&amp;pcode=055" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="032">
# <a class="thumb" href="#">
# <img alt="경향신문" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/032.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="032" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="032" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="032" href="http://newsstand.naver.com/?list=&amp;pcode=032" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="014">
# <a class="thumb" href="#">
# <img alt="파이낸셜뉴스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/014.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="014" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="014" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="014" href="http://newsstand.naver.com/?list=&amp;pcode=014" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="015">
# <a class="thumb" href="#">
# <img alt="한국경제" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/015.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="015" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="015" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="015" href="http://newsstand.naver.com/?list=&amp;pcode=015" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="030">
# <a class="thumb" href="#">
# <img alt="전자신문" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/030.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="030" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="030" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="030" href="http://newsstand.naver.com/?list=&amp;pcode=030" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="025">
# <a class="thumb" href="#">
# <img alt="중앙일보" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/025.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="025" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="025" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="025" href="http://newsstand.naver.com/?list=&amp;pcode=025" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="029">
# <a class="thumb" href="#">
# <img alt="디지털타임스" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/029.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="029" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="029" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="029" href="http://newsstand.naver.com/?list=&amp;pcode=029" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="422">
# <a class="thumb" href="#">
# <img alt="연합뉴스TV" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/2020/logo/light/0604/422.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="422" href="#" role="button">구독</a>
# <a class="btn_popup _NM_NEWSSTAND_THUMB_unsubscribe_press" data-clk="unsub" data-pid="422" href="#" role="button">해지</a>
# <a class="btn_popup" data-clk="logo" data-pid="422" href="http://newsstand.naver.com/?list=&amp;pcode=422" target="_blank">기사보기</a>
# </div>
# </div>
# <div class="thumb_box _NM_NEWSSTAND_THUMB _NM_NEWSSTAND_THUMB_press_valid" data-pid="109">
# <a class="thumb" href="#">
# <img alt="OSEN" class="news_logo" height="20" src="https://s.pstatic.net/static/newsstand/up/2020/0610/nsd151458769.png"/>
# <span class="thumb_dim"></span></a>
# <div class="popup_wrap">
# <a class="btn_popup _NM_NEWSSTAND_THUMB_subscribe_press" data-clk="sub" data-pid="109" href="#" role="button">구독</a>
# ...
# <div class="source_box">
# <span class="date">1주일 전</span>
# <span class="source"><span class="source_inner">함께N</span></span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="CAS_30e6e9fc-d7d4-11eb-a06a-b556084e5679">
# <a class="theme_thumb" data-clk="tcc_pub.list1cont5" href="https://post.naver.com/viewer/postView.nhn?volumeNo=31752883&amp;memberNo=30729681&amp;vType=VERTICAL" target="_blank">
# <img alt="유기동물에게 희망을 전하는 최진혁의 '꽃신'" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0628%2Fupload_1624872992649IyHVo.jpg%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0628%2Fupload_1624872992649IyHVo.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_pub.list1cont5" href="https://post.naver.com/viewer/postView.nhn?volumeNo=31752883&amp;memberNo=30729681&amp;vType=VERTICAL" target="_blank">
# <em class="theme_category"> 함께N</em>
# <strong class="title elss">유기동물에게 희망을 전하는 최진혁의 '꽃신'</strong>
# <p class="desc">안녕하세요 여러분지트리입니다오늘은 마음이 따뜻해지는 소식을 전해드려요~! 네이버 해피빈 펀딩으로유기동물에게 희망을 선물한 진혁 배우의비하인드를 공개할게요 비주얼도 훈훈마음도 훈훈 반려견 몽실이를 생각하며모든 유기동물이 행복해지길 바랐다는 진혁 배우 다함께 꽃길 걸어요 촬영이 시작되자진지한 포즈로찰칵찰칵 잘 나왔으려나?확인도 해보고 (힐끔힐끔) 익살스러운 웃</p>
# <div class="source_box">
# <span class="date">2주일 전</span>
# <span class="source"><span class="source_inner">지트리크리에이티브</span></span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="group_theme" data-block-code="PC-THEME-WITH-MOBILE-RANKING-DEFAULT-1" data-block-id="" data-block-type="MATERIALS" data-da="container" data-index="" data-page="1" data-template-code="MOBILE-RANKING-LIST">
# <div class="list_theme_wrap">
# <ul class="list_theme">
# <li class="theme_item" data-da-position="true" data-gdid="CAS_ad276b95-da2c-11eb-a63b-23eaf87985a2">
# <a class="theme_thumb" data-clk="tcc_pub.list2cont1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=31684926&amp;memberNo=44966329" target="_blank">
# <img alt="세상의 모든 여성들을 응원하는 수제화 브랜드" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0701%2Fupload_1625128930336Xxdp8.jpg%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0701%2Fupload_1625128930336Xxdp8.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_pub.list2cont1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=31684926&amp;memberNo=44966329" target="_blank">
# <em class="theme_category"> 함께N</em>
# <strong class="title elss">세상의 모든 여성들을 응원하는 수제화 브랜드</strong>
# <p class="desc">수제화의 대중화를 꿈꾸다 유리엘라‘신의 빛’이라는 뜻의 유리엘라는 수제화의 대중화를 외치며 수제화 시장에 혜성처럼 등장했다. 세상의 모든 여성을 위해 발이 편한 신발을 만들겠다는 목적으로 저렴한 가격의 수제화를 선보이는 브랜드다. 오랜 내공을 가진 프리미엄 수제화 브랜드 파시나르에서 새롭게 론칭한 곳이기도 하다. 시시각각 변하는 유행에</p>
# <div class="source_box">
# <span class="date">3주일 전</span>
# <span class="source"><span class="source_inner">작은가게오래가게</span></span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="CAS_2dde6d37-d973-11eb-873e-dd0cf4ec74c3">
# <a class="theme_thumb" data-clk="tcc_pub.list2cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=31874684&amp;memberNo=418365" target="_blank">
# <img alt='"버럭 할멈, 그게 내 이름이었습니다"' data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0630%2Fupload_16250441279592V9J3.jpg%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0630%2Fupload_16250441279592V9J3.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_pub.list2cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=31874684&amp;memberNo=418365" target="_blank">
# <em class="theme_category"> 함께N</em>
# <strong class="title elss">"버럭 할멈, 그게 내 이름이었습니다"</strong>
# <p class="desc">계속된 다툼 끝에 침묵을 선택한 윤 할머니2018년 3월 우리 양로원으로 오신 윤인자(가명) 할머니는, 시설 생활이 처음이 아니었습니다. 그 전에 지내셨던 양로원에서는 다른 어르신들과의 다툼으로 인해 어쩔 수 없이 퇴소를 하셨습니다.내가 무슨 말만 하면 썽(성) 낸다고 한다!청력이 많이 약하신 윤 할머니는 다른 어르신들의 이야기</p>
# <div class="source_box">
# <span class="date">3일 전</span>
# <span class="source"><span class="source_inner">재단법인해피빈</span></span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="CAS_2dde6d38-d973-11eb-873e-8b0934f3b39b">
# <a class="theme_thumb" data-clk="tcc_pub.list2cont3" href="https://blog.naver.com/nv_withn/222406470954" target="_blank">
# <img alt="청년 농부가 스마트하게 키운 A급 표고버섯" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0630%2Fupload_1625039819421fW83L.jpg%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0630%2Fupload_1625039819421fW83L.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_pub.list2cont3" href="https://blog.naver.com/nv_withn/222406470954" target="_blank">
# <em class="theme_category"> 함께N</em>
# <strong class="title elss">청년 농부가 스마트하게 키운 A급 표고버섯</strong>
# <p class="desc">국내 최초 ICT(정보통신기술)를 도입해 표고버섯을 재배하는 농장이 있다. 스마트 팜 시설에서 농사를 지어, 연중 내내 버섯 생산이 가능한 이곳. 청년 농부로서 다양한 도전을 하고 있는 이현호 대표는 ‘A급 농부’라는 타이틀을 갖기 위해 오늘도 비지땀을 흘리고 있다. 젊은 나이에 귀농을 선택하신 계기가 궁금해요. 농사에 대한 뜻을 갖게 된 건 호주로 워킹홀</p>
# <div class="source_box">
# <span class="date">1주일 전</span>
# <span class="source"><span class="source_inner">함께N</span></span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="CAS_5b3c4a0b-d8b5-11eb-a63b-490c33607f32">
# <a class="theme_thumb" data-clk="tcc_pub.list2cont4" href="https://post.naver.com/viewer/postView.naver?volumeNo=31712002&amp;memberNo=418365" target="_blank">
# <img alt='"이제는 연희 할머니라는 말이 정말 좋아요"' data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0629%2Fupload_1624956896498YFREc.jpg%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0629%2Fupload_1624956896498YFREc.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_pub.list2cont4" href="https://post.naver.com/viewer/postView.naver?volumeNo=31712002&amp;memberNo=418365" target="_blank">
# <em class="theme_category"> 함께N</em>
# <strong class="title elss">"이제는 연희 할머니라는 말이 정말 좋아요"</strong>
# <p class="desc">손녀와 단 둘이 막막했던 그때 찾아온 따뜻한 관심엄마 품이 아닌 할머니 품에서 4살을 맞이한 연희(가명)와 늦깎이 어머니이자 젊은 할머니로 손녀딸 돌보던 춘영(가명, 64세) 어머니를 기억하시나요? 조손가정 춘영 어머니는 2017년 1월 이후 해피빈 모금함을 통한 지원으로 지금까지 손녀 딸과 알콩달콩 생활하고 계십니다.춘영 어머</p>
# <div class="source_box">
# <span class="date">3주일 전</span>
# <span class="source"><span class="source_inner">재단법인해피빈</span></span>
# </div>
# </a>
# </li>
# <li class="theme_item" data-da-position="true" data-gdid="CAS_48cd86cc-d3f1-11eb-80b8-7d2f00efee47">
# <a class="theme_thumb" data-clk="tcc_pub.list2cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=31833451&amp;memberNo=418365" target="_blank">
# <img alt="누군가 버린 김치 대신 새 김치를 채워 넣습니다" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0624%2Fupload_1624525949779KvJaT.jpg%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2021%2F0624%2Fupload_1624525949779KvJaT.jpg%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_pub.list2cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=31833451&amp;memberNo=418365" target="_blank">
# <em class="theme_category"> 함께N</em>
# <strong class="title elss">누군가 버린 김치 대신 새 김치를 채워 넣습니다</strong>
# <p class="desc">새벽에 줍는 폐지로도 살 수 없었던 ‘새’ 김치2018년 10월, 다가올 겨울 속 어르신의 텅 빈 냉장고를 채우기 위한 ‘포기하지 마세요. 우리가 한 포기 더 할게요.’ 모금함을 기억하고 계시나요? 살기 위해 이른 새벽이면 굶주린 배를 움켜쥐고, 굽은 허리를 간신히 펴고는 폐지를 줍던 정간난(가명, 84세&amp;</p>
# <div class="source_box">
# <span class="date">1주일 전</span>
# <span class="source"><span class="source_inner">재단법인해피빈</span></span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div> </div> <div class="column_right" id="NM_INT_RIGHT"> <div class="column_fix_wrap"> <div id="da_brand"></div>
# <div class="sc_login" id="account">
# <h2 class="blind">Sign in</h2>
# <p class="login_msg">Connect with people</p>
# <a class="link_login" data-clk="log_off.login" href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com"><i class="ico_naver"><span class="blind">NAVER</span></i>Sign in</a>
# <div class="sub_area">
# <div class="look_box">
# <a class="link_look" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">Forgot Username</a>
# <a class="link_look" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">Password</a>
# </div>
# <a class="link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">Sign up</a>
# </div>
# </div>
# <div class="sc_timesquare" id="timesquare"> <h2 class="blind">타임스퀘어</h2> <div class="card_wrap">
# <div class="card_nav">
# <a class="btn_nav btn_prev" data-clk="squ.pre" href="#" role="button"><span class="blind">이전</span></a>
# <a class="btn_nav btn_next" data-clk="squ.next" href="#" role="button"><span class="blind">다음</span></a>
# </div>
# <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
# <div>
# <a class="card_news" data-clk="squ.line3" href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819"><i class="news_badge">이슈</i><span class="news">코로나바이러스감염증-19 현황</span></a>
# </div>
# </div>
# </div> <!-- EMPTY --> </div> <div id="veta_branding"> <iframe data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10601&amp;nrefreshx=0" data-veta-preview="main_rolling" frameborder="0" height="200" id="da_iframe_rolling" marginheight="0" marginwidth="0" name="da_iframe_rolling" scrolling="no" title="광고" width="350"></iframe> <span class="veta_bd_t"></span> <span class="veta_bd_b"></span> <span class="veta_bd_l"></span> <span class="veta_bd_r"></span> </div> <div class="sc_shopcast" id="shopcast"> <iframe data-iframe-src="https://castbox.shopping.naver.com/shoppingboxnew/main.nhn" frameborder="0" height="1539" id="shopcast_iframe" marginheight="0" marginwidth="0" scrolling="no" title="쇼핑캐스트" width="350"></iframe> </div> </div> </div> <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a> <button aria-pressed="false" class="btn_theme" id="NM_darkmode_btn" role="button" type="button"> <span class="blind">라이트 모드로 보기</span> </button> </div> <div id="footer" role="contentinfo"> <div class="footer_inner"> <div class="banner_area"> <div class="da_box_wrap"> <div id="da_public_left"> <iframe data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10641&amp;nrefreshx=0" frameborder="0" height="86" id="da_iframe_bottom_left" scrolling="no" title="광고" width="350"></iframe> </div> <div id="da_public_right"> <iframe data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10642&amp;nrefreshx=0" frameborder="0" height="86" id="da_iframe_bottom_right" scrolling="no" title="광고" width="350"></iframe> </div> <div id="veta_time2"> <iframe data-iframe-src="https://siape.veta.naver.com/fxshow?su=SU10640&amp;nrefreshx=0" data-veta-preview="main_below" frameborder="0" height="86" id="da_iframe_below" name="da_iframe_below" scrolling="no" title="광고" width="350"> </iframe> </div> </div> </div> <div class="notice_area" data-clk-prefix="ntc"> <div class="notice_box"> <h3 class="title"><a href="https://www.naver.com/NOTICE">공지사항</a> </h3>
# <a class="notice_msg" data-clk="notice" href="https://www.naver.com/NOTICE/read/1100001014/10000000000030671651">'비밀번호 관리 프로그램' 사용에 주의해 주세요.</a> </div> <a class="link_all" data-clk="svcmap" href="more.html">서비스 전체보기</a> </div> <div class="aside_area"> <div class="partner_box_wrap"> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Creators</h3> <a class="link_partner" data-clk="creator" href="https://www.navercorp.com/service/creators">크리에이터</a> <a class="link_partner" data-clk="smbusiness" href="https://www.navercorp.com/service/business">스몰비즈니스</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Partners</h3> <a class="link_partner" data-clk="sme" href="https://campaign.naver.com/smefullcare/online/">SME 풀케어 시스템</a> <a class="link_partner" data-clk="service" href="https://business.naver.com/service.html">비즈니스 · 광고</a> <a class="link_partner" data-clk="store" href="https://sell.storefarm.naver.com/#/home/about">스토어 개설</a> <a class="link_partner" data-clk="place" href="https://smartplace.naver.com">지역업체 등록</a> <a class="link_partner" data-clk="expert" href="https://expert.naver.com/expert/introduction?tab=guide#join">엑스퍼트 등록</a> </div> <div class="partner_box" data-clk-prefix="crt"> <h3 class="title">Developers</h3> <a class="link_partner" data-clk="center" href="https://developers.naver.com">네이버 개발자 센터</a> <a class="link_partner" data-clk="openapi" href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md">오픈 API</a> <a class="link_partner" data-clk="opensource" href="https://naver.github.io">오픈소스</a> <a class="link_partner" data-clk="d2" href="https://d2.naver.com">네이버 D2</a> <a class="link_partner" data-clk="naverD2SF" href="http://d2startup.com">네이버 D2SF</a> <a class="link_partner" data-clk="labs" href="https://www.naverlabs.com">네이버 랩스</a> </div> </div> <div class="service_box_wrap"> <div class="service_box" data-clk-prefix="wbd"> <a class="service_logo" data-clk="bt" href="http://whale.naver.com/"> <img alt="웨일" height="48" src="data:image/png;base64,..." width="48"/> </a> <div class="service_info"> <strong class="title">웨일 브라우저</strong> <a class="dsc" data-clk="bt" href="http://whale.naver.com/">다운받기</a> </div> </div> <div class="service_box" data-clk-prefix="prj"> <a class="service_logo" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83"> <img alt="꽃" height="50" src="data:image/png;base64,..." width="47"/> </a> <div class="service_info"> <strong class="title">프로젝트 꽃</strong> <a class="dsc" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">바로가기</a> </div> </div> </div> </div> <div class="corp_area" data-clk-prefix="plc"> <h3 class="blind">네이버 정책 및 약관</h3> <ul class="list_corp"> <li class="corp_item"><a data-clk="intronhn" href="https://www.navercorp.com">회사소개</a></li> <li class="corp_item"><a data-clk="recruit" href="https://recruit.navercorp.com/naver/recruitMain">인재채용</a></li> <li class="corp_item"><a data-clk="contact" href="https://www.navercorp.com/naver/proposalGuide">제휴제안</a></li> <li class="corp_item"><a data-clk="service" href="/policy/service.html">이용약관</a></li> <li class="corp_item"><a data-clk="privacy" href="/policy/privacy.html"><strong>개인정보처리방침</strong></a></li> <li class="corp_item"><a data-clk="youth" href="/policy/youthpolicy.html">청소년보호정책</a></li> <li class="corp_item"><a data-clk="policy" href="/policy/spamcheck.html">네이버 정책</a></li> <li class="corp_item"><a data-clk="helpcenter" href="https://help.naver.com/">고객센터</a></li> </ul> <address class="addr"><a data-clk="nhn" href="https://www.navercorp.com" target="_blank">ⓒ NAVER Corp.</a></address> </div> </div> </div> </div> <div id="adscript" style="display:none"></div> </body> </html>

# %%
# 태그 : HTML의 해당 태그에 대한 첫 번째 정보를 가져옴
# 태그['속성'] : HTML 해당 태그의 속성에 대한 첫 번째 정보를 가져옴
import requests
from bs4 import BeautifulSoup
req = requests.get('https://naver.com')
html = req.text
soup = BeautifulSoup(html, 'html.parser')

print(soup.title)
print(soup.title.name)
print(soup.title.string)
print(soup.img)
print(soup.img['alt'])
print(soup.a['href'])
# Out:
# <title>NAVER</title>
# title
# NAVER
# <img alt="" height="49" src="https://static-whale.pstatic.net/main/img_darkmode_v3@2x.png" style="padding-left: 92px" width="215.5"/>
#
# #newsstand

# %%
import urllib
response = urllib.request.urlopen('https://naver.com')
byte_data = response.read()
html = byte_data.decode('utf-8')
html
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20210601a.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>document.domain="naver.com",window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent;window.nmain.isIE=navigator.appName&&navigator.appName.indexOf("Explorer")>0&&ua.toLocaleLowerCase().indexOf("msie 10.0")<0,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function a(){}return a.prototype=n,new a})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script> <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"ANIMAL":{"menu":"ANIMAL","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000161","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_1","tb":"ANIMAL_1","unit":"SU10567","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000162","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_animal_2","tb":"ANIMAL_1","unit":"SU10568","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"BUSINESS":{"menu":"BUSINESS","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000165","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_1","tb":"BUSINESS_1","unit":"SU10577","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000166","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_business_2","tb" ...

# %%
import urllib
response = urllib.request.urlopen('https://naver.com')
byte_data = response.read()
html = byte_data.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
print(soup.find('a'))
print(soup.find(class_='blind'))
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>
# <span class="blind">NAVER whale</span>

# %%
print(soup.find_all('a',limit=2))
# Out:
# [<a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>, <a href="#themecast"><span>주제별캐스트 바로가기</span></a>]

# %%
print(soup.find_all('a')[0])
# Out:
# <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a>

# %%
print(soup.find_all('span',class_='blind'))
# Out:
# [<span class="blind">NAVER whale</span>, <span class="blind">네이버</span>, <span class="blind">쥬니어네이버</span>, <span class="blind">해피빈</span>, <span class="blind">검색</span>, <span class="blind">한글 입력기</span>, <span class="blind">자동완성 레이어</span>, <span class="blind">쇼핑</span>, <span class="blind">쇼핑LIVE</span>, <span class="blind">리스트형</span>, <span class="blind">썸네일형</span>, <span class="blind">설정</span>, <span class="blind">이전</span>, <span class="blind">다음</span>, <span class="blind">닫기</span>, <span class="blind">닫기</span>, <span class="blind">이전</span>, <span class="blind">다음</span>, <span class="blind">닫기</span>, <span class="blind">닫기</span>, <span class="blind">이전</span>, <span class="blind">다음</span>, <span class="blind">다음</span>, <span class="blind">닫기</span>, <span class="blind">닫기</span>, <span class="blind">이전</span>, <span class="blind">다음</span>, <span class="blind">닫기</span>, <span class="blind">닫기</span>, <span class="blind">이전</span>, <span class="blind">다음</span>, <span class="blind">재생</span>, <span class="blind">재생</span>, <span class="blind">재생</span>, <span class="blind">NAVER</span>, <span class="blind">이전</span>, <span class="blind">다음</span>, <span class="blind">TOP</span>, <span class="blind">라이트 모드로 보기</span>]

# %%
html = '''
[<div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #f3f1ff">
<div class="tY_u8r23">
<a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/banner/details/darkmode?=main&amp;wpid=RydDy7"></a>
<i class="_1KncATpM"><span class="blind">NAVER whale</span></i>
<img alt="" height="49" src="https://static-whale.pstatic.net/main/img_darkmode@2x.png" style="padding-left: 48px" width="303"/>
<span class="_1syGnXOL _3di88A4c" data-clk="dropbanner1a" style="padding-right: 10px; padding-left: 8px"><span>여러분의
눈은 소중하니까, </span><strong>지금 바로 다크 모드를 켜세요!</strong></span>
<a class="_2aeXMlrb" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #7c56d5">다운로드</span></a>
<button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" style="display: none" type="button">
3일 동안 보지 않기
</button>
</div>
</div>]
'''
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# [
# <div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #f3f1ff">
#  <div class="tY_u8r23">
#   <a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/banner/details/darkmode?=main&amp;wpid=RydDy7">
#   </a>
#   <i class="_1KncATpM">
#    <span class="blind">
#     NAVER whale
#    </span>
#   </i>
#   <img alt="" height="49" src="https://static-whale.pstatic.net/main/img_darkmode@2x.png" style="padding-left: 48px" width="303"/>
#   <span class="_1syGnXOL _3di88A4c" data-clk="dropbanner1a" style="padding-right: 10px; padding-left: 8px">
#    <span>
#     여러분의
# 눈은 소중하니까,
#    </span>
#    <strong>
#     지금 바로 다크 모드를 켜세요!
#    </strong>
#   </span>
#   <a class="_2aeXMlrb" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn">
#    <span style="background-color: #7c56d5">
#     다운로드
#    </span>
#   </a>
#   <button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" style="display: none" type="button">
#    3일 동안 보지 않기
#   </button>
#  </div>
# </div>
# ]

# %%
print(soup.find_all('div', id="NM_TOP_BANNER" ))
# Out:
# [<div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #f3f1ff">
# <div class="tY_u8r23">
# <a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/banner/details/darkmode?=main&amp;wpid=RydDy7"></a>
# <i class="_1KncATpM"><span class="blind">NAVER whale</span></i>
# <img alt="" height="49" src="https://static-whale.pstatic.net/main/img_darkmode@2x.png" style="padding-left: 48px" width="303"/>
# <span class="_1syGnXOL _3di88A4c" data-clk="dropbanner1a" style="padding-right: 10px; padding-left: 8px"><span>여러분의
# 눈은 소중하니까, </span><strong>지금 바로 다크 모드를 켜세요!</strong></span>
# <a class="_2aeXMlrb" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #7c56d5">다운로드</span></a>
# <button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" style="display: none" type="button">
# 3일 동안 보지 않기
# </button>
# </div>
# </div>]

# %%
print(soup.find_all('span',class_='blind'))
# Out:
# [<span class="blind">NAVER whale</span>]

# %%
print(soup.find_all('span',attrs={'class':'blind'}))
# Out:
# [<span class="blind">NAVER whale</span>]

# %%
import urllib
response = urllib.request.urlopen('https://naver.com')
byte_data = response.read()
html = byte_data.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
print(soup.find_all(string='자동완성 끄기'))
print(soup.find_all(string=re.compile("자동완성 끄기")))
# Out:
# ['자동완성 끄기']
# ['자동완성 끄기']

# %%
import re
print(soup.find_all(string="네이버"))
print(soup.find_all(string=re.compile("네이버")))
# Out:
# ['네이버']
# ['네이버', '네이버를 시작페이지로', '쥬니어네이버', '네이버뉴스', '언론사가 직접 편집한 뉴스들을 네이버 홈에서 바로 보실 수 있습니다.', '네이버 공연전시', "세계 최고의 클래식 공연 실황부터 인기 뮤지컬, 대학로 LIVE, 다큐멘터리 필름까지! 어디에도 없는 특별한 콘텐츠를 보고 싶다면? 네이버 공연전시 에디터가 직접 선별해 추천하는 이달의 추천작! 6월의 큐레이터, [뮤지컬 배우 정성화]와 함께 하는 '세계 4대 뮤지컬'입니다. ‘세계 4대 뮤지컬’이 뭔지 아시나요? 공연에 관심이 있는 ", '네이버 공연전시', '네이버 공연전시', '공연 <Minyo(미뇨)>｜이희문컴퍼니 파격의 아이콘 경기소리꾼 이희문의 신작 공연 <Minyo(미뇨)> 온라인 콘서트가 오는 7월 23일 오후 8시, 24일 오후 5시 네이버 공연 후원라이브를 통해 진행한다. 이희문은 코로나19 이후, 현장공연의 형태로 작품활동을 해오던 그 동안의 방식을 탈피하고 영상매체로 활동 영역을 넓히기 위해 ', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', "네이버 공연전시가 뮤지컬 <하데스타운>의 배우 박강현이 부른 'Epic III' 뮤직비디오를 선공개한다. <하데스타운>은 지난 6월 10일 배우 조형균이 부른 첫 한국어 음원 'Epic III'을 공개한 바 있다. 해당 영상은 뜨거운 관심을 받으며 <하데스타운> 한국 공연에 대한 궁금증을 고조시켰다. 이어서 공개되는 두 번째", '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', '네이버 공연전시', "네이버 '개인정보 처리방침' 변경에 대한 안내 말씀드립니다.", '네이버 개발자 센터', '네이버 D2', '네이버 D2SF', '네이버 랩스', '네이버 정책 및 약관', '네이버 정책']

# %%
# get_text() : 검색 결과에서 태그를 제외한 텍스트만 출력
# get('속성') : 해당 속성의 값을 출력
import requests
from bs4 import BeautifulSoup
req = requests.get("https://movie.naver.com")
html = req.text
soup = BeautifulSoup(html, 'html.parser')
text = soup.find('span', attrs={'class':'blind'})
print(text)
print(text.get_text())
print(text.get('class'))
# Out:
# <span class="blind">영화검색 영역</span>
# 영화검색 영역
# ['blind']

# %%
text = '''
<a id="NM_set_home_btn" href="https://help.naver.com/support/welcomePage/guide.help" 
class="link_set" data-clk="top.mkhome">네이버를 시작페이지로</a>
<i class="sa_bar"></i>
'''
soup = BeautifulSoup(text,'html.parser')
print(soup.string)
soup2 = BeautifulSoup(text,'html.parser')
result = soup2.find('a',class_='link_set')
print(result)
print(result.string)
# Out:
# None
# <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>
# 네이버를 시작페이지로

# %% [markdown]
# select_one(), select()
# - CSS 선택자를 활용하여 원하는 정보를 가져옴(태그를 검색하는 find, find_all과 비슷함)
# - class는 ., id는 #로 표시

# %%
# 네이버 환율 가져오기
from bs4 import BeautifulSoup
import urllib.request as req
# HTML 가져오기
url = "https://finance.naver.com/marketindex/"
res = req.urlopen(url)
# HTML 분석하기
soup = BeautifulSoup(res, "html.parser")
# 원하는 데이터 추출하기 --- (※1)
price = soup.select_one("div.head_info > span.value").string
print("usd/krw =", price)
# Out:
# usd/krw = 1,195.00

# %%
from bs4 import BeautifulSoup 
import re # 정규 표현식을 사용할 때 --- (※1)
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""
soup = BeautifulSoup(html, "html.parser")
# 정규 표현식으로 href에서 https인 것 추출하기 --- (※2)
li = soup.find_all(href=re.compile(r"^https://"))
for e in li: print(e.attrs['href'])
# Out:
# https://example.com/fuga
# https://example.com/foo

# %%
# Q. 네이버 영화 랭킹 가져와서 조회순 첫번째 영화제목을 출력하세요.
import requests
from bs4 import BeautifulSoup
req = requests.get("https://movie.naver.com/movie/sdb/rank/rmovie.nhn")
html = req.text
soup = BeautifulSoup(html, 'html.parser')
print(soup.find('div',class_='tit3').text)
# Out:
# 탑건: 매버릭

# %%
# Q. 네이버 영화 랭킹 가져와서 조회순 전체 영화제목을 출력하세요.
soup = BeautifulSoup(html, 'html.parser')
# print(soup)
movie_ranking_list = soup.find_all('div',class_='tit3')
for i in range(len(movie_ranking_list)):
    print(f'{i+1}위: {movie_ranking_list[i].get_text().strip()}')
#     print("{:2} 위:{}".format(i+1,movie_ranking_list[i].get_text().strip()))
# Out:
# 1위: 탑건: 매버릭
# 2위: 토르: 러브 앤 썬더
# 3위: 헤어질 결심
# 4위: 마녀(魔女) Part2. The Other One
# 5위: 외계+인 1부
# 6위: 더 킬러: 죽어도 되는 아이
# 7위: 범죄도시2
# 8위: 한산: 용의 출현
# 9위: 엘비스
# 10위: 그레이 맨
# 11위: 명탐정 코난: 할로윈의 신부
# 12위: 비상선언
# 13위: 뒤틀린 집
# 14위: 미니언즈2
# 15위: 브로커
# 16위: 멘
# 17위: 큐어
# 18위: 핸썸
# 19위: 버즈 라이트이어
# 20위: 로스트 도터
# 21위: 메모리
# 22위: 쥬라기 월드: 도미니언
# 23위: 닥터 스트레인지: 대혼돈의 멀티버스
# 24위: 감동주의보
# 25위: 헌트
# 26위: 썸머 필름을 타고!
# 27위: 마녀
# 28위: 룸 쉐어링
# 29위: 놉
# 30위: 탑건
# 31위: 빅샤크4 : 바다공룡 대모험
# 32위: 뽀로로 극장판 드래곤캐슬 대모험
# 33위: 불릿 트레인
# 34위: 극장판 주술회전 0
# 35위: 노스맨
# 36위: 군다
# 37위: 리미트
# 38위: 이상한 나라의 수학자
# 39위: 섹스 앤 퓨리
# 40위: 미친 능력
# 41위: 체리마호: 30살까지 동정이면 마법사가 될 수 있대
# 42위: 스파이형 모델
# 43위: 니얼굴
# 44위: 위대한 침묵
# 45위: 아바타: 물의 길
# 46위: 경아의 딸
# 47위: 클라우스
# 48위: 주(咒)
# 49위: 로스트 시티
# 50위: 베일리 어게인

# %%
# [과제] 기상청 육상 정보에서 강원도의 지역번호는 105이다. 강원도의 날씨예보를 출력하세요.
url = 'https://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105'

# %%
# requests
import requests
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105"
res = requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# '(강수) 23일(토) 오후~24일(일) 오전까지 강원도에 비가 오겠고, 강원영동은 오후까지 이어지는 곳이 있겠습니다. 27일(수)은 강원영서에 비가 오겠습니다.(기온) 이번 예보기간 아침 기온은 17~26도, 낮 기온은 24~33도로 어제(19일, 아침최저기온 16~24도, 낮최고기온 26~32도)과 비슷하겠습니다.(해상) 동해중부해상의 물결은 1.0~2.0m로 일겠습니다.(주말전망) 23일(토) 오후~24일(일) 오전까지 강원도에 비가 오겠고, 강원영동은 오후까지 이어지는 곳이 있겠습니다. 아침 기온은 17~23도, 낮 기온은 25~30도가 되겠습니다. 이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며, 정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
# urllib
import re
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse

API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
# 매개변수를 URL 인코딩합니다. --- (※1)
values = {
    'stnId': '105'
}
params = urllib.parse.urlencode(values)
# 요청 전용 URL을 생성합니다. --- (※2)
url = API + "?" + params
print("url=", url)

res = urllib.request.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').string
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105
# '(강수) 23일(토) 오후~24일(일) 오전까지 강원도에 비가 오겠고, 강원영동은 오후까지 이어지는 곳이 있겠습니다. 27일(수)은 강원영서에 비가 오겠습니다.(기온) 이번 예보기간 아침 기온은 17~26도, 낮 기온은 24~33도로 어제(19일, 아침최저기온 16~24도, 낮최고기온 26~32도)과 비슷하겠습니다.(해상) 동해중부해상의 물결은 1.0~2.0m로 일겠습니다.(주말전망) 23일(토) 오후~24일(일) 오전까지 강원도에 비가 오겠고, 강원영동은 오후까지 이어지는 곳이 있겠습니다. 아침 기온은 17~23도, 낮 기온은 25~30도가 되겠습니다. 이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며, 정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %% [markdown]
# ##매직 명령어<br>
#
# ---
#
#
# https://binaryworld.tistory.com/20

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %%writefile testwf.txt
#
# print('매직 명령어')
# Out:
# Writing testwf.txt

# %%
# %load testwf.txt

print('매직 명령어')

# %%
# %ls

# %%
# 매직명령어 저장
# %%writefile index.html

<!DOCTYPE html>
<html lang="en">
<head>
    
    <title>케빈의 홈페이지</title>
    <link href = "./practice.css" rel="stylesheet" type="text/css">

    <script type="javascript">
        
    </script>
    <script type="text/javascript" src="add_two_numbers.js"></script>
    <script type="text/javascript" src="what_time_is_it.js"></script>
</head>
<body>
    <nav>
        <a href="./index.html">Home</a>
        <a href="./blog_list.html">Blog</a>
        <a href="./about_me.html">About</a>
    </nav>

    <h1>첫번째 헤드라인</h1>
    <h2>두번째 헤드라인</h2>

    <button onclick="whatTimeIsIt()">현재시간</button>
    <hr/>
    <label for="inputA">a</label>
    <input id="inputA" value=1 onkeyup="doSomething()">
    <label for="inputB">b</label>
    <input id="inputB" value=2 onkeyup="doSomething()">

    <p><span id="valueA">1</span> + <span id="valueB">2</span>=<span id="valueC">3</span>입니다.</p>
    
    <p>프로젝트 기반 빅데이터 서비스 솔루션 개발 전문과정</p>
    <p id = "content">
        핵심적인 요소기술 14개 모듈 
    </p>
    <p id = "content">
        빅데이터 머신러닝 프로젝트
    </p>
    <p id = "content">
        기업 특화 AI 솔루션 프로젝트
    </p>
    <p id = "content">
        빅데이터 AI 공모전 및 관심주제 프로젝트
    </p>
    <a href="https://www.google.com">첫화면으로 가기</a>
    <hr/>
    <img src="./images/hriver.jpg" width="600px">
    
</body>
</html>

# %%
# %load index.html
<!DOCTYPE html>
<html lang="en">
<head>
    
    <title>케빈의 홈페이지</title>
    <link href = "./practice.css" rel="stylesheet" type="text/css">

    <script type="javascript">
        
    </script>
    <script type="text/javascript" src="add_two_numbers.js"></script>
    <script type="text/javascript" src="what_time_is_it.js"></script>
</head>
<body>
    <nav>
        <a href="./index.html">Home</a>
        <a href="./blog_list.html">Blog</a>
        <a href="./about_me.html">About</a>
    </nav>

    <h1>첫번째 헤드라인</h1>
    <h2>두번째 헤드라인</h2>

    <button onclick="whatTimeIsIt()">현재시간</button>
    <hr/>
    <label for="inputA">a</label>
    <input id="inputA" value=1 onkeyup="doSomething()">
    <label for="inputB">b</label>
    <input id="inputB" value=2 onkeyup="doSomething()">

    <p><span id="valueA">1</span> + <span id="valueB">2</span>=<span id="valueC">3</span>입니다.</p>
    
    <p>프로젝트 기반 빅데이터 서비스 솔루션 개발 전문과정</p>
    <p id = "content">
        핵심적인 요소기술 14개 모듈 
    </p>
    <p id = "content">
        빅데이터 머신러닝 프로젝트
    </p>
    <p id = "content">
        기업 특화 AI 솔루션 프로젝트
    </p>
    <p id = "content">
        빅데이터 AI 공모전 및 관심주제 프로젝트
    </p>
    <a href="https://www.google.com">첫화면으로 가기</a>
    <hr/>
    <img src="./images/hriver.jpg" width="600px">
    
</body>
</html>

# %%
with open('index.html','r',encoding='utf8') as f:
    html = f.read()
    print(html)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
#     <title>케빈의 홈페이지</title>
#     <link href = "./practice.css" rel="stylesheet" type="text/css">
#
#     <script type="javascript">
#
#     </script>
#     <script type="text/javascript" src="add_two_numbers.js"></script>
#     <script type="text/javascript" src="what_time_is_it.js"></script>
# </head>
# <body>
#     <nav>
#         <a href="./index.html">Home</a>
#         <a href="./blog_list.html">Blog</a>
#         <a href="./about_me.html">About</a>
#     </nav>
#
#     <h1>첫번째 헤드라인</h1>
#     <h2>두번째 헤드라인</h2>
#
#     <button onclick="whatTimeIsIt()">현재시간</button>
#     <hr/>
#     <label for="inputA">a</label>
#     <input id="inputA" value=1 onkeyup="doSomething()">
#     <label for="inputB">b</label>
#     <input id="inputB" value=2 onkeyup="doSomething()">
#
#     <p><span id="valueA">1</span> + <span id="valueB">2</span>=<span id="valueC">3</span>입니다.</p>
#
#     <p>프로젝트 기반 빅데이터 서비스 솔루션 개발 전문과정</p>
#     <p id = "content">
#         핵심적인 요소기술 14개 모듈
#     </p>
#     <p id = "content">
#         빅데이터 머신러닝 프로젝트
#     </p>
#     <p id = "content">
#         기업 특화 AI 솔루션 프로젝트
#     </p>
#     <p id = "content">
#         빅데이터 AI 공모전 및 관심주제 프로젝트
#     </p>
#     <a href="https://www.google.com">첫화면으로 가기</a>
#     <hr/>
#     <img src="./images/hriver.jpg" width="600px">
#
# </body>
# </html>
